# %%
import requests
import base64
from common.custom_types import ImageData
from typing import Tuple, Optional


def fetch_image_as_base64(url: str) -> Optional[Tuple[bytes, str]]:
    """
    Fetches an image from a URL and returns its base64 content and MIME type.

    This function sends a GET request to the provided URL, retrieves the image
    content, and encodes it into a base64 string. It also extracts the
    'Content-Type' header to determine the image's MIME type.

    Args:
        url: The URL of the image to fetch.

    Returns:
        A tuple containing the base64-encoded string of the image and its
        MIME type (e.g., 'image/jpeg').
        Returns None if the request fails, the URL is invalid, or the
        content is not an image.
    """
    # Make the HTTP request to get the image.
    # Set a timeout to avoid hanging indefinitely.
    response = requests.get(url, stream=True, timeout=10)

    # Raise an exception for bad status codes (4xx or 5xx).
    response.raise_for_status()

    # Check the Content-Type header to ensure it's an image.
    mime_type = response.headers.get("Content-Type")
    if not mime_type or not mime_type.startswith("image/"):
        print(f"Warning: URL does not point to an image. MIME type: {mime_type}")
        return None

    # Get the raw binary content of the image.
    image_bytes = response.content

    # Encode the bytes into a base64 string.
    base64_content = base64.b64encode(image_bytes).decode('utf-8')

    return (base64_content, mime_type)


dummy_uri = "https://lh3.googleusercontent.com/gps-cs-s/AC9h4nolu0ktuCp6Iv2xYf862rZitPbloquBOiu53uSwa16PBf8QvFpHicv9KG9oLv1ToCzh7EnQcIQoL7RCYwkx2El97LO3V_TQ8qa4LMz7UtVUU-Tk1qW2lHB8G6bl0yULK2QruLX-hw=w1080"
# dummy_uri = "https://lh3.googleusercontent.com/gps-cs-s/AC9h4no1uCHfrVSWZ8wF0xORLVeQqBL9-7Nlw0JmTQzMsV17MKHXAXM_58i-P8OMqc_-4ZZyDe8xD5pIYSXiReG0OKZkwLJ4l7_zK-yBTTrAaaMW1Qz5cu0In2Kr-MlgfZu-3XteZafF=w1080"
# dummy_uri = "https://lh3.googleusercontent.com/gps-cs-s/AC9h4nptYsYx_z-xeV4_tOC7K7-WK8QVgHFvXaJq0LOlAE4NeMzzcZ-nQa41Ce_LfaUot4CVF6QhA5bEPLzJv8cakoXeHV9yNYn2jgfEHX3cfpBXGaa7CmCJHfbzd-PG7YCmjMBv5cnkGg=w1080"
dummy_uri = "https://lh3.googleusercontent.com/gps-cs-s/AC9h4nrcNsZt5FksLGx03CtA87lhNsHZVkyXm2xpmnBNtxlM1KrmlQivVfEuiUFzhK_rPG0ycmGjZdFUtFCvyvj4gIa7XXGXC6qMe7VwdVwmQjUz02erXFUpZeqbNkctBfEfRtd9k_h2=w1080"

bb, mime = fetch_image_as_base64(dummy_uri)
dummy_img = ImageData(base64=bb, mime_type=mime)
dummy_img
# Out:
# ImageData(base64=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xe1\x00hExif\x00\x00II*\x00\x08\x00\x00\x00\x02\x001\x01\x02\x00\x07\x00\x00\x00&\x00\x00\x00i\x87\x04\x00\x01\x00\x00\x00.\x00\x00\x00\x00\x00\x00\x00Picasa\x00\x00\x02\x00\x00\x90\x07\x00\x04\x00\x00\x000220\x03\x90\x02\x00\x14\x00\x00\x00L\x00\x00\x00\x00\x00\x00\x002023:09:03 17:52:35\x00\xff\xe2\x02(ICC_PROFILE\x00\x01\x01\x00\x00\x02\x18appl\x04\x00\x00\x00mntrRGB XYZ \x07\xe6\x00\x01\x00\x01\x00\x00\x00\x00\x00\x00acspAPPL\x00\x00\x00\x00APPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-appl\xec\xfd\xa3\x8e8\x85G\xc3m\xb4\xbdOz\xda\x18/\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ndesc\x00\x00\x00\xfc\x00\x00\x000cprt\x00\x00\x01,\x00\x00\x00Pwtpt\x00\x00\x01|\x00\x00\x00\x14rXYZ\x00\x00\x01\x90\x00\x00\x00\x14gXYZ\x00\x00\x01\xa4\x00\x00\x00\x14bXYZ\x00\x00\x01\xb8\x00\x00\x00\x14rTRC\x00\x00\x01\xcc\x00\x00\x00 chad\x00\x00\x01\xec\x00\x00\x00,bTRC\x00\x00\x01\xcc\x00\x00\x00 gTRC\x00\x00\x01\xcc\x00\x00\x00 mluc\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x0cenUS\x00\x00\x00\x14\x00\x00\x00\x1c\x00D\x00i\x00s\x00p\x00l\x00a\x00y\x00 \x00P\x003mluc\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x0cenUS\x00\x00\x004\x00\x00\x00\x1c\x00C\x00o\x00p\x00y\x00r\x00i\x00g\x00h\x00t\x00 \x00A\x00p\x00p\x00l\x00e\x00 \x00I\x00n\x00c\x00.\x00,\x00 \x002\x000\x002\x002XYZ \x00\x00\x00\x00\x00\x00\xf6\xd5\x00\x01\x00\x00\x00\x00\xd3,XYZ \x00\x00\x00\x00\x00\x00\x83\xdf\x00\x00=\xbf\xff\xff\xff\xbbXYZ \x00\x00\x00\x00\x00\x00J\xbf\x00\x00\xb17\x00\x00\n\xb9XYZ \x00\x00\x00\x00\x00\x00(8\x00\x00\x11\x0b\x00\x00\xc8\xb9para\x00\x00\x00\x00\x00\x03\x00\x00\x00\x02ff\x00\x00\xf2\xa7\x00\x00\rY\x00\x00\x13\xd0\x00\x00\n[sf32\x00\x00\x00\x00\x00\x01\x0cB\x00\x00\x05\xde\xff\xff\xf3&\x00\x00\x07\x93\x00\x00\xfd\x90\xff\xff\xfb\xa2\xff\xff\xfd\xa3\x00\x00\x03\xdc\x00\x00\xc0n\xff\xdb\x00\x84\x00\x03\x02\x02\n\n\n\n\n\n\n\n\n\n\n\n\x08\n\n\n\n\n\n\x08\n\n\x08\x08\x08\x08\x08\x08\x08\x08\n\x08\x08\x08\n\x08\x08\x08\x08\x08\x08\x08\n\n\x08\x08\x08\n\n\n\x08\x08\r\r\n\x08\r\x08\x08\n\x08\x01\x03\x04\x04\x06\x05\x06\x08\x06\x06\n\r\r\x08\r\r\x08\x08\x08\x08\x08\r\r\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\xff\xc0\x00\x11\x08\x05\xa0\x048\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x00\x06\x03\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x05\x06\x07\x00\x04\x08\t\xff\xc4\x00h\x10\x00\x02\x01\x02\x03\x04\x07\x05\x05\x05\x03\x05\x0c\x05\x01\x19\x01\x02\x03\x04\x11\x00\x12!\x05\x131A\x06\x07"Qaq\xf0\x08\x14\x81\x91\xa1#2\xb1\xc1\xd1\x15BR\xe1\xf1\t$3%CSbr\x16\x174DTcs\x82\x92\x93\xb2\xb3dt\x83\x94\xa2\xc2\x185\xa3\xb4\xc3\xd2&Eu\x84\x95\xa4\xc4\xd3\xd4Ue\x85\xe26\x19\xa5\xb5\xd5\xf4\xff\xc4\x00\x1c\x01\x01\x01\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\xff\xc4\x005\x11\x01\x00\x02\x01\x04\x01\x02\x05\x03\x02\x05\x04\x03\x01\x00\x00\x00\x01\x11\x02\x03\x12!1A\x04Q\x05\x13aq\x81"2\x91\x14\xa1B\xb1\xc1\xe1\xf13R\xd1\xf0\x06\x15b#\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xf2\xc0\x1c\r\xf0\\`\xc6\x01\xc6\r\x9b\t\xdf\x07E\xc0.\x89\x80c\x87-\x9b \x00\xdf\r\xf2\xb6c\xf1\xc78\xc9\xd2b\x9b{*\x9b\xf7\xb1\xb3Y?,)$\x99S\xe5\x86\xd4k\xe3\x15smu\x14_6\x0e\x87\x1a\xc2\xfd\xd8\x10\xc7\xbb\x1aK\x96\xe6\x10h\xc5\xf0jz\x06o\x0cn\xa6\xc8\xb7\x13\x8c\xdcA\x11b\xc7\x05\x85\x870G\xccr\xf1\xc7\xb0>\xc2\xddo\xa6\xd2\xd8\xd1\x04\xa7\x14\xe7gn\xa8%\x0bl\xb2\xc9\x1cK#N\xb6\xd6\xd2+\xad\xc3j\x08<os\xe4\x1a\xd1\x9e\xfcz\x8b\xfd\x97\xfd\x1e\x92=\x8bW+}\xca\x9d\xa0\xef\x1f\x941GN\xe7\xfe\xdcd|1\xbd<\xad5:u\xac\x982\x9c\x14\x91\x83(\xc7\xa2\x1eY\x18\xb6\x077\x80\xc1m\x8c\x03\x1ad\xa1l\x14\xb6\x00/<\x05\xb0\x07\xdez\x18\xcc\xd8!\xc1\xb2\x ...

# %%
from menu_reader import read_menu

res = read_menu(dummy_img)
# Out:
# text_annotations {
#   locale: "en"
#   description: "NEIR\'S\nTAVERN\nEST. 1829\nA TRUE HISTORIC GEM OF NEW YORK CITY\nServing the Coldest Beer in Town for Nearly Two Centuries!\na\nstablished in 1829, Neir\'s Tavern retains much\nmahogany bar and rare stainless steel coil system that\nstill uses ice to serve the coldest beer in town.\nFamed for being one of the oldest bars in New York,\nit\'s the place where many of the iconic scenes were\nfilmed for the classic movie, \"Goodfellas\". Neir\'s was\nalso used for other films such as \"Tower Heist\", and it\nis the bar where Mae West first performed.\nNow known for its excellent food and drinks, we hope\nyou will enjoy your visit to our neighborhood gem, and\nknow that your support will help Neir\'s\nreach its 200th Anniversary in 2029!\nSCAN TO READ THE TAVERN\'S FULL HISTORY ->\nBOWLING\nJOS EPPIC\'S BEER\nSPECIALTY\n&\nCOCKTAILS\nC3\nNEIR\'S Signature Cocktail\nTHE WISE GUY\n12\nUncle Nearest Whiskey, Sweet Vermouth,\nAmaretto, Dash of Bitters\nNEIR\'S OLD FASHIONED 12\nHistoric Old Fashion Cocktail from 1895\nMAE WEST PUNCH 10\nWhiskey, Rum, Lemon & Pineapple Juice\nwith Ginger Ale\nNEIR\'S WHISKEY MULE 10\nWhiskey, Ginger beer, Lime Juice\nCLASSIC WHISKEY SOUR 10\nWhisky, Lemon juice, Simple Syrup\nWHISKEY CHERRY COKE 10\nWhiskey, Grenadine, Coke\nNEIR\'S Specialty\nHAYMAKER\'S PUNCH 12\nDRAFT\nAsk About Our\nMAI-TAI 10\nSpiced Rum, Coconut Rum,\nGrenadine, Pineapple Juice\nBLUE HAWAIIAN 10\nCoconut Rum, White Rum,\nPineapple Juice, Blue Curacao\nVODKA SUNRISE 10\nVodka, Orange Juice & Grenadine\nCOSMOPOLITAN 10\nVodka, Cranberry, Cointreau,\nLime Juice\n\"BEERS OF THE MONTH\"\nAlways On Tap\nGUINNESS 7\nSTELLA 6\nBLUE MOON 6\nFINBACK IPA 8\nLONG ISLAND ICED TEA 12\nVodka, Rum, Gin, Tequila, Triple Sec,\nSour Mix & Splash of Coke\nSIDECAR 12\nCognac, Orange Liqueur,\nFresh Squeezed Lemon Juice\nwith an Orange Twist\nMARGARITA 10\n(CLASSIC, MANGO, STRAWBERRY\nOR PASSION FRUIT)\nTequila, Triple Sec, Lime Juice,\nSour Mix\nThe preferred beverage of early American farmers. Neir\'s\ncombines this centuries-old recipe with a dark Jamaican rum,\nin honor of our owner\'s heritage, for a refreshing cocktail.\nVIRGIN VERSION 10\nBOTTLED Happy\nBUDWEISER 5\nBUD LIGHT 5\nCORONA 6\nCOORS LIGHT 5\nHEINEKEN 6\nHEINEKEN LIGHT 6\nMODELO 6\nMICHELOB ULTRA 5\nO\'DOULS N/A 6\nHour\nMONDAY - FRIDAY 2-7 PM\n$1 OFF ALL DRAFT BEER\n$5 SELECT APPS\nask server for details\nNEIRSTAVERN.COM O"
#   bounding_poly {
#     vertices {
#       x: 175
#       y: 69
#     }
#     vertices {
#       x: 960
#       y: 69
#     }
#     vertices {
#       x: 960
#       y: 1301
#     }
#     vertices {
#       x: 175
#       y: 1301
#     }
#   }
# }
# text_annotations {
#   description: "NEIR\'S"
#   bounding_poly {
#     vertices {
#       x: 470
#       y: 69
#     }
#     vertices {
#       x: 743
#       y: 87
#     }
#     vertices {
#       x: 740
#       y: 140
#     }
#     vertices {
#       x: 466
#       y: 122
#     }
#   }
# }
# text_annotations {
#   description: "TAVERN"
#   bounding_poly {
#     vertices {
#       x: 452
#       y: 152
#     }
#     vertices {
#       x: 533
#       y: 158
#     }
#     vertices {
#       x: 532
#       y: 172
#     }
#     vertices {
#       x: 451
#       y: 166
#     }
#   }
# }
# text_annotations {
#   description: "EST"
#   bounding_poly {
#     vertices {
#       x: 667
#       y: 169
#     }
#     vertices {
#       x: 703
#       y: 172
#     }
#     vertices {
#       x: 702
#       y: 186
#     }
#     vertices {
#       x: 666
#       y: 183
#     }
#   }
# }
# text_annotations {
#   description: "."
#   bounding_poly {
#     vertices {
#       x: 700
#       y: 172
#     }
#     vertices {
#       x: 706
#       y: 172
#     }
#     vertices {
#       x: 705
#       y: 185
#     }
#     vertices {
#       x: 699
#       y: 185
#     }
#   }
# }
# text_annotations {
#   description: "1829"
#   bounding_poly {
#     vertices {
#       x: 712
#       y: 173
#     }
#     vertices {
#       x: 755
#       y: 176
#     }
#     vertices {
#       x: 754
#       y: 189
#     }
#     vertices {
#       x: 711
#       y: 186
#     }
#   }
# }
# text_annotations {
#   description: "A"
#   bounding_poly {
#     vertices {
#       x: 184
#       y: 187
#     }
#     vertices {
#       x: 214
#       y: 189
#     }
#     vertices {
#       x: 212
#       y: 225
#     }
#     vertices {
#       x: 182
#       y: 223
#     }
#   }
# }
# text_annotations {
#   description: "TRUE"
#   bounding_poly {
#     vertices {
#       x: 235
#       y: 189
#     }
#     vertices {
#       x: 330
#       y: 195
#     }
#     vertices {
#       x: 327
#       y: 232
#     }
#     vertices {
#       x: 233
#       y: 226
#     }
#   }
# }
# text_annotations {
#   description: "HISTORIC"
#   bounding_poly {
#     vertices {
#       x: 352
#       y: 197
#     }
#     vertices {
#       x: 514
#       y: 207
#     }
#     vertices {
#       x: 511
#       y: 244
#     }
#     vertices {
#       x: 350
#       y: 234
#     }
#   }
# }
# text_annotations {
#   description: "GEM"
#   bounding_poly {
#     vertices {
#       x: 532
#       y: 209
#     }
#     vertices {
#       x: 612
#       y: 214
#     }
#     vertices {
#       x: 610
#       y: 250
#     }
#     vertices {
#       x: 530
#       y: 245
#     }
#   }
# }
# text_annotations {
#   description: "OF"
#   bounding_poly {
#     vertices {
#       x: 630
#       y: 215
#     }
#     vertices {
#       x: 672
#       y: 218
#     }
#     vertices {
#       x: 670
#       y: 255
#     }
#     vertices {
#       x: 628
#       y: 252
#     }
#   }
# }
# text_annotations {
#   description: "NEW"
#   bounding_poly {
#     vertices {
#       x: 688
#       y: 219
#     }
#     vertices {
#       x: 770
#       y: 224
#     }
#     vertices {
#       x: 768
#       y: 260
#     }
#     vertices {
#       x: 686
#       y: 255
#     }
#   }
# }
# text_annotations {
#   description: "YORK"
#   bounding_poly {
#     vertices {
#       x: 788
#       y: 225
#     }
#     vertices {
#       x: 874
#       y: 231
#     }
#     vertices {
#       x: 871
#       y: 267
#     }
#     vertices {
#       x: 786
#       y: 262
#     }
#   }
# }
# text_annotations {
#   description: "CITY"
#   bounding_poly {
#     vertices {
#       x: 891
#       y: 232
#     }
#     vertices {
#       x: 960
#       y: 236
#     }
#     vertices {
#       x: 958
#       y: 272
#     }
#     vertices {
#       x: 889
#       y: 268
#     }
#   }
# }
# text_annotations {
#   description: "Serving"
#   bounding_poly {
#     vertices {
#       x: 186
#       y: 231
#     }
#     vertices {
#       x: 263
#       y: 236
#     }
#     vertices {
#       x: 262
#       y: 256
#     }
#     vertices {
#       x: 185
#       y: 251
#     }
#   }
# }
# text_annotations {
#   description: "the"
#   bounding_poly {
#     vertices {
#       x: 274
#       y: 237
#     }
#     vertices {
#       x: 302
#       y: 239
#     }
#     vertices {
#       x: 301
#       y: 258
#     }
#     vertices {
#       x: 273
#       y: 256
#     }
#   }
# }
# text_annotations {
#   description: "Coldest"
#   bounding_poly {
#     vertices {
#       x: 314
#       y: 239
#     }
#     vertices {
#       x: 385
#       y: 243
#     }
#     vertices {
#       x: 384
#       y: 263
#     }
#     vertices {
#       x: 313
#       y: 259
#     }
#   }
# }
# text_annotations {
#   description: "Beer"
#   bounding_poly {
#     vertices {
#       x: 393
#       y: 244
#     }
#     vertices {
#       x: 438
#       y: 247
#     }
#     vertices {
#       x: 437
#       y: 266
#     }
#     vertices {
#       x: 392
#       y: 263
#     }
#   }
# }
# text_annotations {
#   description: "in"
#   bounding_poly {
#     vertices {
#       x: 447
#       y: 247
#     }
#     vertices {
#       x: 465
#       y: 248
#     }
#     vertices {
#       x: 464
#       y: 267
#     }
#     vertices {
#       x: 446
#       y: 266
#     }
#   }
# }
# text_annotations {
#   description: "Town"
#   bounding_poly {
#     vertices {
#       x: 474
#       y: 249
#     }
#     vertices {
#       x: 524
#       y: 252
#     }
#     vertices {
#       x: 523
#       y: 271
#     }
#     vertices {
#       x: 473
#       y: 268
#     }
#   }
# }
# text_annotations {
#   description: "for"
#   bounding_poly {
#     vertices {
#       x: 532
#       y: 252
#     }
#     vertices {
#       x: 560
#       y: 254
#     }
#     vertices {
#       x: 559
#       y: 274
#     }
#     vertices {
#       x: 531
#       y: 272
#     }
#   }
# }
# text_annotations {
#   description: "Nearly"
#   bounding_poly {
#     vertices {
#       x: 567
#       y: 254
#     }
#     vertices {
#       x: 628
#       y: 258
#     }
#     vertices {
#       x: 627
#       y: 278
#     }
#     vertices {
#       x: 566
#       y: 274
#     }
#   }
# }
# text_annotations {
#   description: "Two"
#   bounding_poly {
#     vertices {
#       x: 636
#       y: 258
#     }
#     vertices {
#       x: 673
#       y: 260
#     }
#     vertices {
#       x: 672
#       y: 279
#     }
#     vertices {
#       x: 635
#       y: 277
#     }
#   }
# }
# text_annotations {
#   description: "Centuries"
#   bounding_poly {
#     vertices {
#       x: 682
#       y: 261
#     }
#     vertices {
#       x: 767
#       y: 266
#     }
#     vertices {
#       x: 766
#       y: 285
#     }
#     vertices {
#       x: 681
#       y: 280
#     }
#   }
# }
# text_annotations {
#   description: "!"
#   bounding_poly {
#     vertices {
#       x: 766
#       y: 266
#     }
#     vertices {
#       x: 774
#       y: 266
#     }
#     vertices {
#       x: 773
#       y: 285
#     }
#     vertices {
#       x: 765
#       y: 285
#     }
#   }
# }
# text_annotations {
#   description: "a"
#   bounding_poly {
#     vertices {
#       x: 461
#       y: 294
#     }
#     vertices {
#       x: 471
#       y: 295
#     }
#     vertices {
#       x: 470
#       y: 321
#     }
#     vertices {
#       x: 460
#       y: 320
#     }
#   }
# }
# text_annotations {
#   description: "stablished"
#   bounding_poly {
#     vertices {
#       x: 211
#       y: 277
#     }
#     vertices {
#       x: 286
#       y: 281
#     }
#     vertices {
#       x: 285
#       y: 295
#     }
#     vertices {
#       x: 210
#       y: 291
#     }
#   }
# }
# text_annotations {
#   description: "in"
#   bounding_poly {
#     vertices {
#       x: 294
#       y: 282
#     }
#     vertices {
#       x: 308
#       y: 283
#     }
#     vertices {
#       x: 307
#       y: 296
#     }
#     vertices {
#       x: 293
#       y: 295
#     }
#   }
# }
# text_annotations {
#   description: "1829"
#   bounding_poly {
#     vertices {
#       x: 316
#       y: 283
#     }
#     vertices {
#       x: 350
#       y: 285
#     }
#     vertices {
#       x: 349
#       y: 298
#     }
#     vertices {
#       x: 315
#       y: 296
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 348
#       y: 285
#     }
#     vertices {
#       x: 353
#       y: 285
#     }
#     vertices {
#       x: 352
#       y: 298
#     }
#     vertices {
#       x: 347
#       y: 298
#     }
#   }
# }
# text_annotations {
#   description: "Neir\'s"
#   bounding_poly {
#     vertices {
#       x: 360
#       y: 285
#     }
#     vertices {
#       x: 401
#       y: 287
#     }
#     vertices {
#       x: 400
#       y: 301
#     }
#     vertices {
#       x: 359
#       y: 299
#     }
#   }
# }
# text_annotations {
#   description: "Tavern"
#   bounding_poly {
#     vertices {
#       x: 408
#       y: 287
#     }
#     vertices {
#       x: 456
#       y: 289
#     }
#     vertices {
#       x: 455
#       y: 303
#     }
#     vertices {
#       x: 407
#       y: 301
#     }
#   }
# }
# text_annotations {
#   description: "retains"
#   bounding_poly {
#     vertices {
#       x: 464
#       y: 290
#     }
#     vertices {
#       x: 511
#       y: 292
#     }
#     vertices {
#       x: 510
#       y: 306
#     }
#     vertices {
#       x: 463
#       y: 304
#     }
#   }
# }
# text_annotations {
#   description: "much"
#   bounding_poly {
#     vertices {
#       x: 519
#       y: 293
#     }
#     vertices {
#       x: 556
#       y: 295
#     }
#     vertices {
#       x: 555
#       y: 309
#     }
#     vertices {
#       x: 518
#       y: 307
#     }
#   }
# }
# text_annotations {
#   description: "mahogany"
#   bounding_poly {
#     vertices {
#       x: 185
#       y: 312
#     }
#     vertices {
#       x: 261
#       y: 315
#     }
#     vertices {
#       x: 260
#       y: 329
#     }
#     vertices {
#       x: 184
#       y: 326
#     }
#   }
# }
# text_annotations {
#   description: "bar"
#   bounding_poly {
#     vertices {
#       x: 264
#       y: 316
#     }
#     vertices {
#       x: 290
#       y: 317
#     }
#     vertices {
#       x: 289
#       y: 331
#     }
#     vertices {
#       x: 263
#       y: 330
#     }
#   }
# }
# text_annotations {
#   description: "and"
#   bounding_poly {
#     vertices {
#       x: 292
#       y: 317
#     }
#     vertices {
#       x: 318
#       y: 318
#     }
#     vertices {
#       x: 317
#       y: 332
#     }
#     vertices {
#       x: 291
#       y: 331
#     }
#   }
# }
# text_annotations {
#   description: "rare"
#   bounding_poly {
#     vertices {
#       x: 321
#       y: 318
#     }
#     vertices {
#       x: 352
#       y: 319
#     }
#     vertices {
#       x: 351
#       y: 333
#     }
#     vertices {
#       x: 320
#       y: 332
#     }
#   }
# }
# text_annotations {
#   description: "stainless"
#   bounding_poly {
#     vertices {
#       x: 355
#       y: 320
#     }
#     vertices {
#       x: 415
#       y: 323
#     }
#     vertices {
#       x: 414
#       y: 337
#     }
#     vertices {
#       x: 354
#       y: 334
#     }
#   }
# }
# text_annotations {
#   description: "steel"
#   bounding_poly {
#     vertices {
#       x: 418
#       y: 323
#     }
#     vertices {
#       x: 450
#       y: 324
#     }
#     vertices {
#       x: 449
#       y: 337
#     }
#     vertices {
#       x: 417
#       y: 336
#     }
#   }
# }
# text_annotations {
#   description: "coil"
#   bounding_poly {
#     vertices {
#       x: 453
#       y: 325
#     }
#     vertices {
#       x: 478
#       y: 326
#     }
#     vertices {
#       x: 477
#       y: 339
#     }
#     vertices {
#       x: 452
#       y: 338
#     }
#   }
# }
# text_annotations {
#   description: "system"
#   bounding_poly {
#     vertices {
#       x: 480
#       y: 326
#     }
#     vertices {
#       x: 525
#       y: 328
#     }
#     vertices {
#       x: 524
#       y: 341
#     }
#     vertices {
#       x: 479
#       y: 339
#     }
#   }
# }
# text_annotations {
#   description: "that"
#   bounding_poly {
#     vertices {
#       x: 528
#       y: 328
#     }
#     vertices {
#       x: 557
#       y: 329
#     }
#     vertices {
#       x: 556
#       y: 343
#     }
#     vertices {
#       x: 527
#       y: 342
#     }
#   }
# }
# text_annotations {
#   description: "still"
#   bounding_poly {
#     vertices {
#       x: 185
#       y: 329
#     }
#     vertices {
#       x: 212
#       y: 330
#     }
#     vertices {
#       x: 211
#       y: 342
#     }
#     vertices {
#       x: 184
#       y: 341
#     }
#   }
# }
# text_annotations {
#   description: "uses"
#   bounding_poly {
#     vertices {
#       x: 216
#       y: 331
#     }
#     vertices {
#       x: 249
#       y: 333
#     }
#     vertices {
#       x: 248
#       y: 344
#     }
#     vertices {
#       x: 215
#       y: 342
#     }
#   }
# }
# text_annotations {
#   description: "ice"
#   bounding_poly {
#     vertices {
#       x: 251
#       y: 332
#     }
#     vertices {
#       x: 272
#       y: 333
#     }
#     vertices {
#       x: 271
#       y: 345
#     }
#     vertices {
#       x: 250
#       y: 344
#     }
#   }
# }
# text_annotations {
#   description: "to"
#   bounding_poly {
#     vertices {
#       x: 276
#       y: 334
#     }
#     vertices {
#       x: 290
#       y: 335
#     }
#     vertices {
#       x: 289
#       y: 346
#     }
#     vertices {
#       x: 275
#       y: 345
#     }
#   }
# }
# text_annotations {
#   description: "serve"
#   bounding_poly {
#     vertices {
#       x: 294
#       y: 334
#     }
#     vertices {
#       x: 331
#       y: 336
#     }
#     vertices {
#       x: 330
#       y: 348
#     }
#     vertices {
#       x: 293
#       y: 346
#     }
#   }
# }
# text_annotations {
#   description: "the"
#   bounding_poly {
#     vertices {
#       x: 334
#       y: 336
#     }
#     vertices {
#       x: 357
#       y: 337
#     }
#     vertices {
#       x: 356
#       y: 349
#     }
#     vertices {
#       x: 333
#       y: 348
#     }
#   }
# }
# text_annotations {
#   description: "coldest"
#   bounding_poly {
#     vertices {
#       x: 361
#       y: 337
#     }
#     vertices {
#       x: 411
#       y: 339
#     }
#     vertices {
#       x: 410
#       y: 351
#     }
#     vertices {
#       x: 360
#       y: 349
#     }
#   }
# }
# text_annotations {
#   description: "beer"
#   bounding_poly {
#     vertices {
#       x: 414
#       y: 340
#     }
#     vertices {
#       x: 444
#       y: 341
#     }
#     vertices {
#       x: 443
#       y: 352
#     }
#     vertices {
#       x: 413
#       y: 351
#     }
#   }
# }
# text_annotations {
#   description: "in"
#   bounding_poly {
#     vertices {
#       x: 447
#       y: 342
#     }
#     vertices {
#       x: 461
#       y: 343
#     }
#     vertices {
#       x: 460
#       y: 354
#     }
#     vertices {
#       x: 446
#       y: 353
#     }
#   }
# }
# text_annotations {
#   description: "town"
#   bounding_poly {
#     vertices {
#       x: 466
#       y: 342
#     }
#     vertices {
#       x: 499
#       y: 344
#     }
#     vertices {
#       x: 498
#       y: 356
#     }
#     vertices {
#       x: 465
#       y: 354
#     }
#   }
# }
# text_annotations {
#   description: "."
#   bounding_poly {
#     vertices {
#       x: 498
#       y: 344
#     }
#     vertices {
#       x: 501
#       y: 344
#     }
#     vertices {
#       x: 500
#       y: 355
#     }
#     vertices {
#       x: 497
#       y: 355
#     }
#   }
# }
# text_annotations {
#   description: "Famed"
#   bounding_poly {
#     vertices {
#       x: 185
#       y: 353
#     }
#     vertices {
#       x: 235
#       y: 355
#     }
#     vertices {
#       x: 234
#       y: 370
#     }
#     vertices {
#       x: 184
#       y: 368
#     }
#   }
# }
# text_annotations {
#   description: "for"
#   bounding_poly {
#     vertices {
#       x: 238
#       y: 355
#     }
#     vertices {
#       x: 261
#       y: 356
#     }
#     vertices {
#       x: 260
#       y: 371
#     }
#     vertices {
#       x: 237
#       y: 370
#     }
#   }
# }
# text_annotations {
#   description: "being"
#   bounding_poly {
#     vertices {
#       x: 266
#       y: 357
#     }
#     vertices {
#       x: 307
#       y: 359
#     }
#     vertices {
#       x: 306
#       y: 373
#     }
#     vertices {
#       x: 265
#       y: 371
#     }
#   }
# }
# text_annotations {
#   description: "one"
#   bounding_poly {
#     vertices {
#       x: 311
#       y: 359
#     }
#     vertices {
#       x: 337
#       y: 360
#     }
#     vertices {
#       x: 336
#       y: 374
#     }
#     vertices {
#       x: 310
#       y: 373
#     }
#   }
# }
# text_annotations {
#   description: "of"
#   bounding_poly {
#     vertices {
#       x: 342
#       y: 360
#     }
#     vertices {
#       x: 357
#       y: 361
#     }
#     vertices {
#       x: 356
#       y: 376
#     }
#     vertices {
#       x: 341
#       y: 375
#     }
#   }
# }
# text_annotations {
#   description: "the"
#   bounding_poly {
#     vertices {
#       x: 361
#       y: 361
#     }
#     vertices {
#       x: 383
#       y: 362
#     }
#     vertices {
#       x: 382
#       y: 376
#     }
#     vertices {
#       x: 360
#       y: 375
#     }
#   }
# }
# text_annotations {
#   description: "oldest"
#   bounding_poly {
#     vertices {
#       x: 388
#       y: 362
#     }
#     vertices {
#       x: 431
#       y: 364
#     }
#     vertices {
#       x: 430
#       y: 379
#     }
#     vertices {
#       x: 387
#       y: 377
#     }
#   }
# }
# text_annotations {
#   description: "bars"
#   bounding_poly {
#     vertices {
#       x: 436
#       y: 364
#     }
#     vertices {
#       x: 464
#       y: 365
#     }
#     vertices {
#       x: 463
#       y: 380
#     }
#     vertices {
#       x: 435
#       y: 379
#     }
#   }
# }
# text_annotations {
#   description: "in"
#   bounding_poly {
#     vertices {
#       x: 471
#       y: 366
#     }
#     vertices {
#       x: 483
#       y: 367
#     }
#     vertices {
#       x: 482
#       y: 380
#     }
#     vertices {
#       x: 470
#       y: 380
#     }
#   }
# }
# text_annotations {
#   description: "New"
#   bounding_poly {
#     vertices {
#       x: 489
#       y: 366
#     }
#     vertices {
#       x: 518
#       y: 367
#     }
#     vertices {
#       x: 517
#       y: 382
#     }
#     vertices {
#       x: 488
#       y: 381
#     }
#   }
# }
# text_annotations {
#   description: "York"
#   bounding_poly {
#     vertices {
#       x: 522
#       y: 368
#     }
#     vertices {
#       x: 554
#       y: 369
#     }
#     vertices {
#       x: 553
#       y: 383
#     }
#     vertices {
#       x: 521
#       y: 382
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 553
#       y: 369
#     }
#     vertices {
#       x: 556
#       y: 369
#     }
#     vertices {
#       x: 555
#       y: 383
#     }
#     vertices {
#       x: 552
#       y: 383
#     }
#   }
# }
# text_annotations {
#   description: "it\'s"
#   bounding_poly {
#     vertices {
#       x: 186
#       y: 369
#     }
#     vertices {
#       x: 207
#       y: 370
#     }
#     vertices {
#       x: 206
#       y: 385
#     }
#     vertices {
#       x: 185
#       y: 384
#     }
#   }
# }
# text_annotations {
#   description: "the"
#   bounding_poly {
#     vertices {
#       x: 212
#       y: 370
#     }
#     vertices {
#       x: 236
#       y: 371
#     }
#     vertices {
#       x: 235
#       y: 386
#     }
#     vertices {
#       x: 211
#       y: 385
#     }
#   }
# }
# text_annotations {
#   description: "place"
#   bounding_poly {
#     vertices {
#       x: 242
#       y: 372
#     }
#     vertices {
#       x: 281
#       y: 374
#     }
#     vertices {
#       x: 280
#       y: 388
#     }
#     vertices {
#       x: 241
#       y: 386
#     }
#   }
# }
# text_annotations {
#   description: "where"
#   bounding_poly {
#     vertices {
#       x: 286
#       y: 374
#     }
#     vertices {
#       x: 330
#       y: 376
#     }
#     vertices {
#       x: 329
#       y: 390
#     }
#     vertices {
#       x: 285
#       y: 388
#     }
#   }
# }
# text_annotations {
#   description: "many"
#   bounding_poly {
#     vertices {
#       x: 336
#       y: 376
#     }
#     vertices {
#       x: 376
#       y: 378
#     }
#     vertices {
#       x: 375
#       y: 393
#     }
#     vertices {
#       x: 335
#       y: 391
#     }
#   }
# }
# text_annotations {
#   description: "of"
#   bounding_poly {
#     vertices {
#       x: 381
#       y: 378
#     }
#     vertices {
#       x: 397
#       y: 379
#     }
#     vertices {
#       x: 396
#       y: 394
#     }
#     vertices {
#       x: 380
#       y: 393
#     }
#   }
# }
# text_annotations {
#   description: "the"
#   bounding_poly {
#     vertices {
#       x: 400
#       y: 379
#     }
#     vertices {
#       x: 423
#       y: 380
#     }
#     vertices {
#       x: 422
#       y: 394
#     }
#     vertices {
#       x: 399
#       y: 393
#     }
#   }
# }
# text_annotations {
#   description: "iconic"
#   bounding_poly {
#     vertices {
#       x: 429
#       y: 380
#     }
#     vertices {
#       x: 470
#       y: 382
#     }
#     vertices {
#       x: 469
#       y: 397
#     }
#     vertices {
#       x: 428
#       y: 395
#     }
#   }
# }
# text_annotations {
#   description: "scenes"
#   bounding_poly {
#     vertices {
#       x: 475
#       y: 382
#     }
#     vertices {
#       x: 519
#       y: 384
#     }
#     vertices {
#       x: 518
#       y: 399
#     }
#     vertices {
#       x: 474
#       y: 397
#     }
#   }
# }
# text_annotations {
#   description: "were"
#   bounding_poly {
#     vertices {
#       x: 524
#       y: 385
#     }
#     vertices {
#       x: 557
#       y: 386
#     }
#     vertices {
#       x: 556
#       y: 400
#     }
#     vertices {
#       x: 523
#       y: 399
#     }
#   }
# }
# text_annotations {
#   description: "filmed"
#   bounding_poly {
#     vertices {
#       x: 185
#       y: 388
#     }
#     vertices {
#       x: 232
#       y: 390
#     }
#     vertices {
#       x: 231
#       y: 403
#     }
#     vertices {
#       x: 184
#       y: 401
#     }
#   }
# }
# text_annotations {
#   description: "for"
#   bounding_poly {
#     vertices {
#       x: 236
#       y: 390
#     }
#     vertices {
#       x: 260
#       y: 391
#     }
#     vertices {
#       x: 259
#       y: 404
#     }
#     vertices {
#       x: 235
#       y: 403
#     }
#   }
# }
# text_annotations {
#   description: "the"
#   bounding_poly {
#     vertices {
#       x: 264
#       y: 391
#     }
#     vertices {
#       x: 288
#       y: 392
#     }
#     vertices {
#       x: 287
#       y: 405
#     }
#     vertices {
#       x: 263
#       y: 404
#     }
#   }
# }
# text_annotations {
#   description: "classic"
#   bounding_poly {
#     vertices {
#       x: 293
#       y: 392
#     }
#     vertices {
#       x: 341
#       y: 394
#     }
#     vertices {
#       x: 340
#       y: 407
#     }
#     vertices {
#       x: 292
#       y: 405
#     }
#   }
# }
# text_annotations {
#   description: "movie"
#   bounding_poly {
#     vertices {
#       x: 345
#       y: 395
#     }
#     vertices {
#       x: 388
#       y: 397
#     }
#     vertices {
#       x: 387
#       y: 410
#     }
#     vertices {
#       x: 344
#       y: 408
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 387
#       y: 397
#     }
#     vertices {
#       x: 391
#       y: 397
#     }
#     vertices {
#       x: 391
#       y: 409
#     }
#     vertices {
#       x: 387
#       y: 409
#     }
#   }
# }
# text_annotations {
#   description: "\""
#   bounding_poly {
#     vertices {
#       x: 396
#       y: 397
#     }
#     vertices {
#       x: 402
#       y: 397
#     }
#     vertices {
#       x: 402
#       y: 409
#     }
#     vertices {
#       x: 396
#       y: 409
#     }
#   }
# }
# text_annotations {
#   description: "Goodfellas"
#   bounding_poly {
#     vertices {
#       x: 401
#       y: 397
#     }
#     vertices {
#       x: 475
#       y: 400
#     }
#     vertices {
#       x: 474
#       y: 413
#     }
#     vertices {
#       x: 400
#       y: 410
#     }
#   }
# }
# text_annotations {
#   description: "\""
#   bounding_poly {
#     vertices {
#       x: 474
#       y: 400
#     }
#     vertices {
#       x: 480
#       y: 400
#     }
#     vertices {
#       x: 480
#       y: 412
#     }
#     vertices {
#       x: 474
#       y: 412
#     }
#   }
# }
# text_annotations {
#   description: "."
#   bounding_poly {
#     vertices {
#       x: 479
#       y: 401
#     }
#     vertices {
#       x: 483
#       y: 401
#     }
#     vertices {
#       x: 483
#       y: 413
#     }
#     vertices {
#       x: 479
#       y: 413
#     }
#   }
# }
# text_annotations {
#   description: "Neir\'s"
#   bounding_poly {
#     vertices {
#       x: 488
#       y: 401
#     }
#     vertices {
#       x: 528
#       y: 403
#     }
#     vertices {
#       x: 527
#       y: 415
#     }
#     vertices {
#       x: 488
#       y: 413
#     }
#   }
# }
# text_annotations {
#   description: "was"
#   bounding_poly {
#     vertices {
#       x: 531
#       y: 403
#     }
#     vertices {
#       x: 557
#       y: 404
#     }
#     vertices {
#       x: 556
#       y: 416
#     }
#     vertices {
#       x: 531
#       y: 415
#     }
#   }
# }
# text_annotations {
#   description: "also"
#   bounding_poly {
#     vertices {
#       x: 186
#       y: 404
#     }
#     vertices {
#       x: 216
#       y: 405
#     }
#     vertices {
#       x: 215
#       y: 419
#     }
#     vertices {
#       x: 185
#       y: 418
#     }
#   }
# }
# text_annotations {
#   description: "used"
#   bounding_poly {
#     vertices {
#       x: 219
#       y: 405
#     }
#     vertices {
#       x: 253
#       y: 406
#     }
#     vertices {
#       x: 252
#       y: 420
#     }
#     vertices {
#       x: 218
#       y: 419
#     }
#   }
# }
# text_annotations {
#   description: "for"
#   bounding_poly {
#     vertices {
#       x: 257
#       y: 407
#     }
#     vertices {
#       x: 279
#       y: 408
#     }
#     vertices {
#       x: 278
#       y: 421
#     }
#     vertices {
#       x: 256
#       y: 420
#     }
#   }
# }
# text_annotations {
#   description: "other"
#   bounding_poly {
#     vertices {
#       x: 282
#       y: 408
#     }
#     vertices {
#       x: 322
#       y: 410
#     }
#     vertices {
#       x: 321
#       y: 424
#     }
#     vertices {
#       x: 281
#       y: 422
#     }
#   }
# }
# text_annotations {
#   description: "films"
#   bounding_poly {
#     vertices {
#       x: 325
#       y: 409
#     }
#     vertices {
#       x: 360
#       y: 410
#     }
#     vertices {
#       x: 359
#       y: 424
#     }
#     vertices {
#       x: 324
#       y: 423
#     }
#   }
# }
# text_annotations {
#   description: "such"
#   bounding_poly {
#     vertices {
#       x: 364
#       y: 411
#     }
#     vertices {
#       x: 397
#       y: 412
#     }
#     vertices {
#       x: 396
#       y: 426
#     }
#     vertices {
#       x: 363
#       y: 425
#     }
#   }
# }
# text_annotations {
#   description: "as"
#   bounding_poly {
#     vertices {
#       x: 401
#       y: 413
#     }
#     vertices {
#       x: 414
#       y: 414
#     }
#     vertices {
#       x: 413
#       y: 426
#     }
#     vertices {
#       x: 400
#       y: 426
#     }
#   }
# }
# text_annotations {
#   description: "\""
#   bounding_poly {
#     vertices {
#       x: 419
#       y: 414
#     }
#     vertices {
#       x: 425
#       y: 414
#     }
#     vertices {
#       x: 424
#       y: 427
#     }
#     vertices {
#       x: 418
#       y: 427
#     }
#   }
# }
# text_annotations {
#   description: "Tower"
#   bounding_poly {
#     vertices {
#       x: 425
#       y: 413
#     }
#     vertices {
#       x: 468
#       y: 415
#     }
#     vertices {
#       x: 467
#       y: 429
#     }
#     vertices {
#       x: 424
#       y: 427
#     }
#   }
# }
# text_annotations {
#   description: "Heist"
#   bounding_poly {
#     vertices {
#       x: 471
#       y: 415
#     }
#     vertices {
#       x: 508
#       y: 416
#     }
#     vertices {
#       x: 507
#       y: 430
#     }
#     vertices {
#       x: 470
#       y: 429
#     }
#   }
# }
# text_annotations {
#   description: "\""
#   bounding_poly {
#     vertices {
#       x: 506
#       y: 417
#     }
#     vertices {
#       x: 511
#       y: 417
#     }
#     vertices {
#       x: 510
#       y: 430
#     }
#     vertices {
#       x: 505
#       y: 430
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 511
#       y: 417
#     }
#     vertices {
#       x: 515
#       y: 417
#     }
#     vertices {
#       x: 514
#       y: 430
#     }
#     vertices {
#       x: 510
#       y: 430
#     }
#   }
# }
# text_annotations {
#   description: "and"
#   bounding_poly {
#     vertices {
#       x: 518
#       y: 417
#     }
#     vertices {
#       x: 543
#       y: 418
#     }
#     vertices {
#       x: 542
#       y: 432
#     }
#     vertices {
#       x: 517
#       y: 431
#     }
#   }
# }
# text_annotations {
#   description: "it"
#   bounding_poly {
#     vertices {
#       x: 548
#       y: 419
#     }
#     vertices {
#       x: 558
#       y: 419
#     }
#     vertices {
#       x: 557
#       y: 432
#     }
#     vertices {
#       x: 547
#       y: 432
#     }
#   }
# }
# text_annotations {
#   description: "is"
#   bounding_poly {
#     vertices {
#       x: 186
#       y: 423
#     }
#     vertices {
#       x: 198
#       y: 423
#     }
#     vertices {
#       x: 198
#       y: 435
#     }
#     vertices {
#       x: 186
#       y: 435
#     }
#   }
# }
# text_annotations {
#   description: "the"
#   bounding_poly {
#     vertices {
#       x: 201
#       y: 423
#     }
#     vertices {
#       x: 226
#       y: 424
#     }
#     vertices {
#       x: 226
#       y: 436
#     }
#     vertices {
#       x: 201
#       y: 435
#     }
#   }
# }
# text_annotations {
#   description: "bar"
#   bounding_poly {
#     vertices {
#       x: 228
#       y: 424
#     }
#     vertices {
#       x: 255
#       y: 425
#     }
#     vertices {
#       x: 254
#       y: 438
#     }
#     vertices {
#       x: 227
#       y: 437
#     }
#   }
# }
# text_annotations {
#   description: "where"
#   bounding_poly {
#     vertices {
#       x: 257
#       y: 425
#     }
#     vertices {
#       x: 302
#       y: 427
#     }
#     vertices {
#       x: 301
#       y: 440
#     }
#     vertices {
#       x: 256
#       y: 438
#     }
#   }
# }
# text_annotations {
#   description: "Mae"
#   bounding_poly {
#     vertices {
#       x: 304
#       y: 427
#     }
#     vertices {
#       x: 335
#       y: 428
#     }
#     vertices {
#       x: 334
#       y: 440
#     }
#     vertices {
#       x: 304
#       y: 439
#     }
#   }
# }
# text_annotations {
#   description: "West"
#   bounding_poly {
#     vertices {
#       x: 337
#       y: 428
#     }
#     vertices {
#       x: 373
#       y: 429
#     }
#     vertices {
#       x: 372
#       y: 442
#     }
#     vertices {
#       x: 336
#       y: 441
#     }
#   }
# }
# text_annotations {
#   description: "first"
#   bounding_poly {
#     vertices {
#       x: 375
#       y: 430
#     }
#     vertices {
#       x: 404
#       y: 431
#     }
#     vertices {
#       x: 404
#       y: 443
#     }
#     vertices {
#       x: 375
#       y: 442
#     }
#   }
# }
# text_annotations {
#   description: "performed"
#   bounding_poly {
#     vertices {
#       x: 406
#       y: 431
#     }
#     vertices {
#       x: 480
#       y: 434
#     }
#     vertices {
#       x: 479
#       y: 447
#     }
#     vertices {
#       x: 405
#       y: 444
#     }
#   }
# }
# text_annotations {
#   description: "."
#   bounding_poly {
#     vertices {
#       x: 478
#       y: 434
#     }
#     vertices {
#       x: 482
#       y: 434
#     }
#     vertices {
#       x: 482
#       y: 446
#     }
#     vertices {
#       x: 478
#       y: 446
#     }
#   }
# }
# text_annotations {
#   description: "Now"
#   bounding_poly {
#     vertices {
#       x: 186
#       y: 446
#     }
#     vertices {
#       x: 219
#       y: 447
#     }
#     vertices {
#       x: 218
#       y: 460
#     }
#     vertices {
#       x: 186
#       y: 459
#     }
#   }
# }
# text_annotations {
#   description: "known"
#   bounding_poly {
#     vertices {
#       x: 223
#       y: 448
#     }
#     vertices {
#       x: 272
#       y: 450
#     }
#     vertices {
#       x: 272
#       y: 462
#     }
#     vertices {
#       x: 223
#       y: 460
#     }
#   }
# }
# text_annotations {
#   description: "for"
#   bounding_poly {
#     vertices {
#       x: 274
#       y: 449
#     }
#     vertices {
#       x: 296
#       y: 450
#     }
#     vertices {
#       x: 295
#       y: 463
#     }
#     vertices {
#       x: 274
#       y: 462
#     }
#   }
# }
# text_annotations {
#   description: "its"
#   bounding_poly {
#     vertices {
#       x: 299
#       y: 451
#     }
#     vertices {
#       x: 317
#       y: 452
#     }
#     vertices {
#       x: 317
#       y: 464
#     }
#     vertices {
#       x: 299
#       y: 463
#     }
#   }
# }
# text_annotations {
#   description: "excellent"
#   bounding_poly {
#     vertices {
#       x: 320
#       y: 451
#     }
#     vertices {
#       x: 384
#       y: 453
#     }
#     vertices {
#       x: 383
#       y: 466
#     }
#     vertices {
#       x: 320
#       y: 464
#     }
#   }
# }
# text_annotations {
#   description: "food"
#   bounding_poly {
#     vertices {
#       x: 387
#       y: 454
#     }
#     vertices {
#       x: 419
#       y: 455
#     }
#     vertices {
#       x: 419
#       y: 467
#     }
#     vertices {
#       x: 387
#       y: 466
#     }
#   }
# }
# text_annotations {
#   description: "and"
#   bounding_poly {
#     vertices {
#       x: 422
#       y: 455
#     }
#     vertices {
#       x: 449
#       y: 456
#     }
#     vertices {
#       x: 448
#       y: 469
#     }
#     vertices {
#       x: 422
#       y: 468
#     }
#   }
# }
# text_annotations {
#   description: "drinks"
#   bounding_poly {
#     vertices {
#       x: 451
#       y: 456
#     }
#     vertices {
#       x: 495
#       y: 458
#     }
#     vertices {
#       x: 494
#       y: 471
#     }
#     vertices {
#       x: 451
#       y: 469
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 495
#       y: 458
#     }
#     vertices {
#       x: 499
#       y: 458
#     }
#     vertices {
#       x: 499
#       y: 470
#     }
#     vertices {
#       x: 495
#       y: 470
#     }
#   }
# }
# text_annotations {
#   description: "we"
#   bounding_poly {
#     vertices {
#       x: 502
#       y: 458
#     }
#     vertices {
#       x: 520
#       y: 459
#     }
#     vertices {
#       x: 519
#       y: 472
#     }
#     vertices {
#       x: 502
#       y: 471
#     }
#   }
# }
# text_annotations {
#   description: "hope"
#   bounding_poly {
#     vertices {
#       x: 524
#       y: 459
#     }
#     vertices {
#       x: 557
#       y: 460
#     }
#     vertices {
#       x: 556
#       y: 473
#     }
#     vertices {
#       x: 524
#       y: 472
#     }
#   }
# }
# text_annotations {
#   description: "you"
#   bounding_poly {
#     vertices {
#       x: 186
#       y: 463
#     }
#     vertices {
#       x: 213
#       y: 464
#     }
#     vertices {
#       x: 213
#       y: 480
#     }
#     vertices {
#       x: 186
#       y: 479
#     }
#   }
# }
# text_annotations {
#   description: "will"
#   bounding_poly {
#     vertices {
#       x: 216
#       y: 464
#     }
#     vertices {
#       x: 243
#       y: 465
#     }
#     vertices {
#       x: 243
#       y: 481
#     }
#     vertices {
#       x: 216
#       y: 480
#     }
#   }
# }
# text_annotations {
#   description: "enjoy"
#   bounding_poly {
#     vertices {
#       x: 246
#       y: 465
#     }
#     vertices {
#       x: 285
#       y: 466
#     }
#     vertices {
#       x: 284
#       y: 482
#     }
#     vertices {
#       x: 246
#       y: 481
#     }
#   }
# }
# text_annotations {
#   description: "your"
#   bounding_poly {
#     vertices {
#       x: 287
#       y: 466
#     }
#     vertices {
#       x: 321
#       y: 467
#     }
#     vertices {
#       x: 320
#       y: 483
#     }
#     vertices {
#       x: 287
#       y: 482
#     }
#   }
# }
# text_annotations {
#   description: "visit"
#   bounding_poly {
#     vertices {
#       x: 323
#       y: 467
#     }
#     vertices {
#       x: 352
#       y: 468
#     }
#     vertices {
#       x: 352
#       y: 484
#     }
#     vertices {
#       x: 323
#       y: 483
#     }
#   }
# }
# text_annotations {
#   description: "to"
#   bounding_poly {
#     vertices {
#       x: 355
#       y: 469
#     }
#     vertices {
#       x: 370
#       y: 469
#     }
#     vertices {
#       x: 370
#       y: 484
#     }
#     vertices {
#       x: 355
#       y: 484
#     }
#   }
# }
# text_annotations {
#   description: "our"
#   bounding_poly {
#     vertices {
#       x: 372
#       y: 469
#     }
#     vertices {
#       x: 396
#       y: 470
#     }
#     vertices {
#       x: 396
#       y: 485
#     }
#     vertices {
#       x: 372
#       y: 484
#     }
#   }
# }
# text_annotations {
#   description: "neighborhood"
#   bounding_poly {
#     vertices {
#       x: 399
#       y: 469
#     }
#     vertices {
#       x: 495
#       y: 472
#     }
#     vertices {
#       x: 494
#       y: 488
#     }
#     vertices {
#       x: 399
#       y: 485
#     }
#   }
# }
# text_annotations {
#   description: "gem"
#   bounding_poly {
#     vertices {
#       x: 499
#       y: 473
#     }
#     vertices {
#       x: 526
#       y: 474
#     }
#     vertices {
#       x: 526
#       y: 489
#     }
#     vertices {
#       x: 499
#       y: 488
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 525
#       y: 474
#     }
#     vertices {
#       x: 530
#       y: 474
#     }
#     vertices {
#       x: 530
#       y: 489
#     }
#     vertices {
#       x: 525
#       y: 489
#     }
#   }
# }
# text_annotations {
#   description: "and"
#   bounding_poly {
#     vertices {
#       x: 531
#       y: 474
#     }
#     vertices {
#       x: 557
#       y: 475
#     }
#     vertices {
#       x: 557
#       y: 490
#     }
#     vertices {
#       x: 531
#       y: 489
#     }
#   }
# }
# text_annotations {
#   description: "know"
#   bounding_poly {
#     vertices {
#       x: 187
#       y: 481
#     }
#     vertices {
#       x: 228
#       y: 482
#     }
#     vertices {
#       x: 228
#       y: 495
#     }
#     vertices {
#       x: 187
#       y: 494
#     }
#   }
# }
# text_annotations {
#   description: "that"
#   bounding_poly {
#     vertices {
#       x: 232
#       y: 483
#     }
#     vertices {
#       x: 262
#       y: 484
#     }
#     vertices {
#       x: 262
#       y: 496
#     }
#     vertices {
#       x: 232
#       y: 495
#     }
#   }
# }
# text_annotations {
#   description: "your"
#   bounding_poly {
#     vertices {
#       x: 267
#       y: 484
#     }
#     vertices {
#       x: 303
#       y: 485
#     }
#     vertices {
#       x: 303
#       y: 497
#     }
#     vertices {
#       x: 267
#       y: 496
#     }
#   }
# }
# text_annotations {
#   description: "support"
#   bounding_poly {
#     vertices {
#       x: 308
#       y: 485
#     }
#     vertices {
#       x: 364
#       y: 487
#     }
#     vertices {
#       x: 364
#       y: 500
#     }
#     vertices {
#       x: 308
#       y: 498
#     }
#   }
# }
# text_annotations {
#   description: "will"
#   bounding_poly {
#     vertices {
#       x: 369
#       y: 487
#     }
#     vertices {
#       x: 396
#       y: 488
#     }
#     vertices {
#       x: 396
#       y: 501
#     }
#     vertices {
#       x: 369
#       y: 500
#     }
#   }
# }
# text_annotations {
#   description: "help"
#   bounding_poly {
#     vertices {
#       x: 401
#       y: 488
#     }
#     vertices {
#       x: 433
#       y: 489
#     }
#     vertices {
#       x: 433
#       y: 502
#     }
#     vertices {
#       x: 401
#       y: 501
#     }
#   }
# }
# text_annotations {
#   description: "Neir\'s"
#   bounding_poly {
#     vertices {
#       x: 438
#       y: 489
#     }
#     vertices {
#       x: 478
#       y: 490
#     }
#     vertices {
#       x: 478
#       y: 503
#     }
#     vertices {
#       x: 438
#       y: 502
#     }
#   }
# }
# text_annotations {
#   description: "reach"
#   bounding_poly {
#     vertices {
#       x: 187
#       y: 497
#     }
#     vertices {
#       x: 227
#       y: 498
#     }
#     vertices {
#       x: 227
#       y: 511
#     }
#     vertices {
#       x: 187
#       y: 510
#     }
#   }
# }
# text_annotations {
#   description: "its"
#   bounding_poly {
#     vertices {
#       x: 232
#       y: 499
#     }
#     vertices {
#       x: 249
#       y: 500
#     }
#     vertices {
#       x: 249
#       y: 512
#     }
#     vertices {
#       x: 232
#       y: 511
#     }
#   }
# }
# text_annotations {
#   description: "200th"
#   bounding_poly {
#     vertices {
#       x: 252
#       y: 499
#     }
#     vertices {
#       x: 295
#       y: 500
#     }
#     vertices {
#       x: 295
#       y: 513
#     }
#     vertices {
#       x: 252
#       y: 512
#     }
#   }
# }
# text_annotations {
#   description: "Anniversary"
#   bounding_poly {
#     vertices {
#       x: 297
#       y: 501
#     }
#     vertices {
#       x: 384
#       y: 504
#     }
#     vertices {
#       x: 383
#       y: 517
#     }
#     vertices {
#       x: 297
#       y: 514
#     }
#   }
# }
# text_annotations {
#   description: "in"
#   bounding_poly {
#     vertices {
#       x: 387
#       y: 504
#     }
#     vertices {
#       x: 401
#       y: 504
#     }
#     vertices {
#       x: 401
#       y: 517
#     }
#     vertices {
#       x: 387
#       y: 517
#     }
#   }
# }
# text_annotations {
#   description: "2029"
#   bounding_poly {
#     vertices {
#       x: 404
#       y: 505
#     }
#     vertices {
#       x: 436
#       y: 506
#     }
#     vertices {
#       x: 436
#       y: 518
#     }
#     vertices {
#       x: 404
#       y: 517
#     }
#   }
# }
# text_annotations {
#   description: "!"
#   bounding_poly {
#     vertices {
#       x: 436
#       y: 506
#     }
#     vertices {
#       x: 442
#       y: 506
#     }
#     vertices {
#       x: 442
#       y: 518
#     }
#     vertices {
#       x: 436
#       y: 518
#     }
#   }
# }
# text_annotations {
#   description: "SCAN"
#   bounding_poly {
#     vertices {
#       x: 187
#       y: 538
#     }
#     vertices {
#       x: 219
#       y: 539
#     }
#     vertices {
#       x: 219
#       y: 554
#     }
#     vertices {
#       x: 187
#       y: 553
#     }
#   }
# }
# text_annotations {
#   description: "TO"
#   bounding_poly {
#     vertices {
#       x: 227
#       y: 540
#     }
#     vertices {
#       x: 241
#       y: 540
#     }
#     vertices {
#       x: 241
#       y: 554
#     }
#     vertices {
#       x: 227
#       y: 554
#     }
#   }
# }
# text_annotations {
#   description: "READ"
#   bounding_poly {
#     vertices {
#       x: 248
#       y: 540
#     }
#     vertices {
#       x: 281
#       y: 541
#     }
#     vertices {
#       x: 281
#       y: 555
#     }
#     vertices {
#       x: 248
#       y: 554
#     }
#   }
# }
# text_annotations {
#   description: "THE"
#   bounding_poly {
#     vertices {
#       x: 288
#       y: 541
#     }
#     vertices {
#       x: 310
#       y: 542
#     }
#     vertices {
#       x: 310
#       y: 556
#     }
#     vertices {
#       x: 288
#       y: 555
#     }
#   }
# }
# text_annotations {
#   description: "TAVERN\'S"
#   bounding_poly {
#     vertices {
#       x: 316
#       y: 541
#     }
#     vertices {
#       x: 375
#       y: 542
#     }
#     vertices {
#       x: 375
#       y: 557
#     }
#     vertices {
#       x: 316
#       y: 556
#     }
#   }
# }
# text_annotations {
#   description: "FULL"
#   bounding_poly {
#     vertices {
#       x: 380
#       y: 543
#     }
#     vertices {
#       x: 409
#       y: 544
#     }
#     vertices {
#       x: 409
#       y: 559
#     }
#     vertices {
#       x: 380
#       y: 558
#     }
#   }
# }
# text_annotations {
#   description: "HISTORY"
#   bounding_poly {
#     vertices {
#       x: 416
#       y: 544
#     }
#     vertices {
#       x: 463
#       y: 545
#     }
#     vertices {
#       x: 463
#       y: 560
#     }
#     vertices {
#       x: 416
#       y: 559
#     }
#   }
# }
# text_annotations {
#   description: "-"
#   bounding_poly {
#     vertices {
#       x: 468
#       y: 546
#     }
#     vertices {
#       x: 480
#       y: 546
#     }
#     vertices {
#       x: 480
#       y: 560
#     }
#     vertices {
#       x: 468
#       y: 560
#     }
#   }
# }
# text_annotations {
#   description: ">"
#   bounding_poly {
#     vertices {
#       x: 467
#       y: 546
#     }
#     vertices {
#       x: 482
#       y: 546
#     }
#     vertices {
#       x: 482
#       y: 560
#     }
#     vertices {
#       x: 467
#       y: 560
#     }
#   }
# }
# text_annotations {
#   description: "BOWLING"
#   bounding_poly {
#     vertices {
#       x: 756
#       y: 348
#     }
#     vertices {
#       x: 807
#       y: 343
#     }
#     vertices {
#       x: 808
#       y: 353
#     }
#     vertices {
#       x: 757
#       y: 358
#     }
#   }
# }
# text_annotations {
#   description: "JOS"
#   bounding_poly {
#     vertices {
#       x: 644
#       y: 368
#     }
#     vertices {
#       x: 668
#       y: 367
#     }
#     vertices {
#       x: 669
#       y: 380
#     }
#     vertices {
#       x: 645
#       y: 381
#     }
#   }
# }
# text_annotations {
#   description: "EPPIC\'S"
#   bounding_poly {
#     vertices {
#       x: 677
#       y: 366
#     }
#     vertices {
#       x: 738
#       y: 363
#     }
#     vertices {
#       x: 739
#       y: 376
#     }
#     vertices {
#       x: 678
#       y: 379
#     }
#   }
# }
# text_annotations {
#   description: "BEER"
#   bounding_poly {
#     vertices {
#       x: 748
#       y: 363
#     }
#     vertices {
#       x: 798
#       y: 361
#     }
#     vertices {
#       x: 799
#       y: 374
#     }
#     vertices {
#       x: 749
#       y: 376
#     }
#   }
# }
# text_annotations {
#   description: "SPECIALTY"
#   bounding_poly {
#     vertices {
#       x: 185
#       y: 606
#     }
#     vertices {
#       x: 520
#       y: 608
#     }
#     vertices {
#       x: 520
#       y: 681
#     }
#     vertices {
#       x: 185
#       y: 679
#     }
#   }
# }
# text_annotations {
#   description: "&"
#   bounding_poly {
#     vertices {
#       x: 177
#       y: 698
#     }
#     vertices {
#       x: 202
#       y: 698
#     }
#     vertices {
#       x: 202
#       y: 710
#     }
#     vertices {
#       x: 177
#       y: 710
#     }
#   }
# }
# text_annotations {
#   description: "COCKTAILS"
#   bounding_poly {
#     vertices {
#       x: 225
#       y: 667
#     }
#     vertices {
#       x: 485
#       y: 667
#     }
#     vertices {
#       x: 485
#       y: 709
#     }
#     vertices {
#       x: 225
#       y: 709
#     }
#   }
# }
# text_annotations {
#   description: "C3"
#   bounding_poly {
#     vertices {
#       x: 498
#       y: 697
#     }
#     vertices {
#       x: 527
#       y: 698
#     }
#     vertices {
#       x: 527
#       y: 710
#     }
#     vertices {
#       x: 498
#       y: 709
#     }
#   }
# }
# text_annotations {
#   description: "NEIR\'S"
#   bounding_poly {
#     vertices {
#       x: 675
#       y: 620
#     }
#     vertices {
#       x: 749
#       y: 620
#     }
#     vertices {
#       x: 749
#       y: 641
#     }
#     vertices {
#       x: 675
#       y: 641
#     }
#   }
# }
# text_annotations {
#   description: "Signature"
#   bounding_poly {
#     vertices {
#       x: 754
#       y: 620
#     }
#     vertices {
#       x: 848
#       y: 620
#     }
#     vertices {
#       x: 848
#       y: 641
#     }
#     vertices {
#       x: 754
#       y: 641
#     }
#   }
# }
# text_annotations {
#   description: "Cocktail"
#   bounding_poly {
#     vertices {
#       x: 856
#       y: 620
#     }
#     vertices {
#       x: 936
#       y: 620
#     }
#     vertices {
#       x: 936
#       y: 641
#     }
#     vertices {
#       x: 856
#       y: 641
#     }
#   }
# }
# text_annotations {
#   description: "THE"
#   bounding_poly {
#     vertices {
#       x: 677
#       y: 641
#     }
#     vertices {
#       x: 735
#       y: 642
#     }
#     vertices {
#       x: 734
#       y: 673
#     }
#     vertices {
#       x: 676
#       y: 672
#     }
#   }
# }
# text_annotations {
#   description: "WISE"
#   bounding_poly {
#     vertices {
#       x: 743
#       y: 643
#     }
#     vertices {
#       x: 825
#       y: 645
#     }
#     vertices {
#       x: 824
#       y: 676
#     }
#     vertices {
#       x: 742
#       y: 674
#     }
#   }
# }
# text_annotations {
#   description: "GUY"
#   bounding_poly {
#     vertices {
#       x: 835
#       y: 645
#     }
#     vertices {
#       x: 895
#       y: 646
#     }
#     vertices {
#       x: 894
#       y: 677
#     }
#     vertices {
#       x: 834
#       y: 676
#     }
#   }
# }
# text_annotations {
#   description: "12"
#   bounding_poly {
#     vertices {
#       x: 902
#       y: 662
#     }
#     vertices {
#       x: 914
#       y: 662
#     }
#     vertices {
#       x: 914
#       y: 671
#     }
#     vertices {
#       x: 902
#       y: 671
#     }
#   }
# }
# text_annotations {
#   description: "Uncle"
#   bounding_poly {
#     vertices {
#       x: 675
#       y: 682
#     }
#     vertices {
#       x: 711
#       y: 682
#     }
#     vertices {
#       x: 711
#       y: 693
#     }
#     vertices {
#       x: 675
#       y: 693
#     }
#   }
# }
# text_annotations {
#   description: "Nearest"
#   bounding_poly {
#     vertices {
#       x: 713
#       y: 682
#     }
#     vertices {
#       x: 761
#       y: 682
#     }
#     vertices {
#       x: 761
#       y: 693
#     }
#     vertices {
#       x: 713
#       y: 693
#     }
#   }
# }
# text_annotations {
#   description: "Whiskey"
#   bounding_poly {
#     vertices {
#       x: 763
#       y: 682
#     }
#     vertices {
#       x: 816
#       y: 682
#     }
#     vertices {
#       x: 816
#       y: 693
#     }
#     vertices {
#       x: 763
#       y: 693
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 815
#       y: 682
#     }
#     vertices {
#       x: 819
#       y: 682
#     }
#     vertices {
#       x: 819
#       y: 693
#     }
#     vertices {
#       x: 815
#       y: 693
#     }
#   }
# }
# text_annotations {
#   description: "Sweet"
#   bounding_poly {
#     vertices {
#       x: 821
#       y: 682
#     }
#     vertices {
#       x: 857
#       y: 682
#     }
#     vertices {
#       x: 857
#       y: 693
#     }
#     vertices {
#       x: 821
#       y: 693
#     }
#   }
# }
# text_annotations {
#   description: "Vermouth"
#   bounding_poly {
#     vertices {
#       x: 859
#       y: 682
#     }
#     vertices {
#       x: 918
#       y: 682
#     }
#     vertices {
#       x: 918
#       y: 693
#     }
#     vertices {
#       x: 859
#       y: 693
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 918
#       y: 682
#     }
#     vertices {
#       x: 922
#       y: 682
#     }
#     vertices {
#       x: 922
#       y: 693
#     }
#     vertices {
#       x: 918
#       y: 693
#     }
#   }
# }
# text_annotations {
#   description: "Amaretto"
#   bounding_poly {
#     vertices {
#       x: 675
#       y: 697
#     }
#     vertices {
#       x: 730
#       y: 696
#     }
#     vertices {
#       x: 730
#       y: 707
#     }
#     vertices {
#       x: 675
#       y: 708
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 731
#       y: 697
#     }
#     vertices {
#       x: 734
#       y: 697
#     }
#     vertices {
#       x: 734
#       y: 707
#     }
#     vertices {
#       x: 731
#       y: 707
#     }
#   }
# }
# ...
#                 y: 1251
#               }
#             }
#             text: "o"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 850
#                 y: 1240
#               }
#               vertices {
#                 x: 856
#                 y: 1239
#               }
#               vertices {
#                 x: 857
#                 y: 1250
#               }
#               vertices {
#                 x: 851
#                 y: 1251
#               }
#             }
#             text: "r"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 860
#               y: 1239
#             }
#             vertices {
#               x: 890
#               y: 1236
#             }
#             vertices {
#               x: 891
#               y: 1247
#             }
#             vertices {
#               x: 861
#               y: 1250
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 860
#                 y: 1239
#               }
#               vertices {
#                 x: 866
#                 y: 1238
#               }
#               vertices {
#                 x: 867
#                 y: 1249
#               }
#               vertices {
#                 x: 861
#                 y: 1250
#               }
#             }
#             text: "d"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 866
#                 y: 1238
#               }
#               vertices {
#                 x: 872
#                 y: 1237
#               }
#               vertices {
#                 x: 873
#                 y: 1248
#               }
#               vertices {
#                 x: 867
#                 y: 1249
#               }
#             }
#             text: "e"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 871
#                 y: 1238
#               }
#               vertices {
#                 x: 876
#                 y: 1238
#               }
#               vertices {
#                 x: 877
#                 y: 1249
#               }
#               vertices {
#                 x: 872
#                 y: 1249
#               }
#             }
#             text: "t"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 874
#                 y: 1238
#               }
#               vertices {
#                 x: 880
#                 y: 1237
#               }
#               vertices {
#                 x: 881
#                 y: 1248
#               }
#               vertices {
#                 x: 875
#                 y: 1249
#               }
#             }
#             text: "a"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 879
#                 y: 1237
#               }
#               vertices {
#                 x: 884
#                 y: 1237
#               }
#               vertices {
#                 x: 885
#                 y: 1248
#               }
#               vertices {
#                 x: 880
#                 y: 1248
#               }
#             }
#             text: "i"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 883
#                 y: 1237
#               }
#               vertices {
#                 x: 887
#                 y: 1237
#               }
#               vertices {
#                 x: 888
#                 y: 1248
#               }
#               vertices {
#                 x: 884
#                 y: 1248
#               }
#             }
#             text: "l"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 885
#                 y: 1237
#               }
#               vertices {
#                 x: 890
#                 y: 1237
#               }
#               vertices {
#                 x: 891
#                 y: 1248
#               }
#               vertices {
#                 x: 886
#                 y: 1248
#               }
#             }
#             text: "s"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#     blocks {
#       bounding_box {
#         vertices {
#           x: 747
#           y: 1280
#         }
#         vertices {
#           x: 919
#           y: 1265
#         }
#         vertices {
#           x: 920
#           y: 1277
#         }
#         vertices {
#           x: 748
#           y: 1292
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 747
#             y: 1280
#           }
#           vertices {
#             x: 919
#             y: 1265
#           }
#           vertices {
#             x: 920
#             y: 1277
#           }
#           vertices {
#             x: 748
#             y: 1292
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "pt"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 747
#               y: 1280
#             }
#             vertices {
#               x: 867
#               y: 1269
#             }
#             vertices {
#               x: 868
#               y: 1281
#             }
#             vertices {
#               x: 748
#               y: 1292
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 747
#                 y: 1281
#               }
#               vertices {
#                 x: 756
#                 y: 1280
#               }
#               vertices {
#                 x: 757
#                 y: 1291
#               }
#               vertices {
#                 x: 748
#                 y: 1292
#               }
#             }
#             text: "N"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 756
#                 y: 1280
#               }
#               vertices {
#                 x: 763
#                 y: 1279
#               }
#               vertices {
#                 x: 764
#                 y: 1290
#               }
#               vertices {
#                 x: 757
#                 y: 1291
#               }
#             }
#             text: "E"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 764
#                 y: 1279
#               }
#               vertices {
#                 x: 768
#                 y: 1279
#               }
#               vertices {
#                 x: 769
#                 y: 1290
#               }
#               vertices {
#                 x: 765
#                 y: 1290
#               }
#             }
#             text: "I"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 769
#                 y: 1278
#               }
#               vertices {
#                 x: 777
#                 y: 1277
#               }
#               vertices {
#                 x: 778
#                 y: 1288
#               }
#               vertices {
#                 x: 770
#                 y: 1289
#               }
#             }
#             text: "R"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 777
#                 y: 1278
#               }
#               vertices {
#                 x: 784
#                 y: 1277
#               }
#               vertices {
#                 x: 785
#                 y: 1288
#               }
#               vertices {
#                 x: 778
#                 y: 1289
#               }
#             }
#             text: "S"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 785
#                 y: 1277
#               }
#               vertices {
#                 x: 792
#                 y: 1276
#               }
#               vertices {
#                 x: 793
#                 y: 1287
#               }
#               vertices {
#                 x: 786
#                 y: 1288
#               }
#             }
#             text: "T"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 793
#                 y: 1276
#               }
#               vertices {
#                 x: 802
#                 y: 1275
#               }
#               vertices {
#                 x: 803
#                 y: 1286
#               }
#               vertices {
#                 x: 794
#                 y: 1287
#               }
#             }
#             text: "A"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 801
#                 y: 1276
#               }
#               vertices {
#                 x: 809
#                 y: 1275
#               }
#               vertices {
#                 x: 810
#                 y: 1286
#               }
#               vertices {
#                 x: 802
#                 y: 1287
#               }
#             }
#             text: "V"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 810
#                 y: 1275
#               }
#               vertices {
#                 x: 817
#                 y: 1274
#               }
#               vertices {
#                 x: 818
#                 y: 1285
#               }
#               vertices {
#                 x: 811
#                 y: 1286
#               }
#             }
#             text: "E"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 818
#                 y: 1274
#               }
#               vertices {
#                 x: 825
#                 y: 1273
#               }
#               vertices {
#                 x: 826
#                 y: 1284
#               }
#               vertices {
#                 x: 819
#                 y: 1285
#               }
#             }
#             text: "R"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 825
#                 y: 1274
#               }
#               vertices {
#                 x: 835
#                 y: 1273
#               }
#               vertices {
#                 x: 836
#                 y: 1284
#               }
#               vertices {
#                 x: 826
#                 y: 1285
#               }
#             }
#             text: "N"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 833
#                 y: 1273
#               }
#               vertices {
#                 x: 838
#                 y: 1273
#               }
#               vertices {
#                 x: 839
#                 y: 1284
#               }
#               vertices {
#                 x: 834
#                 y: 1284
#               }
#             }
#             text: "."
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 839
#                 y: 1272
#               }
#               vertices {
#                 x: 848
#                 y: 1271
#               }
#               vertices {
#                 x: 849
#                 y: 1282
#               }
#               vertices {
#                 x: 840
#                 y: 1283
#               }
#             }
#             text: "C"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 846
#                 y: 1272
#               }
#               vertices {
#                 x: 856
#                 y: 1271
#               }
#               vertices {
#                 x: 857
#                 y: 1282
#               }
#               vertices {
#                 x: 847
#                 y: 1283
#               }
#             }
#             text: "O"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 855
#                 y: 1271
#               }
#               vertices {
#                 x: 867
#                 y: 1270
#               }
#               vertices {
#                 x: 868
#                 y: 1281
#               }
#               vertices {
#                 x: 856
#                 y: 1282
#               }
#             }
#             text: "M"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "pt"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 906
#               y: 1266
#             }
#             vertices {
#               x: 919
#               y: 1265
#             }
#             vertices {
#               x: 920
#               y: 1276
#             }
#             vertices {
#               x: 907
#               y: 1277
#             }
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 906
#                 y: 1266
#               }
#               vertices {
#                 x: 919
#                 y: 1265
#               }
#               vertices {
#                 x: 920
#                 y: 1276
#               }
#               vertices {
#                 x: 907
#                 y: 1277
#               }
#             }
#             text: "O"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#   }
#   text: "NEIR\'S\nTAVERN\nEST. 1829\nA TRUE HISTORIC GEM OF NEW YORK CITY\nServing the Coldest Beer in Town for Nearly Two Centuries!\na\nstablished in 1829, Neir\'s Tavern retains much\nmahogany bar and rare stainless steel coil system that\nstill uses ice to serve the coldest beer in town.\nFamed for being one of the oldest bars in New York,\nit\'s the place where many of the iconic scenes were\nfilmed for the classic movie, \"Goodfellas\". Neir\'s was\nalso used for other films such as \"Tower Heist\", and it\nis the bar where Mae West first performed.\nNow known for its excellent food and drinks, we hope\nyou will enjoy your visit to our neighborhood gem, and\nknow that your support will help Neir\'s\nreach its 200th Anniversary in 2029!\nSCAN TO READ THE TAVERN\'S FULL HISTORY ->\nBOWLING\nJOS EPPIC\'S BEER\nSPECIALTY\n&\nCOCKTAILS\nC3\nNEIR\'S Signature Cocktail\nTHE WISE GUY\n12\nUncle Nearest Whiskey, Sweet Vermouth,\nAmaretto, Dash of Bitters\nNEIR\'S OLD FASHIONED 12\nHistoric Old Fashion Cocktail from 1895\nMAE WEST PUNCH 10\nWhiskey, Rum, Lemon & Pineapple Juice\nwith Ginger Ale\nNEIR\'S WHISKEY MULE 10\nWhiskey, Ginger beer, Lime Juice\nCLASSIC WHISKEY SOUR 10\nWhisky, Lemon juice, Simple Syrup\nWHISKEY CHERRY COKE 10\nWhiskey, Grenadine, Coke\nNEIR\'S Specialty\nHAYMAKER\'S PUNCH 12\nDRAFT\nAsk About Our\nMAI-TAI 10\nSpiced Rum, Coconut Rum,\nGrenadine, Pineapple Juice\nBLUE HAWAIIAN 10\nCoconut Rum, White Rum,\nPineapple Juice, Blue Curacao\nVODKA SUNRISE 10\nVodka, Orange Juice & Grenadine\nCOSMOPOLITAN 10\nVodka, Cranberry, Cointreau,\nLime Juice\n\"BEERS OF THE MONTH\"\nAlways On Tap\nGUINNESS 7\nSTELLA 6\nBLUE MOON 6\nFINBACK IPA 8\nLONG ISLAND ICED TEA 12\nVodka, Rum, Gin, Tequila, Triple Sec,\nSour Mix & Splash of Coke\nSIDECAR 12\nCognac, Orange Liqueur,\nFresh Squeezed Lemon Juice\nwith an Orange Twist\nMARGARITA 10\n(CLASSIC, MANGO, STRAWBERRY\nOR PASSION FRUIT)\nTequila, Triple Sec, Lime Juice,\nSour Mix\nThe preferred beverage of early American farmers. Neir\'s\ncombines this centuries-old recipe with a dark Jamaican rum,\nin honor of our owner\'s heritage, for a refreshing cocktail.\nVIRGIN VERSION 10\nBOTTLED Happy\nBUDWEISER 5\nBUD LIGHT 5\nCORONA 6\nCOORS LIGHT 5\nHEINEKEN 6\nHEINEKEN LIGHT 6\nMODELO 6\nMICHELOB ULTRA 5\nO\'DOULS N/A 6\nHour\nMONDAY - FRIDAY 2-7 PM\n$1 OFF ALL DRAFT BEER\n$5 SELECT APPS\nask server for details\nNEIRSTAVERN.COM O"
# }

# %%
res
# Out:
# MenuData(sections=[])
