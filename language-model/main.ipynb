# %% [markdown]
# ## Setup

# %%
import requests
import base64
from common.custom_types import ImageData
from typing import Tuple, Optional


def fetch_image_as_base64(url: str) -> Optional[Tuple[bytes, str]]:
    """
    Fetches an image from a URL and returns its base64 content and MIME type.

    This function sends a GET request to the provided URL, retrieves the image
    content, and encodes it into a base64 string. It also extracts the
    'Content-Type' header to determine the image's MIME type.

    Args:
        url: The URL of the image to fetch.

    Returns:
        A tuple containing the base64-encoded string of the image and its
        MIME type (e.g., 'image/jpeg').
        Returns None if the request fails, the URL is invalid, or the
        content is not an image.
    """
    # Make the HTTP request to get the image.
    # Set a timeout to avoid hanging indefinitely.
    response = requests.get(url, stream=True, timeout=10)

    # Raise an exception for bad status codes (4xx or 5xx).
    response.raise_for_status()

    # Check the Content-Type header to ensure it's an image.
    mime_type = response.headers.get("Content-Type")
    if not mime_type or not mime_type.startswith("image/"):
        print(f"Warning: URL does not point to an image. MIME type: {mime_type}")
        return None

    # Get the raw binary content of the image.
    image_bytes = response.content

    # Encode the bytes into a base64 string.
    base64_content = base64.b64encode(image_bytes).decode('utf-8')

    return (base64_content, mime_type)

# %% [markdown]
# ## Initial Testing

# %%
# dummy_uri = "https://lh3.googleusercontent.com/gps-cs-s/AC9h4nolu0ktuCp6Iv2xYf862rZitPbloquBOiu53uSwa16PBf8QvFpHicv9KG9oLv1ToCzh7EnQcIQoL7RCYwkx2El97LO3V_TQ8qa4LMz7UtVUU-Tk1qW2lHB8G6bl0yULK2QruLX-hw=w1080"
# dummy_uri = "https://lh3.googleusercontent.com/gps-cs-s/AC9h4no1uCHfrVSWZ8wF0xORLVeQqBL9-7Nlw0JmTQzMsV17MKHXAXM_58i-P8OMqc_-4ZZyDe8xD5pIYSXiReG0OKZkwLJ4l7_zK-yBTTrAaaMW1Qz5cu0In2Kr-MlgfZu-3XteZafF=w1080"
# dummy_uri = "https://lh3.googleusercontent.com/gps-cs-s/AC9h4nptYsYx_z-xeV4_tOC7K7-WK8QVgHFvXaJq0LOlAE4NeMzzcZ-nQa41Ce_LfaUot4CVF6QhA5bEPLzJv8cakoXeHV9yNYn2jgfEHX3cfpBXGaa7CmCJHfbzd-PG7YCmjMBv5cnkGg=w1080"
dummy_uri = "https://lh3.googleusercontent.com/gps-cs-s/AC9h4nrcNsZt5FksLGx03CtA87lhNsHZVkyXm2xpmnBNtxlM1KrmlQivVfEuiUFzhK_rPG0ycmGjZdFUtFCvyvj4gIa7XXGXC6qMe7VwdVwmQjUz02erXFUpZeqbNkctBfEfRtd9k_h2=w1080"

bb, mime = fetch_image_as_base64(dummy_uri)
dummy_img = ImageData(base64=bb, mime_type=mime)
dummy_img

# %%
from menu_reader import read_menu

res = await read_menu(dummy_img)
# Out:
# text_annotations {
#   locale: "en"
#   description: "croffles\ncraffle (noun)\ncantades stuter,\nforest cafe menu\na hybrid mix of a croissant and affla\nteat, milk, soy may contain eye ata, sesame\nplain 4\nsogar glaze\nforest cafe menu\nsignature drink\nFOREST\nespresso\nLATTE\norganic maple syrup cinnamon milk\nour signature flavor\ncoffee & specialty drinks\nve ceston roast our own (arabical beans\nbrewed coffee-selise roast; notes of chocolate, almond, cherry\nexpress medios to dark roast; notes of cinnamon & brown sagar\ndecaf espresso medium to dark roast; notes of caramel\nbrewed coffee\ncold brew\nespresso\namericano\nmacchiato (traditional)\ncortado\ncappuccino\nflat white\nlatte\nmocha latte\nlavender latte\nvanilla latte\nube latte (purple yan)\nbeing and\nHOT\nICED\n6.00\n6.50\ntry foresting\nyour drink\n+1.25\n3.25\n4.75\n3.25\n3.75\n3.56\n4.08\n3.75\n4.25\n4.75\n4.15\n4.75\n5.50\n5.75\n6.25\n5.75\n6.25\n5.75\n6.25\n5.75\n6.25\n?\n6.25\n5.75\n6.25\n7.25\n7.75\ngrab\nsalted caramel latte\niced shakerato (shaken espresso over milk)\ndirty be latte (+ espresso)\nmatcha & hojicha\nespresso alternatives.\nnatcha\najic\norganic ceremonial grade graasd green tea leaves contains caffeine\norganic roasted green tea leaves; contains very\ncaffeine\npairs well with expresse, forested, or bath\nmatcha / hojicha latte (with milk)\nmatcha/hojicha americano (with water)\nLavender natcha / hojicha Latte\nlavender netcha/hajscha americano\nearth elixir\n5.35\n6.25\n5.25\n5.75\n6.50\n7.88\n6.00\n6.50\n6.30\n6.50\nother\nbabyccino (4 oz steaned milk)\n2.20\nhot chocolate\n4.75\nheeesade iced tea (sweetened black tea)\n4.00\nlondon fog rearl grey tea teased asik vanilla & leverder me\nhot teas\n5.08\n3.75\nnutella 6\ntopped with rice crispies\nseasonal croffle.\nask us about itf\n-n-go\ngochujang tamago sando 9.75\negs, ret pepper pete, kople mayonnaise, sugar, peppermi\nforest overnight oats 6.75\nset ala, eta, erganic ates, organic ate ne\nmatcha chia seed pudding 6.25\ncoconut milk, or this sek, organ winch, featuring seas an\nvegan and guten We contac\nprotein power bites 5.751\nvegan and gluten free contain\nmerch\nforest cafe tote bag 35\nwah friendly, y\n(berley, breakfast blend, chaalle lemon, earl grey, green, Jenice)\nкутер/sauce options\ncaffeine fr\nice option\nmilk options\nwole ar ski\nforest\n3.25\nA\n-\ndary asks\norganic sapte syne\nlander sn\nhow iced tea & cel\n9.75\n-9.75\nsc\ndark chocalate\n-8.75\ntra double st"
#   bounding_poly {
#     vertices {
#       x: 142
#       y: 36
#     }
#     vertices {
#       x: 806
#       y: 36
#     }
#     vertices {
#       x: 806
#       y: 572
#     }
#     vertices {
#       x: 142
#       y: 572
#     }
#   }
# }
# text_annotations {
#   description: "croffles"
#   bounding_poly {
#     vertices {
#       x: 559
#       y: 106
#     }
#     vertices {
#       x: 601
#       y: 106
#     }
#     vertices {
#       x: 601
#       y: 122
#     }
#     vertices {
#       x: 559
#       y: 122
#     }
#   }
# }
# text_annotations {
#   description: "craffle"
#   bounding_poly {
#     vertices {
#       x: 557
#       y: 131
#     }
#     vertices {
#       x: 582
#       y: 132
#     }
#     vertices {
#       x: 582
#       y: 138
#     }
#     vertices {
#       x: 557
#       y: 137
#     }
#   }
# }
# text_annotations {
#   description: "("
#   bounding_poly {
#     vertices {
#       x: 584
#       y: 131
#     }
#     vertices {
#       x: 587
#       y: 131
#     }
#     vertices {
#       x: 587
#       y: 137
#     }
#     vertices {
#       x: 584
#       y: 137
#     }
#   }
# }
# text_annotations {
#   description: "noun"
#   bounding_poly {
#     vertices {
#       x: 587
#       y: 131
#     }
#     vertices {
#       x: 601
#       y: 131
#     }
#     vertices {
#       x: 601
#       y: 137
#     }
#     vertices {
#       x: 587
#       y: 137
#     }
#   }
# }
# text_annotations {
#   description: ")"
#   bounding_poly {
#     vertices {
#       x: 600
#       y: 132
#     }
#     vertices {
#       x: 603
#       y: 132
#     }
#     vertices {
#       x: 603
#       y: 138
#     }
#     vertices {
#       x: 600
#       y: 138
#     }
#   }
# }
# text_annotations {
#   description: "cantades"
#   bounding_poly {
#     vertices {
#       x: 563
#       y: 139
#     }
#     vertices {
#       x: 588
#       y: 140
#     }
#     vertices {
#       x: 588
#       y: 148
#     }
#     vertices {
#       x: 563
#       y: 147
#     }
#   }
# }
# text_annotations {
#   description: "stuter"
#   bounding_poly {
#     vertices {
#       x: 590
#       y: 140
#     }
#     vertices {
#       x: 609
#       y: 141
#     }
#     vertices {
#       x: 609
#       y: 149
#     }
#     vertices {
#       x: 590
#       y: 148
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 608
#       y: 141
#     }
#     vertices {
#       x: 610
#       y: 141
#     }
#     vertices {
#       x: 610
#       y: 148
#     }
#     vertices {
#       x: 608
#       y: 148
#     }
#   }
# }
# text_annotations {
#   description: "forest"
#   bounding_poly {
#     vertices {
#       x: 613
#       y: 54
#     }
#     vertices {
#       x: 695
#       y: 59
#     }
#     vertices {
#       x: 693
#       y: 90
#     }
#     vertices {
#       x: 611
#       y: 85
#     }
#   }
# }
# text_annotations {
#   description: "cafe"
#   bounding_poly {
#     vertices {
#       x: 689
#       y: 58
#     }
#     vertices {
#       x: 743
#       y: 61
#     }
#     vertices {
#       x: 741
#       y: 92
#     }
#     vertices {
#       x: 687
#       y: 89
#     }
#   }
# }
# text_annotations {
#   description: "menu"
#   bounding_poly {
#     vertices {
#       x: 741
#       y: 61
#     }
#     vertices {
#       x: 806
#       y: 65
#     }
#     vertices {
#       x: 804
#       y: 96
#     }
#     vertices {
#       x: 739
#       y: 92
#     }
#   }
# }
# text_annotations {
#   description: "a"
#   bounding_poly {
#     vertices {
#       x: 613
#       y: 132
#     }
#     vertices {
#       x: 617
#       y: 132
#     }
#     vertices {
#       x: 617
#       y: 138
#     }
#     vertices {
#       x: 613
#       y: 138
#     }
#   }
# }
# text_annotations {
#   description: "hybrid"
#   bounding_poly {
#     vertices {
#       x: 620
#       y: 132
#     }
#     vertices {
#       x: 641
#       y: 133
#     }
#     vertices {
#       x: 641
#       y: 139
#     }
#     vertices {
#       x: 620
#       y: 138
#     }
#   }
# }
# text_annotations {
#   description: "mix"
#   bounding_poly {
#     vertices {
#       x: 643
#       y: 133
#     }
#     vertices {
#       x: 655
#       y: 133
#     }
#     vertices {
#       x: 655
#       y: 139
#     }
#     vertices {
#       x: 643
#       y: 139
#     }
#   }
# }
# text_annotations {
#   description: "of"
#   bounding_poly {
#     vertices {
#       x: 657
#       y: 133
#     }
#     vertices {
#       x: 665
#       y: 133
#     }
#     vertices {
#       x: 665
#       y: 139
#     }
#     vertices {
#       x: 657
#       y: 139
#     }
#   }
# }
# text_annotations {
#   description: "a"
#   bounding_poly {
#     vertices {
#       x: 666
#       y: 133
#     }
#     vertices {
#       x: 670
#       y: 133
#     }
#     vertices {
#       x: 670
#       y: 139
#     }
#     vertices {
#       x: 666
#       y: 139
#     }
#   }
# }
# text_annotations {
#   description: "croissant"
#   bounding_poly {
#     vertices {
#       x: 673
#       y: 133
#     }
#     vertices {
#       x: 702
#       y: 134
#     }
#     vertices {
#       x: 702
#       y: 141
#     }
#     vertices {
#       x: 673
#       y: 140
#     }
#   }
# }
# text_annotations {
#   description: "and"
#   bounding_poly {
#     vertices {
#       x: 706
#       y: 134
#     }
#     vertices {
#       x: 716
#       y: 134
#     }
#     vertices {
#       x: 716
#       y: 140
#     }
#     vertices {
#       x: 706
#       y: 140
#     }
#   }
# }
# text_annotations {
#   description: "affla"
#   bounding_poly {
#     vertices {
#       x: 721
#       y: 134
#     }
#     vertices {
#       x: 738
#       y: 134
#     }
#     vertices {
#       x: 738
#       y: 141
#     }
#     vertices {
#       x: 721
#       y: 141
#     }
#   }
# }
# text_annotations {
#   description: "teat"
#   bounding_poly {
#     vertices {
#       x: 617
#       y: 141
#     }
#     vertices {
#       x: 629
#       y: 141
#     }
#     vertices {
#       x: 629
#       y: 148
#     }
#     vertices {
#       x: 617
#       y: 148
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 629
#       y: 141
#     }
#     vertices {
#       x: 631
#       y: 141
#     }
#     vertices {
#       x: 631
#       y: 148
#     }
#     vertices {
#       x: 629
#       y: 148
#     }
#   }
# }
# text_annotations {
#   description: "milk"
#   bounding_poly {
#     vertices {
#       x: 634
#       y: 141
#     }
#     vertices {
#       x: 646
#       y: 141
#     }
#     vertices {
#       x: 646
#       y: 149
#     }
#     vertices {
#       x: 634
#       y: 149
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 647
#       y: 142
#     }
#     vertices {
#       x: 649
#       y: 142
#     }
#     vertices {
#       x: 649
#       y: 149
#     }
#     vertices {
#       x: 647
#       y: 149
#     }
#   }
# }
# text_annotations {
#   description: "soy"
#   bounding_poly {
#     vertices {
#       x: 652
#       y: 142
#     }
#     vertices {
#       x: 663
#       y: 142
#     }
#     vertices {
#       x: 663
#       y: 149
#     }
#     vertices {
#       x: 652
#       y: 149
#     }
#   }
# }
# text_annotations {
#   description: "may"
#   bounding_poly {
#     vertices {
#       x: 670
#       y: 142
#     }
#     vertices {
#       x: 679
#       y: 142
#     }
#     vertices {
#       x: 679
#       y: 150
#     }
#     vertices {
#       x: 670
#       y: 150
#     }
#   }
# }
# text_annotations {
#   description: "contain"
#   bounding_poly {
#     vertices {
#       x: 682
#       y: 142
#     }
#     vertices {
#       x: 703
#       y: 143
#     }
#     vertices {
#       x: 703
#       y: 151
#     }
#     vertices {
#       x: 682
#       y: 150
#     }
#   }
# }
# text_annotations {
#   description: "eye"
#   bounding_poly {
#     vertices {
#       x: 705
#       y: 143
#     }
#     vertices {
#       x: 731
#       y: 144
#     }
#     vertices {
#       x: 731
#       y: 152
#     }
#     vertices {
#       x: 705
#       y: 151
#     }
#   }
# }
# text_annotations {
#   description: "ata"
#   bounding_poly {
#     vertices {
#       x: 735
#       y: 144
#     }
#     vertices {
#       x: 745
#       y: 144
#     }
#     vertices {
#       x: 745
#       y: 151
#     }
#     vertices {
#       x: 735
#       y: 151
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 745
#       y: 145
#     }
#     vertices {
#       x: 747
#       y: 145
#     }
#     vertices {
#       x: 747
#       y: 152
#     }
#     vertices {
#       x: 745
#       y: 152
#     }
#   }
# }
# text_annotations {
#   description: "sesame"
#   bounding_poly {
#     vertices {
#       x: 750
#       y: 145
#     }
#     vertices {
#       x: 767
#       y: 145
#     }
#     vertices {
#       x: 767
#       y: 152
#     }
#     vertices {
#       x: 750
#       y: 152
#     }
#   }
# }
# text_annotations {
#   description: "plain"
#   bounding_poly {
#     vertices {
#       x: 648
#       y: 171
#     }
#     vertices {
#       x: 675
#       y: 171
#     }
#     vertices {
#       x: 675
#       y: 179
#     }
#     vertices {
#       x: 648
#       y: 179
#     }
#   }
# }
# text_annotations {
#   description: "4"
#   bounding_poly {
#     vertices {
#       x: 679
#       y: 171
#     }
#     vertices {
#       x: 685
#       y: 171
#     }
#     vertices {
#       x: 685
#       y: 179
#     }
#     vertices {
#       x: 679
#       y: 179
#     }
#   }
# }
# text_annotations {
#   description: "sogar"
#   bounding_poly {
#     vertices {
#       x: 647
#       y: 181
#     }
#     vertices {
#       x: 664
#       y: 181
#     }
#     vertices {
#       x: 664
#       y: 186
#     }
#     vertices {
#       x: 647
#       y: 186
#     }
#   }
# }
# text_annotations {
#   description: "glaze"
#   bounding_poly {
#     vertices {
#       x: 666
#       y: 181
#     }
#     vertices {
#       x: 685
#       y: 181
#     }
#     vertices {
#       x: 685
#       y: 186
#     }
#     vertices {
#       x: 666
#       y: 186
#     }
#   }
# }
# text_annotations {
#   description: "forest"
#   bounding_poly {
#     vertices {
#       x: 194
#       y: 36
#     }
#     vertices {
#       x: 282
#       y: 41
#     }
#     vertices {
#       x: 280
#       y: 73
#     }
#     vertices {
#       x: 192
#       y: 68
#     }
#   }
# }
# text_annotations {
#   description: "cafe"
#   bounding_poly {
#     vertices {
#       x: 276
#       y: 41
#     }
#     vertices {
#       x: 335
#       y: 44
#     }
#     vertices {
#       x: 333
#       y: 75
#     }
#     vertices {
#       x: 274
#       y: 72
#     }
#   }
# }
# text_annotations {
#   description: "menu"
#   bounding_poly {
#     vertices {
#       x: 336
#       y: 44
#     }
#     vertices {
#       x: 409
#       y: 48
#     }
#     vertices {
#       x: 407
#       y: 79
#     }
#     vertices {
#       x: 334
#       y: 75
#     }
#   }
# }
# text_annotations {
#   description: "signature"
#   bounding_poly {
#     vertices {
#       x: 142
#       y: 81
#     }
#     vertices {
#       x: 205
#       y: 80
#     }
#     vertices {
#       x: 205
#       y: 97
#     }
#     vertices {
#       x: 142
#       y: 98
#     }
#   }
# }
# text_annotations {
#   description: "drink"
#   bounding_poly {
#     vertices {
#       x: 206
#       y: 80
#     }
#     vertices {
#       x: 246
#       y: 79
#     }
#     vertices {
#       x: 246
#       y: 96
#     }
#     vertices {
#       x: 206
#       y: 97
#     }
#   }
# }
# text_annotations {
#   description: "FOREST"
#   bounding_poly {
#     vertices {
#       x: 144
#       y: 103
#     }
#     vertices {
#       x: 176
#       y: 104
#     }
#     vertices {
#       x: 176
#       y: 111
#     }
#     vertices {
#       x: 144
#       y: 110
#     }
#   }
# }
# text_annotations {
#   description: "espresso"
#   bounding_poly {
#     vertices {
#       x: 146
#       y: 116
#     }
#     vertices {
#       x: 175
#       y: 117
#     }
#     vertices {
#       x: 175
#       y: 123
#     }
#     vertices {
#       x: 146
#       y: 122
#     }
#   }
# }
# text_annotations {
#   description: "LATTE"
#   bounding_poly {
#     vertices {
#       x: 184
#       y: 104
#     }
#     vertices {
#       x: 211
#       y: 105
#     }
#     vertices {
#       x: 211
#       y: 112
#     }
#     vertices {
#       x: 184
#       y: 111
#     }
#   }
# }
# text_annotations {
#   description: "organic"
#   bounding_poly {
#     vertices {
#       x: 184
#       y: 116
#     }
#     vertices {
#       x: 209
#       y: 117
#     }
#     vertices {
#       x: 209
#       y: 124
#     }
#     vertices {
#       x: 184
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "maple"
#   bounding_poly {
#     vertices {
#       x: 210
#       y: 117
#     }
#     vertices {
#       x: 230
#       y: 117
#     }
#     vertices {
#       x: 230
#       y: 123
#     }
#     vertices {
#       x: 210
#       y: 123
#     }
#   }
# }
# text_annotations {
#   description: "syrup"
#   bounding_poly {
#     vertices {
#       x: 233
#       y: 117
#     }
#     vertices {
#       x: 250
#       y: 117
#     }
#     vertices {
#       x: 250
#       y: 124
#     }
#     vertices {
#       x: 233
#       y: 124
#     }
#   }
# }
# text_annotations {
#   description: "cinnamon"
#   bounding_poly {
#     vertices {
#       x: 260
#       y: 118
#     }
#     vertices {
#       x: 288
#       y: 119
#     }
#     vertices {
#       x: 288
#       y: 125
#     }
#     vertices {
#       x: 260
#       y: 124
#     }
#   }
# }
# text_annotations {
#   description: "milk"
#   bounding_poly {
#     vertices {
#       x: 297
#       y: 119
#     }
#     vertices {
#       x: 312
#       y: 119
#     }
#     vertices {
#       x: 312
#       y: 125
#     }
#     vertices {
#       x: 297
#       y: 125
#     }
#   }
# }
# text_annotations {
#   description: "our"
#   bounding_poly {
#     vertices {
#       x: 147
#       y: 123
#     }
#     vertices {
#       x: 159
#       y: 123
#     }
#     vertices {
#       x: 159
#       y: 130
#     }
#     vertices {
#       x: 147
#       y: 130
#     }
#   }
# }
# text_annotations {
#   description: "signature"
#   bounding_poly {
#     vertices {
#       x: 162
#       y: 123
#     }
#     vertices {
#       x: 193
#       y: 123
#     }
#     vertices {
#       x: 193
#       y: 130
#     }
#     vertices {
#       x: 162
#       y: 130
#     }
#   }
# }
# text_annotations {
#   description: "flavor"
#   bounding_poly {
#     vertices {
#       x: 195
#       y: 123
#     }
#     vertices {
#       x: 218
#       y: 123
#     }
#     vertices {
#       x: 218
#       y: 130
#     }
#     vertices {
#       x: 195
#       y: 130
#     }
#   }
# }
# text_annotations {
#   description: "coffee"
#   bounding_poly {
#     vertices {
#       x: 152
#       y: 140
#     }
#     vertices {
#       x: 190
#       y: 140
#     }
#     vertices {
#       x: 190
#       y: 157
#     }
#     vertices {
#       x: 152
#       y: 157
#     }
#   }
# }
# text_annotations {
#   description: "&"
#   bounding_poly {
#     vertices {
#       x: 194
#       y: 140
#     }
#     vertices {
#       x: 207
#       y: 140
#     }
#     vertices {
#       x: 207
#       y: 157
#     }
#     vertices {
#       x: 194
#       y: 157
#     }
#   }
# }
# text_annotations {
#   description: "specialty"
#   bounding_poly {
#     vertices {
#       x: 207
#       y: 140
#     }
#     vertices {
#       x: 267
#       y: 141
#     }
#     vertices {
#       x: 267
#       y: 159
#     }
#     vertices {
#       x: 207
#       y: 158
#     }
#   }
# }
# text_annotations {
#   description: "drinks"
#   bounding_poly {
#     vertices {
#       x: 268
#       y: 141
#     }
#     vertices {
#       x: 310
#       y: 142
#     }
#     vertices {
#       x: 310
#       y: 159
#     }
#     vertices {
#       x: 268
#       y: 158
#     }
#   }
# }
# text_annotations {
#   description: "ve"
#   bounding_poly {
#     vertices {
#       x: 152
#       y: 160
#     }
#     vertices {
#       x: 161
#       y: 160
#     }
#     vertices {
#       x: 161
#       y: 167
#     }
#     vertices {
#       x: 152
#       y: 167
#     }
#   }
# }
# text_annotations {
#   description: "ceston"
#   bounding_poly {
#     vertices {
#       x: 162
#       y: 160
#     }
#     vertices {
#       x: 182
#       y: 160
#     }
#     vertices {
#       x: 182
#       y: 167
#     }
#     vertices {
#       x: 162
#       y: 167
#     }
#   }
# }
# text_annotations {
#   description: "roast"
#   bounding_poly {
#     vertices {
#       x: 184
#       y: 160
#     }
#     vertices {
#       x: 200
#       y: 160
#     }
#     vertices {
#       x: 200
#       y: 168
#     }
#     vertices {
#       x: 184
#       y: 168
#     }
#   }
# }
# text_annotations {
#   description: "our"
#   bounding_poly {
#     vertices {
#       x: 203
#       y: 161
#     }
#     vertices {
#       x: 214
#       y: 161
#     }
#     vertices {
#       x: 214
#       y: 168
#     }
#     vertices {
#       x: 203
#       y: 168
#     }
#   }
# }
# text_annotations {
#   description: "own"
#   bounding_poly {
#     vertices {
#       x: 216
#       y: 161
#     }
#     vertices {
#       x: 227
#       y: 161
#     }
#     vertices {
#       x: 227
#       y: 168
#     }
#     vertices {
#       x: 216
#       y: 168
#     }
#   }
# }
# text_annotations {
#   description: "("
#   bounding_poly {
#     vertices {
#       x: 229
#       y: 161
#     }
#     vertices {
#       x: 231
#       y: 161
#     }
#     vertices {
#       x: 231
#       y: 168
#     }
#     vertices {
#       x: 229
#       y: 168
#     }
#   }
# }
# text_annotations {
#   description: "arabical"
#   bounding_poly {
#     vertices {
#       x: 231
#       y: 161
#     }
#     vertices {
#       x: 258
#       y: 162
#     }
#     vertices {
#       x: 258
#       y: 170
#     }
#     vertices {
#       x: 231
#       y: 169
#     }
#   }
# }
# text_annotations {
#   description: "beans"
#   bounding_poly {
#     vertices {
#       x: 261
#       y: 162
#     }
#     vertices {
#       x: 277
#       y: 162
#     }
#     vertices {
#       x: 277
#       y: 169
#     }
#     vertices {
#       x: 261
#       y: 169
#     }
#   }
# }
# text_annotations {
#   description: "brewed"
#   bounding_poly {
#     vertices {
#       x: 160
#       y: 166
#     }
#     vertices {
#       x: 180
#       y: 166
#     }
#     vertices {
#       x: 180
#       y: 173
#     }
#     vertices {
#       x: 160
#       y: 173
#     }
#   }
# }
# text_annotations {
#   description: "coffee"
#   bounding_poly {
#     vertices {
#       x: 182
#       y: 166
#     }
#     vertices {
#       x: 203
#       y: 166
#     }
#     vertices {
#       x: 203
#       y: 173
#     }
#     vertices {
#       x: 182
#       y: 173
#     }
#   }
# }
# text_annotations {
#   description: "-"
#   bounding_poly {
#     vertices {
#       x: 204
#       y: 167
#     }
#     vertices {
#       x: 209
#       y: 167
#     }
#     vertices {
#       x: 209
#       y: 174
#     }
#     vertices {
#       x: 204
#       y: 174
#     }
#   }
# }
# text_annotations {
#   description: "selise"
#   bounding_poly {
#     vertices {
#       x: 211
#       y: 167
#     }
#     vertices {
#       x: 231
#       y: 167
#     }
#     vertices {
#       x: 231
#       y: 174
#     }
#     vertices {
#       x: 211
#       y: 174
#     }
#   }
# }
# text_annotations {
#   description: "roast"
#   bounding_poly {
#     vertices {
#       x: 233
#       y: 167
#     }
#     vertices {
#       x: 250
#       y: 167
#     }
#     vertices {
#       x: 250
#       y: 174
#     }
#     vertices {
#       x: 233
#       y: 174
#     }
#   }
# }
# text_annotations {
#   description: ";"
#   bounding_poly {
#     vertices {
#       x: 250
#       y: 168
#     }
#     vertices {
#       x: 253
#       y: 168
#     }
#     vertices {
#       x: 253
#       y: 175
#     }
#     vertices {
#       x: 250
#       y: 175
#     }
#   }
# }
# text_annotations {
#   description: "notes"
#   bounding_poly {
#     vertices {
#       x: 256
#       y: 168
#     }
#     vertices {
#       x: 272
#       y: 168
#     }
#     vertices {
#       x: 272
#       y: 175
#     }
#     vertices {
#       x: 256
#       y: 175
#     }
#   }
# }
# text_annotations {
#   description: "of"
#   bounding_poly {
#     vertices {
#       x: 276
#       y: 168
#     }
#     vertices {
#       x: 282
#       y: 168
#     }
#     vertices {
#       x: 282
#       y: 175
#     }
#     vertices {
#       x: 276
#       y: 175
#     }
#   }
# }
# text_annotations {
#   description: "chocolate"
#   bounding_poly {
#     vertices {
#       x: 285
#       y: 168
#     }
#     vertices {
#       x: 313
#       y: 169
#     }
#     vertices {
#       x: 313
#       y: 177
#     }
#     vertices {
#       x: 285
#       y: 176
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 313
#       y: 169
#     }
#     vertices {
#       x: 315
#       y: 169
#     }
#     vertices {
#       x: 315
#       y: 176
#     }
#     vertices {
#       x: 313
#       y: 176
#     }
#   }
# }
# text_annotations {
#   description: "almond"
#   bounding_poly {
#     vertices {
#       x: 319
#       y: 169
#     }
#     vertices {
#       x: 337
#       y: 169
#     }
#     vertices {
#       x: 337
#       y: 177
#     }
#     vertices {
#       x: 319
#       y: 177
#     }
#   }
# }
# text_annotations {
#   description: ","
#   bounding_poly {
#     vertices {
#       x: 338
#       y: 170
#     }
#     vertices {
#       x: 340
#       y: 170
#     }
#     vertices {
#       x: 340
#       y: 177
#     }
#     vertices {
#       x: 338
#       y: 177
#     }
#   }
# }
# text_annotations {
#   description: "cherry"
#   bounding_poly {
#     vertices {
#       x: 343
#       y: 170
#     }
#     vertices {
#       x: 363
#       y: 170
#     }
#     vertices {
#       x: 363
#       y: 177
#     }
#     vertices {
#       x: 343
#       y: 177
#     }
#   }
# }
# text_annotations {
#   description: "express"
#   bounding_poly {
#     vertices {
#       x: 161
#       y: 173
#     }
#     vertices {
#       x: 183
#       y: 173
#     }
#     vertices {
#       x: 183
#       y: 177
#     }
#     vertices {
#       x: 161
#       y: 177
#     }
#   }
# }
# text_annotations {
#   description: "medios"
#   bounding_poly {
#     vertices {
#       x: 195
#       y: 174
#     }
#     vertices {
#       x: 216
#       y: 174
#     }
#     vertices {
#       x: 216
#       y: 180
#     }
#     vertices {
#       x: 195
#       y: 180
#     }
#   }
# }
# text_annotations {
#   description: "to"
#   bounding_poly {
#     vertices {
#       x: 219
#       y: 174
#     }
#     vertices {
#       x: 225
#       y: 174
#     }
#     vertices {
#       x: 225
#       y: 180
#     }
#     vertices {
#       x: 219
#       y: 180
#     }
#   }
# }
# text_annotations {
#   description: "dark"
#   bounding_poly {
#     vertices {
#       x: 228
#       y: 174
#     }
#     vertices {
#       x: 241
#       y: 174
#     }
#     vertices {
#       x: 241
#       y: 180
#     }
#     vertices {
#       x: 228
#       y: 180
#     }
#   }
# }
# text_annotations {
#   description: "roast"
#   bounding_poly {
#     vertices {
#       x: 243
#       y: 175
#     }
#     vertices {
#       x: 259
#       y: 175
#     }
#     vertices {
#       x: 259
#       y: 181
#     }
#     vertices {
#       x: 243
#       y: 181
#     }
#   }
# }
# text_annotations {
#   description: ";"
#   bounding_poly {
#     vertices {
#       x: 259
#       y: 175
#     }
#     vertices {
#       x: 262
#       y: 175
#     }
#     vertices {
#       x: 262
#       y: 181
#     }
#     vertices {
#       x: 259
#       y: 181
#     }
#   }
# }
# text_annotations {
#   description: "notes"
#   bounding_poly {
#     vertices {
#       x: 267
#       y: 175
#     }
#     vertices {
#       x: 282
#       y: 175
#     }
#     vertices {
#       x: 282
#       y: 181
#     }
#     vertices {
#       x: 267
#       y: 181
#     }
#   }
# }
# text_annotations {
#   description: "of"
#   bounding_poly {
#     vertices {
#       x: 285
#       y: 176
#     }
#     vertices {
#       x: 291
#       y: 176
#     }
#     vertices {
#       x: 291
#       y: 182
#     }
#     vertices {
#       x: 285
#       y: 182
#     }
#   }
# }
# text_annotations {
#   description: "cinnamon"
#   bounding_poly {
#     vertices {
#       x: 295
#       y: 176
#     }
#     vertices {
#       x: 320
#       y: 177
#     }
#     vertices {
#       x: 320
#       y: 183
#     }
#     vertices {
#       x: 295
#       y: 182
#     }
#   }
# }
# text_annotations {
#   description: "&"
#   bounding_poly {
#     vertices {
#       x: 322
#       y: 176
#     }
#     vertices {
#       x: 326
#       y: 176
#     }
#     vertices {
#       x: 326
#       y: 182
#     }
#     vertices {
#       x: 322
#       y: 182
#     }
#   }
# }
# text_annotations {
#   description: "brown"
#   bounding_poly {
#     vertices {
#       x: 327
#       y: 177
#     }
#     vertices {
#       x: 345
#       y: 177
#     }
#     vertices {
#       x: 345
#       y: 183
#     }
#     vertices {
#       x: 327
#       y: 183
#     }
#   }
# }
# text_annotations {
#   description: "sagar"
#   bounding_poly {
#     vertices {
#       x: 347
#       y: 177
#     }
#     vertices {
#       x: 362
#       y: 177
#     }
#     vertices {
#       x: 362
#       y: 183
#     }
#     vertices {
#       x: 347
#       y: 183
#     }
#   }
# }
# text_annotations {
#   description: "decaf"
#   bounding_poly {
#     vertices {
#       x: 162
#       y: 179
#     }
#     vertices {
#       x: 177
#       y: 179
#     }
#     vertices {
#       x: 177
#       y: 184
#     }
#     vertices {
#       x: 162
#       y: 184
#     }
#   }
# }
# text_annotations {
#   description: "espresso"
#   bounding_poly {
#     vertices {
#       x: 180
#       y: 179
#     }
#     vertices {
#       x: 206
#       y: 180
#     }
#     vertices {
#       x: 206
#       y: 185
#     }
#     vertices {
#       x: 180
#       y: 184
#     }
#   }
# }
# text_annotations {
#   description: "medium"
#   bounding_poly {
#     vertices {
#       x: 215
#       y: 180
#     }
#     vertices {
#       x: 234
#       y: 180
#     }
#     vertices {
#       x: 234
#       y: 186
#     }
#     vertices {
#       x: 215
#       y: 186
#     }
#   }
# }
# text_annotations {
#   description: "to"
#   bounding_poly {
#     vertices {
#       x: 238
#       y: 180
#     }
#     vertices {
#       x: 245
#       y: 180
#     }
#     vertices {
#       x: 245
#       y: 186
#     }
#     vertices {
#       x: 238
#       y: 186
#     }
#   }
# }
# text_annotations {
#   description: "dark"
#   bounding_poly {
#     vertices {
#       x: 247
#       y: 180
#     }
#     vertices {
#       x: 261
#       y: 180
#     }
#     vertices {
#       x: 261
#       y: 186
#     }
#     vertices {
#       x: 247
#       y: 186
#     }
#   }
# }
# text_annotations {
#   description: "roast"
#   bounding_poly {
#     vertices {
#       x: 264
#       y: 181
#     }
#     vertices {
#       x: 279
#       y: 181
#     }
#     vertices {
#       x: 279
#       y: 187
#     }
#     vertices {
#       x: 264
#       y: 187
#     }
#   }
# }
# text_annotations {
#   description: ";"
#   bounding_poly {
#     vertices {
#       x: 281
#       y: 181
#     }
#     vertices {
#       x: 284
#       y: 181
#     }
#     vertices {
#       x: 284
#       y: 187
#     }
#     vertices {
#       x: 281
#       y: 187
#     }
#   }
# }
# text_annotations {
#   description: "notes"
#   bounding_poly {
#     vertices {
#       x: 287
#       y: 181
#     }
#     vertices {
#       x: 302
#       y: 181
#     }
#     vertices {
#       x: 302
#       y: 187
#     }
#     vertices {
#       x: 287
#       y: 187
#     }
#   }
# }
# text_annotations {
#   description: "of"
#   bounding_poly {
#     vertices {
#       x: 305
#       y: 182
#     }
#     vertices {
#       x: 311
#       y: 182
#     }
#     vertices {
#       x: 311
#       y: 188
#     }
#     vertices {
#       x: 305
#       y: 188
#     }
#   }
# }
# text_annotations {
#   description: "caramel"
#   bounding_poly {
#     vertices {
#       x: 314
#       y: 182
#     }
#     vertices {
#       x: 335
#       y: 182
#     }
#     vertices {
#       x: 335
#       y: 188
#     }
#     vertices {
#       x: 314
#       y: 188
#     }
#   }
# }
# text_annotations {
#   description: "brewed"
#   bounding_poly {
#     vertices {
#       x: 156
#       y: 190
#     }
#     vertices {
#       x: 177
#       y: 190
#     }
#     vertices {
#       x: 177
#       y: 196
#     }
#     vertices {
#       x: 156
#       y: 196
#     }
#   }
# }
# text_annotations {
#   description: "coffee"
#   bounding_poly {
#     vertices {
#       x: 181
#       y: 190
#     }
#     vertices {
#       x: 205
#       y: 190
#     }
#     vertices {
#       x: 205
#       y: 196
#     }
#     vertices {
#       x: 181
#       y: 196
#     }
#   }
# }
# text_annotations {
#   description: "cold"
#   bounding_poly {
#     vertices {
#       x: 157
#       y: 200
#     }
#     vertices {
#       x: 172
#       y: 200
#     }
#     vertices {
#       x: 172
#       y: 205
#     }
#     vertices {
#       x: 157
#       y: 205
#     }
#   }
# }
# text_annotations {
#   description: "brew"
#   bounding_poly {
#     vertices {
#       x: 175
#       y: 200
#     }
#     vertices {
#       x: 190
#       y: 200
#     }
#     vertices {
#       x: 190
#       y: 205
#     }
#     vertices {
#       x: 175
#       y: 205
#     }
#   }
# }
# text_annotations {
#   description: "espresso"
#   bounding_poly {
#     vertices {
#       x: 158
#       y: 210
#     }
#     vertices {
#       x: 187
#       y: 210
#     }
#     vertices {
#       x: 187
#       y: 215
#     }
#     vertices {
#       x: 158
#       y: 215
#     }
#   }
# }
# text_annotations {
#   description: "americano"
#   bounding_poly {
#     vertices {
#       x: 159
#       y: 217
#     }
#     vertices {
#       x: 191
#       y: 218
#     }
#     vertices {
#       x: 191
#       y: 224
#     }
#     vertices {
#       x: 159
#       y: 223
#     }
#   }
# }
# text_annotations {
#   description: "macchiato"
#   bounding_poly {
#     vertices {
#       x: 159
#       y: 227
#     }
#     vertices {
#       x: 193
#       y: 227
#     }
#     vertices {
#       x: 193
#       y: 233
#     }
#     vertices {
#       x: 159
#       y: 233
#     }
#   }
# }
# text_annotations {
#   description: "("
#   bounding_poly {
#     vertices {
#       x: 196
#       y: 227
#     }
#     vertices {
#       x: 199
#       y: 227
#     }
#     vertices {
#       x: 199
#       y: 233
#     }
#     vertices {
#       x: 196
#       y: 233
#     }
#   }
# }
# text_annotations {
#   description: "traditional"
#   bounding_poly {
#     vertices {
#       x: 199
#       y: 227
#     }
#     vertices {
#       x: 242
#       y: 227
#     }
#     vertices {
#       x: 242
#       y: 233
#     }
#     vertices {
#       x: 199
#       y: 233
#     }
#   }
# }
# text_annotations {
#   description: ")"
#   bounding_poly {
#     vertices {
#       x: 242
#       y: 227
#     }
#     vertices {
#       x: 246
#       y: 227
#     }
#     vertices {
#       x: 246
#       y: 233
#     }
#     vertices {
#       x: 242
#       y: 233
#     }
#   }
# }
# text_annotations {
#   description: "cortado"
#   bounding_poly {
#     vertices {
#       x: 161
#       y: 237
#     }
#     vertices {
#       x: 186
#       y: 237
#     }
#     vertices {
#       x: 186
#       y: 242
#     }
#     vertices {
#       x: 161
#       y: 242
#     }
#   }
# }
# text_annotations {
#   description: "cappuccino"
#   bounding_poly {
#     vertices {
#       x: 162
#       y: 245
#     }
#     vertices {
#       x: 198
#       y: 245
#     }
#     vertices {
#       x: 198
#       y: 250
#     }
#     vertices {
#       x: 162
#       y: 250
#     }
#   }
# }
# text_annotations {
#   description: "flat"
#   bounding_poly {
#     vertices {
#       x: 162
#       y: 253
#     }
#     vertices {
#       x: 177
#       y: 253
#     }
#     vertices {
#       x: 177
#       y: 259
#     }
#     vertices {
#       x: 162
#       y: 259
#     }
#   }
# }
# text_annotations {
#   description: "white"
#   bounding_poly {
#     vertices {
#       x: 179
#       y: 253
#     }
#     vertices {
#       x: 199
#       y: 254
#     }
#     vertices {
#       x: 199
#       y: 260
#     }
#     vertices {
#       x: 179
#       y: 259
#     }
#   }
# }
# text_annotations {
#   description: "latte"
#   bounding_poly {
#     vertices {
#       x: 163
#       y: 263
#     }
#     vertices {
#       x: 181
#       y: 263
#     }
#     vertices {
#       x: 181
#       y: 268
#     }
#     vertices {
#       x: 163
#       y: 268
#     }
#   }
# }
# text_annotations {
#   description: "mocha"
#   bounding_poly {
#     vertices {
#       x: 163
#       y: 276
#     }
#     vertices {
#       x: 180
#       y: 276
#     }
#     vertices {
#       x: 180
#       y: 282
#     }
#     vertices {
#       x: 163
#       y: 282
#     }
#   }
# }
# text_annotations {
#   description: "latte"
#   bounding_poly {
#     vertices {
#       x: 185
#       y: 276
#     }
#     vertices {
#       x: 204
#       y: 276
#     }
#     vertices {
#       x: 204
#       y: 281
#     }
#     vertices {
#       x: 185
#       y: 281
#     }
#   }
# }
# text_annotations {
#   description: "lavender"
#   bounding_poly {
#     vertices {
#       x: 166
#       y: 294
#     }
#     vertices {
#       x: 194
#       y: 294
#     }
#     vertices {
#       x: 194
#       y: 299
#     }
#     vertices {
#       x: 166
#       y: 299
#     }
#   }
# }
# text_annotations {
#   description: "latte"
#   bounding_poly {
#     vertices {
#       x: 199
#       y: 294
#     }
#     vertices {
#       x: 218
#       y: 294
#     }
#     vertices {
#       x: 218
#       y: 299
#     }
#     vertices {
#       x: 199
#       y: 299
#     }
#   }
# }
# text_annotations {
#   description: "vanilla"
#   bounding_poly {
#     vertices {
#       x: 166
#       y: 302
#     }
#     vertices {
#       x: 194
#       y: 302
#     }
#     vertices {
#       x: 194
#       y: 308
#     }
#     vertices {
#       x: 166
#       y: 308
#     }
#   }
# }
# text_annotations {
#   description: "latte"
#   bounding_poly {
#     vertices {
#       x: 197
#       y: 302
#     }
#     vertices {
#       x: 216
#       y: 302
#     }
#     vertices {
#       x: 216
#       y: 308
#     }
#     vertices {
#       x: 197
#       y: 308
#     }
#   }
# }
# text_annotations {
#   description: "ube"
#   bounding_poly {
#     vertices {
#       x: 168
#       y: 318
#     }
#     vertices {
#       x: 180
#       y: 318
#     }
#     vertices {
#       x: 180
#       y: 326
#     }
#     vertices {
#       x: 168
#       y: 326
#     }
#   }
# }
# text_annotations {
#   description: "latte"
#   bounding_poly {
#     vertices {
#       x: 183
#       y: 318
#     }
#     vertices {
#       x: 202
#       y: 318
#     }
#     vertices {
#       x: 202
#       y: 325
#     }
#     vertices {
#       x: 183
#       y: 325
#     }
#   }
# }
# text_annotations {
#   description: "("
#   bounding_poly {
#     vertices {
#       x: 207
#       y: 318
#     }
#     vertices {
#       x: 210
#       y: 318
#     }
#     vertices {
#       x: 210
#       y: 325
#     }
#     vertices {
#       x: 207
#       y: 325
#     }
#   }
# }
# text_annotations {
#   description: "purple"
#   bounding_poly {
#     vertices {
#       x: 209
#       y: 318
#     }
#     vertices {
#       x: 233
#       y: 318
#     }
#     vertices {
#       x: 233
#       y: 325
#     }
#     vertices {
#       x: 209
#       y: 325
#     }
#   }
# }
# text_annotations {
#   description: "yan"
#   bounding_poly {
#     vertices {
#       x: 236
#       y: 318
#     }
#     vertices {
#       x: 249
#       y: 318
#     }
#     vertices {
#       x: 249
#       y: 325
#     }
#     vertices {
#       x: 236
#       y: 325
#     }
#   }
# }
# text_annotations {
#   description: ")"
#   bounding_poly {
#     vertices {
#       x: 249
#       y: 317
#     }
#     vertices {
#       x: 252
#       y: 317
#     }
#     vertices {
#       x: 252
#       y: 324
#     }
#     vertices {
#       x: 249
#       y: 324
#     }
#   }
# }
# text_annotations {
#   description: "being"
#   bounding_poly {
#     vertices {
#       x: 422
#       y: 84
#     }
#     vertices {
#       x: 440
#       y: 85
#     }
#     vertices {
#       x: 440
#       y: 90
#     }
#     vertices {
#       x: 422
#       y: 89
#     }
#   }
# }
# text_annotations {
#   description: "and"
#   bounding_poly {
#     vertices {
#       x: 449
#       y: 86
#     }
#     vertices {
#       x: 457
#       y: 86
#     }
#     vertices {
#       x: 457
#       y: 90
#     }
#     vertices {
#       x: 449
#       y: 90
#     }
#   }
# }
# text_annotations {
#   description: "HOT"
#   bounding_poly {
#     vertices {
#       x: 432
#       y: 96
#     }
#     vertices {
#       x: 444
#       y: 96
#     }
#     vertices {
#       x: 444
#       y: 101
#     }
#     vertices {
#       x: 432
#       y: 101
#     }
#   }
# }
# text_annotations {
#   description: "ICED"
#   bounding_poly {
#     vertices {
#       x: 468
#       y: 96
#     }
#     vertices {
#       x: 485
#       y: 97
#     }
#     vertices {
#       x: 485
#       y: 105
#     }
#     vertices {
#       x: 468
#       y: 104
#     }
#   }
# }
# text_annotations {
#   description: "6.00"
#   bounding_poly {
#     vertices {
#       x: 432
#       y: 113
#     }
#     vertices {
#       x: 446
#       y: 113
#     }
#     vertices {
#       x: 446
#       y: 118
#     }
#     vertices {
#       x: 432
#       y: 118
#     }
#   }
# }
# text_annotations {
#   description: "6.50"
#   bounding_poly {
#     vertices {
#       x: 468
#       y: 114
#     }
#     vertices {
#       x: 482
#       y: 114
#     }
#     vertices {
#       x: 482
#       y: 119
#     }
#     vertices {
#       x: 468
#       y: 119
#     }
#   }
# }
# text_annotations {
#   description: "try"
#   bounding_poly {
#     vertices {
#       x: 405
#       y: 148
#     }
#     vertices {
#       x: 418
#       y: 148
#     }
#     vertices {
#       x: 418
#       y: 158
#     }
#     vertices {
#       x: 405
#       y: 158
#     }
#   }
# }
# text_annotations {
#   description: "foresting"
#   bounding_poly {
#     vertices {
#       x: 415
#       y: 147
#     }
#     vertices {
#       x: 453
#       y: 148
#     }
#     vertices {
#       x: 453
#       y: 159
#     }
#     vertices {
#       x: 415
#       y: 158
#     }
#   }
# }
# text_annotations {
#   description: "your"
#   bounding_poly {
#     vertices {
#       x: 406
#       y: 157
#     }
#     vertices {
#       x: 425
#       y: 157
#     }
#     vertices {
#       x: 425
#       y: 167
#     }
#     vertices {
#       x: 406
#       y: 167
#     }
#   }
# }
# text_annotations {
#   description: "drink"
#   bounding_poly {
#     vertices {
#       x: 427
#       y: 157
#     }
#     vertices {
#       x: 450
#       y: 156
#     }
#     vertices {
#       x: 450
#       y: 165
#     }
#     vertices {
#       x: 427
#       y: 166
#     }
#   }
# }
# text_annotations {
#   description: "+1.25"
#   bounding_poly {
#     vertices {
#       x: 419
#       y: 168
#     }
#     vertices {
#       x: 435
#       y: 168
#     }
#     vertices {
#       x: 435
#       y: 172
#     }
#     vertices {
#       x: 419
#       y: 172
#     }
#   }
# }
# text_annotations {
#   description: "3.25"
#   bounding_poly {
#     vertices {
#       x: 434
#       y: 196
#     }
#     vertices {
#       x: 448
#       y: 196
#     }
#     vertices {
#       x: 448
#       y: 200
#     }
#     vertices {
#       x: 434
#       y: 200
#     }
#   }
# }
# text_annotations {
#   description: "4.75"
#   bounding_poly {
#     vertices {
#       x: 469
#       y: 205
#     }
#     vertices {
#       x: 484
#       y: 205
#     }
#     vertices {
#       x: 484
#       y: 210
#     }
#     vertices {
#       x: 469
#       y: 210
#     }
#   }
# }
# text_annotations {
#   description: "3.25"
#   bounding_poly {
#     vertices {
#       x: 435
#       y: 213
#     }
#     vertices {
#       x: 449
#       y: 213
#     }
#     vertices {
#       x: 449
#       y: 218
#     }
#     vertices {
#       x: 435
#       y: 218
#     }
#   }
# }
# text_annotations {
#   description: "3.75"
#   bounding_poly {
#     vertices {
#       x: 470
#       y: 213
#     }
#     vertices {
#       x: 483
#       y: 213
#     }
#     vertices {
#       x: 483
#       y: 219
#     }
#     vertices {
#       x: 470
#       y: 219
#     }
#   }
# }
# text_annotations {
#   description: "3.56"
#   bounding_poly {
#     vertices {
#       x: 435
#       y: 220
#     }
#     vertices {
#       x: 450
#       y: 221
#     }
#     vertices {
#       x: 450
#       y: 227
#     }
#     vertices {
#       x: 435
#       y: 226
#     }
#   }
# }
# text_annotations {
#   description: "4.08"
#   bounding_poly {
#     vertices {
#       x: 470
#       y: 223
#     }
#     vertices {
#       x: 485
#       y: 223
#     }
#     vertices {
#       x: 485
#       y: 228
#     }
#     vertices {
#       x: 470
#       y: 228
#     }
#   }
# }
# text_annotations {
#   description: "3.75"
#   bounding_poly {
#     vertices {
#       x: 435
#       y: 231
#     }
#     vertices {
#       x: 449
#       y: 231
#     }
#     vertices {
#       x: 449
#       y: 235
#     }
#     vertices {
#       x: 435
#       y: 235
#     }
#   }
# }
# text_annotations {
#   description: "4.25"
#   bounding_poly {
#     vertices {
#       x: 435
#       y: 240
#     }
#     vertices {
#       x: 449
#       y: 240
#     }
#     vertices {
#       x: 449
#       y: 245
#     }
#     vertices {
#       x: 435
#       y: 245
#     }
#   }
# }
# text_annotations {
#   description: "4.75"
#   bounding_poly {
#     vertices {
#       x: 470
#       y: 240
#     }
#     vertices {
#       x: 483
#       y: 240
#     }
#     vertices {
#       x: 483
#       y: 244
#     }
#     vertices {
#       x: 470
#       y: 244
#     }
#   }
# }
# text_annotations {
#   description: "4.15"
#   bounding_poly {
#     vertices {
#       x: 435
#       y: 249
#     }
#     vertices {
#       x: 450
#       y: 249
#     }
#     vertices {
#       x: 450
#       y: 253
#     }
#     vertices {
#       x: 435
#       y: 253
#     }
#   }
# }
# text_annotations {
#   description: "4.75"
#   bounding_poly {
#     vertices {
#       x: 435
#       y: 257
#     }
#     vertices {
#       x: 449
#       y: 257
#     }
#     vertices {
#       x: 449
#       y: 261
#     }
#     vertices {
#       x: 435
#       y: 261
#     }
#   }
# }
# text_annotations {
#   description: "5.50"
#   bounding_poly {
#     vertices {
#       x: 470
#       y: 265
#     }
#     vertices {
#       x: 485
#       y: 266
#     }
#     vertices {
#       x: 485
#       y: 271
#     }
#     vertices {
#       x: 470
#       y: 270
#     }
#   }
# }
# text_annotations {
#   description: "5.75"
#   bounding_poly {
#     vertices {
#       x: 436
#       y: 279
#     }
#     vertices {
#       x: 451
#       y: 279
#     }
#     vertices {
#       x: 451
#       y: 283
#     }
#     vertices {
#       x: 436
#       y: 283
#     }
#   }
# }
# text_annotations {
#   description: "6.25"
#   bounding_poly {
#     vertices {
#       x: 470
#       y: 279
#     }
#     vertices {
#       x: 485
#       y: 279
#     }
#     vertices {
#       x: 485
#       y: 283
#     }
#     vertices {
#       x: 470
#       y: 283
#     }
#   }
# }
# text_annotations {
#   description: "5.75"
#   bounding_poly {
#     vertices {
#       x: 436
#       y: 287
#     }
#     vertices {
#       x: 451
#       y: 287
#     }
#     vertices {
#       x: 451
#       y: 291
#     }
#     vertices {
#       x: 436
#       y: 291
#     }
#   }
# }
# text_annotations {
#   description: "6.25"
#   bounding_poly {
#     vertices {
#       x: 471
#       y: 287
#     }
#     vertices {
#       x: 485
#       y: 287
#     }
#     vertices {
#       x: 485
#       y: 291
#     }
#     vertices {
#       x: 471
#       y: 291
#     }
#   }
# }
# text_annotations {
#   description: "5.75"
#   bounding_poly {
#     vertices {
#       x: 437
#       y: 294
#     }
#     vertices {
#       x: 450
#       y: 294
#     }
#     vertices {
#       x: 450
#       y: 299
#     }
#     vertices {
#       x: 437
#       y: 299
#     }
#   }
# }
# text_annotations {
#   description: "6.25"
#   bounding_poly {
#     vertices {
#       x: 471
#       y: 294
#     }
#     vertices {
#       x: 484
#       y: 294
#     }
#     vertices {
#       x: 484
#       y: 299
#     }
#     vertices {
#       x: 471
#       y: 299
#     }
#   }
# }
# text_annotations {
#   description: "5.75"
#   bounding_poly {
#     vertices {
#       x: 437
#       y: 303
#     }
#     vertices {
#       x: 450
#       y: 303
#     }
#     vertices {
#       x: 450
#       y: 308
#     }
#     vertices {
#       x: 437
#       y: 308
#     }
#   }
# }
# text_annotations {
#   description: "6.25"
#   bounding_poly {
#     vertices {
#       x: 471
#       y: 303
#     }
#     vertices {
#       x: 483
#       y: 303
#     }
#     vertices {
#       x: 483
#       y: 308
#     }
#     vertices {
#       x: 471
#       y: 308
#     }
#   }
# }
# text_annotations {
#   description: "?"
#   bounding_poly {
#     vertices {
#       x: 579
#       y: 297
#     }
#     vertices {
#       x: 585
#       y: 297
#     }
#     vertices {
#       x: 585
#       y: 306
#     }
#     vertices {
#       x: 579
#       y: 306
#     }
#   }
# }
# text_annotations {
#   description: "6.25"
#   bounding_poly {
#     vertices {
#       x: 471
#       y: 311
#     }
#     vertices {
#       x: 484
#       y: 311
#     }
#     vertices {
#       x: 484
#       y: 316
#     }
#     vertices {
#       x: 471
#       y: 316
#     }
#   }
# }
# text_annotations {
#   description: "5.75"
#   bounding_poly {
#     vertices {
#       x: 437
#       y: 319
#     }
#     vertices {
#       x: 450
#       y: 319
#     }
#     vertices {
#       x: 450
#       y: 325
#     }
#     vertices {
#       x: 437
#       y: 325
#     }
#   }
# }
# text_annotations {
#   description: "6.25"
#   bounding_poly {
#     vertices {
#       x: 471
#       y: 319
#     }
#     vertices {
#       x: 484
#       y: 319
#     }
#     vertices {
#       x: 484
#       y: 324
#     }
#     vertices {
#       x: 471
#       y: 324
#     }
#   }
# }
# text_annotations {
#   description: "7.25"
#   bounding_poly {
#     vertices {
#       x: 437
#       y: 327
#     }
#     vertices {
#       x: 451
#       y: 327
#     }
#     vertices {
#       x: 451
#       y: 332
#     }
#     vertices {
#       x: 437
#       y: 332
#     }
#   }
# }
# text_annotations {
#   description: "7.75"
#   bounding_poly {
#     vertices {
#       x: 471
#       y: 327
#     }
#     vertices {
#       x: 484
#       y: 327
#     }
#     vertices {
#       x: 484
#       y: 332
#     }
#     vertices {
#       x: 471
#       y: 332
#     }
#   }
# }
# text_annotations {
#   description: "grab"
#   bounding_poly {
#     vertices {
#       x: 559
#       y: 319
#     }
#     vertices {
#       x: 586
#       y: 319
#     }
#     vertices {
#       x: 586
#       y: 333
#     }
#     vertices {
#       x: 559
#       y: 333
#     }
#   }
# }
# text_annotations {
#   description: "salted"
#   bounding_poly {
#     vertices {
#       x: 164
#       y: 285
#     }
#     vertices {
#       x: 186
#       y: 285
#     }
#     vertices {
#       x: 186
#       y: 291
#     }
#     vertices {
#       x: 164
#       y: 291
#     }
#   }
# }
# text_annotations {
#   description: "caramel"
#   bounding_poly {
#     vertices {
#       x: 191
#       y: 285
#     }
#     vertices {
#       x: 217
#       y: 285
#     }
#     vertices {
#       x: 217
#       y: 291
#     }
#     vertices {
#       x: 191
#       y: 291
#     }
#   }
# }
# text_annotations {
#   description: "latte"
#   bounding_poly {
#     vertices {
#       x: 221
#       y: 285
#     }
#     vertices {
#       x: 242
#       y: 285
#     }
#     vertices {
#       x: 242
#       y: 291
#     }
#     vertices {
#       x: 221
#       y: 291
#     }
#   }
# }
# text_annotations {
#   description: "iced"
#   bounding_poly {
#     vertices {
#       x: 167
#       y: 310
#     }
#     vertices {
#       x: 182
#       y: 310
#     }
#     vertices {
#       x: 182
#       y: 317
#     }
#     vertices {
#       x: 167
#       y: 317
#     }
#   }
# }
# text_annotations {
#   description: "shakerato"
#   bounding_poly {
#     vertices {
#       x: 185
#       y: 310
#     }
#     vertices {
#       x: 220
#       y: 310
#     }
#     vertices {
#       x: 220
#       y: 316
#     }
#     vertices {
#       x: 185
#       y: 316
#     }
#   }
# }
# text_annotations {
#   description: "("
#   bounding_poly {
#     vertices {
#       x: 225
#       y: 310
#     }
#     vertices {
#       x: 228
#       y: 310
#     }
#     vertices {
#       x: 228
#       y: 316
#     }
#     vertices {
#       x: 225
#       y: 316
#     }
#   }
# }
# text_annotations {
#   description: "shaken"
#   bounding_poly {
#     vertices {
#       x: 228
#       y: 310
#     }
#     vertices {
#       x: 251
#       y: 310
#     }
#     vertices {
#       x: 251
#       y: 316
#     }
#     vertices {
#       x: 228
#       y: 316
#     }
#   }
# }
# text_annotations {
#   description: "espresso"
#   bounding_poly {
#     vertices {
#       x: 255
#       y: 310
#     }
#     vertices {
#       x: 284
#       y: 310
#     }
#     vertices {
#       x: 284
#       y: 316
#     }
#     vertices {
#       x: 255
#       y: 316
#     }
#   }
# }
# text_annotations {
#   description: "over"
#   bounding_poly {
#     vertices {
#       x: 287
#       y: 310
#     }
#     vertices {
#       x: 302
#       y: 310
#     }
#     vertices {
#       x: 302
#       y: 316
#     }
#     vertices {
#       x: 287
#       y: 316
#     }
#   }
# }
# text_annotations {
#   description: "milk"
#   bounding_poly {
#     vertices {
#       x: 304
#       y: 310
#     }
#     vertices {
#       x: 318
#       y: 310
#     }
#     vertices {
#       x: 318
#       y: 316
#     }
#     vertices {
#       x: 304
#       y: 316
#     }
#   }
# }
# text_annotations {
#   description: ")"
#   bounding_poly {
#     vertices {
#       x: 318
#       y: 310
#     }
#     vertices {
#       x: 321
#       y: 310
#     }
#     vertices {
#       x: 321
#       y: 316
#     }
#     vertices {
#       x: 318
#       y: 316
#     }
#   }
# }
# text_annotations {
#   description: "dirty"
#   bounding_poly {
#     vertices {
#       x: 169
#       y: 326
#     }
#     vertices {
#       x: 189
#       y: 326
#     }
#     vertices {
#       x: 189
#       y: 334
#     }
#     vertices {
#       x: 169
#       y: 334
#     }
#   }
# }
# text_annotations {
#   description: "be"
#   bounding_poly {
#     vertices {
#       x: 195
#       y: 326
#     }
#     vertices {
#       x: 204
#       y: 326
#     }
#     vertices {
#       x: 204
#       y: 333
#     }
#     vertices {
#       x: 195
#       y: 333
#     }
#   }
# }
# text_annotations {
#   description: "latte"
#   bounding_poly {
#     vertices {
#       x: 208
#       y: 326
#     }
#     vertices {
#       x: 228
#       y: 326
#     }
#     vertices {
#       x: 228
#       y: 333
#     }
#     vertices {
#       x: 208
#       y: 333
#     }
#   }
# }
# text_annotations {
#   description: "("
#   bounding_poly {
#     vertices {
#       x: 231
#       y: 326
#     }
#     vertices {
#       x: 235
#       y: 326
#     }
#     vertices {
#       x: 235
#       y: 333
#     }
#     vertices {
#       x: 231
#       y: 333
#     }
#   }
# }
# text_annotations {
#   description: "+"
#   bounding_poly {
#     vertices {
#       x: 233
#       y: 326
#     }
#     vertices {
#       x: 238
#       y: 326
#     }
#     vertices {
#       x: 238
#       y: 333
#     }
#     vertices {
#       x: 233
#       y: 333
#     }
#   }
# }
# text_annotations {
#   description: "espresso"
#   bounding_poly {
#     vertices {
#       x: 241
#       y: 325
#     }
#     vertices {
#       x: 271
#       y: 325
#     }
#     vertices {
#       x: 271
#       y: 332
#     }
#     vertices {
#       x: 241
# ...
#                 y: 566
#               }
#               vertices {
#                 x: 225
#                 y: 566
#               }
#               vertices {
#                 x: 225
#                 y: 571
#               }
#               vertices {
#                 x: 221
#                 y: 571
#               }
#             }
#             text: "c"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 224
#                 y: 566
#               }
#               vertices {
#                 x: 228
#                 y: 566
#               }
#               vertices {
#                 x: 228
#                 y: 571
#               }
#               vertices {
#                 x: 224
#                 y: 571
#               }
#             }
#             text: "a"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 227
#                 y: 566
#               }
#               vertices {
#                 x: 230
#                 y: 566
#               }
#               vertices {
#                 x: 230
#                 y: 571
#               }
#               vertices {
#                 x: 227
#                 y: 571
#               }
#             }
#             text: "l"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 228
#                 y: 567
#               }
#               vertices {
#                 x: 232
#                 y: 567
#               }
#               vertices {
#                 x: 232
#                 y: 572
#               }
#               vertices {
#                 x: 228
#                 y: 572
#               }
#             }
#             text: "a"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 231
#                 y: 567
#               }
#               vertices {
#                 x: 234
#                 y: 567
#               }
#               vertices {
#                 x: 234
#                 y: 572
#               }
#               vertices {
#                 x: 231
#                 y: 572
#               }
#             }
#             text: "t"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 234
#                 y: 567
#               }
#               vertices {
#                 x: 238
#                 y: 567
#               }
#               vertices {
#                 x: 238
#                 y: 572
#               }
#               vertices {
#                 x: 234
#                 y: 572
#               }
#             }
#             text: "e"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#     blocks {
#       bounding_box {
#         vertices {
#           x: 267
#           y: 565
#         }
#         vertices {
#           x: 284
#           y: 565
#         }
#         vertices {
#           x: 284
#           y: 570
#         }
#         vertices {
#           x: 267
#           y: 570
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 267
#             y: 565
#           }
#           vertices {
#             x: 284
#             y: 565
#           }
#           vertices {
#             x: 284
#             y: 570
#           }
#           vertices {
#             x: 267
#             y: 570
#           }
#         }
#         words {
#           bounding_box {
#             vertices {
#               x: 267
#               y: 565
#             }
#             vertices {
#               x: 284
#               y: 565
#             }
#             vertices {
#               x: 284
#               y: 570
#             }
#             vertices {
#               x: 267
#               y: 570
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 267
#                 y: 566
#               }
#               vertices {
#                 x: 271
#                 y: 566
#               }
#               vertices {
#                 x: 271
#                 y: 570
#               }
#               vertices {
#                 x: 267
#                 y: 570
#               }
#             }
#             text: "-"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 272
#                 y: 565
#               }
#               vertices {
#                 x: 276
#                 y: 565
#               }
#               vertices {
#                 x: 276
#                 y: 569
#               }
#               vertices {
#                 x: 272
#                 y: 569
#               }
#             }
#             text: "8"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 275
#                 y: 565
#               }
#               vertices {
#                 x: 278
#                 y: 565
#               }
#               vertices {
#                 x: 278
#                 y: 569
#               }
#               vertices {
#                 x: 275
#                 y: 569
#               }
#             }
#             text: "."
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 278
#                 y: 565
#               }
#               vertices {
#                 x: 281
#                 y: 565
#               }
#               vertices {
#                 x: 281
#                 y: 569
#               }
#               vertices {
#                 x: 278
#                 y: 569
#               }
#             }
#             text: "7"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 281
#                 y: 565
#               }
#               vertices {
#                 x: 284
#                 y: 565
#               }
#               vertices {
#                 x: 284
#                 y: 569
#               }
#               vertices {
#                 x: 281
#                 y: 569
#               }
#             }
#             text: "5"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#     blocks {
#       bounding_box {
#         vertices {
#           x: 403
#           y: 560
#         }
#         vertices {
#           x: 464
#           y: 557
#         }
#         vertices {
#           x: 464
#           y: 564
#         }
#         vertices {
#           x: 403
#           y: 567
#         }
#       }
#       paragraphs {
#         bounding_box {
#           vertices {
#             x: 403
#             y: 560
#           }
#           vertices {
#             x: 464
#             y: 557
#           }
#           vertices {
#             x: 464
#             y: 564
#           }
#           vertices {
#             x: 403
#             y: 567
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 403
#               y: 560
#             }
#             vertices {
#               x: 411
#               y: 560
#             }
#             vertices {
#               x: 411
#               y: 567
#             }
#             vertices {
#               x: 403
#               y: 567
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 403
#                 y: 561
#               }
#               vertices {
#                 x: 408
#                 y: 561
#               }
#               vertices {
#                 x: 408
#                 y: 567
#               }
#               vertices {
#                 x: 403
#                 y: 567
#               }
#             }
#             text: "t"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 405
#                 y: 560
#               }
#               vertices {
#                 x: 409
#                 y: 560
#               }
#               vertices {
#                 x: 409
#                 y: 566
#               }
#               vertices {
#                 x: 405
#                 y: 566
#               }
#             }
#             text: "r"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 408
#                 y: 560
#               }
#               vertices {
#                 x: 411
#                 y: 560
#               }
#               vertices {
#                 x: 411
#                 y: 566
#               }
#               vertices {
#                 x: 408
#                 y: 566
#               }
#             }
#             text: "a"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 414
#               y: 560
#             }
#             vertices {
#               x: 451
#               y: 558
#             }
#             vertices {
#               x: 451
#               y: 564
#             }
#             vertices {
#               x: 414
#               y: 566
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 414
#                 y: 560
#               }
#               vertices {
#                 x: 418
#                 y: 560
#               }
#               vertices {
#                 x: 418
#                 y: 566
#               }
#               vertices {
#                 x: 414
#                 y: 566
#               }
#             }
#             text: "d"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 417
#                 y: 560
#               }
#               vertices {
#                 x: 420
#                 y: 560
#               }
#               vertices {
#                 x: 420
#                 y: 566
#               }
#               vertices {
#                 x: 417
#                 y: 566
#               }
#             }
#             text: "o"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 419
#                 y: 560
#               }
#               vertices {
#                 x: 422
#                 y: 560
#               }
#               vertices {
#                 x: 422
#                 y: 566
#               }
#               vertices {
#                 x: 419
#                 y: 566
#               }
#             }
#             text: "u"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 422
#                 y: 560
#               }
#               vertices {
#                 x: 426
#                 y: 560
#               }
#               vertices {
#                 x: 426
#                 y: 566
#               }
#               vertices {
#                 x: 422
#                 y: 566
#               }
#             }
#             text: "b"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 425
#                 y: 559
#               }
#               vertices {
#                 x: 428
#                 y: 559
#               }
#               vertices {
#                 x: 428
#                 y: 565
#               }
#               vertices {
#                 x: 425
#                 y: 565
#               }
#             }
#             text: "l"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 447
#                 y: 558
#               }
#               vertices {
#                 x: 451
#                 y: 558
#               }
#               vertices {
#                 x: 451
#                 y: 564
#               }
#               vertices {
#                 x: 447
#                 y: 564
#               }
#             }
#             text: "e"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 452
#               y: 558
#             }
#             vertices {
#               x: 464
#               y: 557
#             }
#             vertices {
#               x: 464
#               y: 563
#             }
#             vertices {
#               x: 452
#               y: 564
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 452
#                 y: 558
#               }
#               vertices {
#                 x: 455
#                 y: 558
#               }
#               vertices {
#                 x: 455
#                 y: 564
#               }
#               vertices {
#                 x: 452
#                 y: 564
#               }
#             }
#             text: "s"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 461
#                 y: 558
#               }
#               vertices {
#                 x: 464
#                 y: 558
#               }
#               vertices {
#                 x: 464
#                 y: 564
#               }
#               vertices {
#                 x: 461
#                 y: 564
#               }
#             }
#             text: "t"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#   }
#   text: "croffles\ncraffle (noun)\ncantades stuter,\nforest cafe menu\na hybrid mix of a croissant and affla\nteat, milk, soy may contain eye ata, sesame\nplain 4\nsogar glaze\nforest cafe menu\nsignature drink\nFOREST\nespresso\nLATTE\norganic maple syrup cinnamon milk\nour signature flavor\ncoffee & specialty drinks\nve ceston roast our own (arabical beans\nbrewed coffee-selise roast; notes of chocolate, almond, cherry\nexpress medios to dark roast; notes of cinnamon & brown sagar\ndecaf espresso medium to dark roast; notes of caramel\nbrewed coffee\ncold brew\nespresso\namericano\nmacchiato (traditional)\ncortado\ncappuccino\nflat white\nlatte\nmocha latte\nlavender latte\nvanilla latte\nube latte (purple yan)\nbeing and\nHOT\nICED\n6.00\n6.50\ntry foresting\nyour drink\n+1.25\n3.25\n4.75\n3.25\n3.75\n3.56\n4.08\n3.75\n4.25\n4.75\n4.15\n4.75\n5.50\n5.75\n6.25\n5.75\n6.25\n5.75\n6.25\n5.75\n6.25\n?\n6.25\n5.75\n6.25\n7.25\n7.75\ngrab\nsalted caramel latte\niced shakerato (shaken espresso over milk)\ndirty be latte (+ espresso)\nmatcha & hojicha\nespresso alternatives.\nnatcha\najic\norganic ceremonial grade graasd green tea leaves contains caffeine\norganic roasted green tea leaves; contains very\ncaffeine\npairs well with expresse, forested, or bath\nmatcha / hojicha latte (with milk)\nmatcha/hojicha americano (with water)\nLavender natcha / hojicha Latte\nlavender netcha/hajscha americano\nearth elixir\n5.35\n6.25\n5.25\n5.75\n6.50\n7.88\n6.00\n6.50\n6.30\n6.50\nother\nbabyccino (4 oz steaned milk)\n2.20\nhot chocolate\n4.75\nheeesade iced tea (sweetened black tea)\n4.00\nlondon fog rearl grey tea teased asik vanilla & leverder me\nhot teas\n5.08\n3.75\nnutella 6\ntopped with rice crispies\nseasonal croffle.\nask us about itf\n-n-go\ngochujang tamago sando 9.75\negs, ret pepper pete, kople mayonnaise, sugar, peppermi\nforest overnight oats 6.75\nset ala, eta, erganic ates, organic ate ne\nmatcha chia seed pudding 6.25\ncoconut milk, or this sek, organ winch, featuring seas an\nvegan and guten We contac\nprotein power bites 5.751\nvegan and gluten free contain\nmerch\nforest cafe tote bag 35\nwah friendly, y\n(berley, breakfast blend, chaalle lemon, earl grey, green, Jenice)\nкутер/sauce options\ncaffeine fr\nice option\nmilk options\nwole ar ski\nforest\n3.25\nA\n-\ndary asks\norganic sapte syne\nlander sn\nhow iced tea & cel\n9.75\n-9.75\nsc\ndark chocalate\n-8.75\ntra double st"
# }

# %%
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 res
#
# NameError: name 'res' is not defined

# %%
import pickle

if False: 
    with open("menu_dat.pkl", "wb") as file:
        pickle.dump(res, file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import pickle


with open("menu_dat.pkl", "rb") as file:
    loaded_data = pickle.load(file)

loaded_data
res = loaded_data

# %%
res
# Out:
# MenuData(sections=[MenuSection(section='signature drink', description='', items=[MenuItem(name='FOREST LATTE', description='espresso + organic maple syrup + cinnamon + milk. our signature flavor.', symbols=[], contains=None)]), MenuSection(section='coffee & specialty drinks', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', items=[MenuItem(name='brewed coffee', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=None), MenuItem(name='cold brew', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=None), MenuItem(name='espresso', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=None), MenuItem(name='americano', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=None), MenuItem(name='macchiato (traditional)', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=None), MenuItem(name='cortado', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=None), MenuItem(name='cappuccino', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=None), MenuItem(name='flat white', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=None), MenuItem(name='latte', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=None), MenuItem(name='mocha latte', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=None), MenuItem(name='salted caramel latte', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=None), MenuItem(name='lavender latte', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolat ...

# %%
from allergy_detector import detect_allergen, detect_allergens
from common.custom_types import SupportedAllergen

# detection = await detect_allergens(res, [SupportedAllergen.GLUTEN, SupportedAllergen.SHELLFISH])
detection = await detect_allergens(res, [SupportedAllergen.GLUTEN, SupportedAllergen.SHELLFISH, SupportedAllergen.TREE_NUTS])
# Out:
# START RESPONSE TEXT
# {
#   "sections": [
#     {
#       "section": "signature drink",
#       "description": "",
#       "items": [
#         {
#           "name": "FOREST LATTE",
#           "description": "espresso + organic maple syrup + cinnamon + milk. our signature flavor.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Standard coffee ingredients, maple syrup, cinnamon, and milk are naturally gluten-free."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "coffee & specialty drinks",
#       "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#       "items": [
#         {
#           "name": "brewed coffee",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Coffee beans and water are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "cold brew",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Coffee beans and water are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "espresso",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso (coffee) is naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "americano",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso and water are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "macchiato (traditional)",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso and milk are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "cortado",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso and milk are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "cappuccino",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso and milk are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "flat white",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso and milk are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "latte",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso and milk are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "mocha latte",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso, chocolate, and milk are naturally gluten-free ingredients."
#             }
#           ]
#         },
#         {
#           "name": "salted caramel latte",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso, milk, and standard salted caramel syrup are generally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "lavender latte",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso, milk, and standard lavender syrup are generally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "vanilla latte",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso, milk, and standard vanilla syrup are generally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "iced shakerato",
#           "description": "shaken espresso over milk. we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso and milk are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "ube latte (purple yam)",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso, milk, and ube (purple yam) are naturally gluten-free ingredients."
#             }
#           ]
#         },
#         {
#           "name": "dirty ube latte",
#           "description": "(+ espresso). we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso, milk, and ube (purple yam) are naturally gluten-free ingredients."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "matcha & hojicha",
#       "description": "matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#       "items": [
#         {
#           "name": "matcha / hojicha latte",
#           "description": "(with milk). matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Matcha/hojicha (green tea) and milk are naturally gluten-free ingredients."
#             }
#           ]
#         },
#         {
#           "name": "matcha / hojicha americano",
#           "description": "(with water). matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Matcha/hojicha (green tea) and water are naturally gluten-free ingredients."
#             }
#           ]
#         },
#         {
#           "name": "lavender matcha / hojicha latte",
#           "description": "matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Matcha/hojicha, milk, and standard lavender syrup are generally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "lavender matcha / hojicha americano",
#           "description": "matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Matcha/hojicha, water, and standard lavender syrup are generally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "earth elixir",
#           "description": "blend of mushroom, maca root, & adaptogenic powders with a dose of caffeine or without; recommended with oat milk and a pump of maple syrup. matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Mushroom, maca root, adaptogenic powders, oat milk, and maple syrup are generally gluten-free ingredients."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "other",
#       "description": "",
#       "items": [
#         {
#           "name": "babyccino",
#           "description": "4 oz steamed milk.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Steamed milk is naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "hot chocolate",
#           "description": "",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Hot chocolate typically consists of milk and cocoa/chocolate, which are generally gluten-free. No thickeners are explicitly mentioned."
#             }
#           ]
#         },
#         {
#           "name": "homemade iced tea",
#           "description": "sweetened black tea.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Tea and sugar are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "london fog",
#           "description": "earl grey tea + steamed milk + vanilla & lavender syrup.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Earl Grey tea, milk, and standard vanilla and lavender syrups are generally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "hot teas",
#           "description": "herbal, breakfast blend, chamomile lemon, earl grey, green, jasmine.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Various types of tea are naturally gluten-free."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "croffles",
#       "description": "croffle (noun) - a hybrid mix of a croissant and waffle. contains gluten, wheat, milk, soy | may contain egg, tree nuts, sesame.",
#       "items": [
#         {
#           "name": "plain",
#           "description": "sugar glaze. croffle (noun) - a hybrid mix of a croissant and waffle. contains gluten, wheat, milk, soy | may contain egg, tree nuts, sesame.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The section description explicitly states that croffles 'contains gluten, wheat'."
#             }
#           ]
#         },
#         {
#           "name": "nutella",
#           "description": "topped with rice crispies. croffle (noun) - a hybrid mix of a croissant and waffle. contains gluten, wheat, milk, soy | may contain egg, tree nuts, sesame.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The section description explicitly states that croffles 'contains gluten, wheat'. Nutella is generally gluten-free, but the base item is not."
#             }
#           ]
#         },
#         {
#           "name": "seasonal croffle",
#           "description": "ask us about it! croffle (noun) - a hybrid mix of a croissant and waffle. contains gluten, wheat, milk, soy | may contain egg, tree nuts, sesame.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The section description explicitly states that croffles 'contains gluten, wheat'."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "grab-n-go",
#       "description": "",
#       "items": [
#         {
#           "name": "gochujang tamago sando",
#           "description": "eggs, red pepper paste, kewpie mayonnaise, sugar, pepper on milk toast.",
#           "symbols": [
#             "VG"
#           ],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The item description explicitly mentions 'milk toast,' which is a common source of wheat/gluten."
#             }
#           ]
#         },
#         {
#           "name": "forest overnight oats",
#           "description": "oat milk, oats, organic maple syrup, cinnamon.",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "Oats are naturally gluten-free but are often subject to cross-contamination if not certified gluten-free. 'Oats' alone are ambiguous."
#             }
#           ]
#         },
#         {
#           "name": "matcha chia seed pudding",
#           "description": "coconut milk, organic chia seeds, organic matcha, featuring seasonal jam.",
#           "symbols": [
#             "GF",
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The item is marked 'GF' and all listed ingredients (coconut milk, chia seeds, matcha, jam) are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "protein power bites",
#           "description": "dates, cashews, dried cherries, coconut oil, cacao powder, pumpkin seeds, hemp seeds.",
#           "symbols": [
#             "GF",
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The item is marked 'GF' and all listed ingredients (dates, cashews, dried cherries, coconut oil, cacao powder, pumpkin seeds, hemp seeds) are naturally gluten-free."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "merch",
#       "description": "",
#       "items": [
#         {
#           "name": "forest cafe tote bag",
#           "description": "wash friendly, dry on low",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This is a non-food item and does not contain gluten."
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }
# END RESPONSE TEXT
# {
#   "sections": [
#     {
#       "section": "signature drink",
#       "description": "",
#       "items": [
#         {
#           "name": "FOREST LATTE",
#           "description": "espresso + organic maple syrup + cinnamon + milk. our signature flavor.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Standard coffee ingredients, maple syrup, cinnamon, and milk are naturally gluten-free."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "coffee & specialty drinks",
#       "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#       "items": [
#         {
#           "name": "brewed coffee",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Coffee beans and water are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "cold brew",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Coffee beans and water are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "espresso",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso (coffee) is naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "americano",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso and water are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "macchiato (traditional)",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso and milk are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "cortado",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso and milk are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "cappuccino",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso and milk are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "flat white",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso and milk are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "latte",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso and milk are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "mocha latte",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso, chocolate, and milk are naturally gluten-free ingredients."
#             }
#           ]
#         },
#         {
#           "name": "salted caramel latte",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso, milk, and standard salted caramel syrup are generally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "lavender latte",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso, milk, and standard lavender syrup are generally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "vanilla latte",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso, milk, and standard vanilla syrup are generally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "iced shakerato",
#           "description": "shaken espresso over milk. we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso and milk are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "ube latte (purple yam)",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso, milk, and ube (purple yam) are naturally gluten-free ingredients."
#             }
#           ]
#         },
#         {
#           "name": "dirty ube latte",
#           "description": "(+ espresso). we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso, milk, and ube (purple yam) are naturally gluten-free ingredients."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "matcha & hojicha",
#       "description": "matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#       "items": [
#         {
#           "name": "matcha / hojicha latte",
#           "description": "(with milk). matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Matcha/hojicha (green tea) and milk are naturally gluten-free ingredients."
#             }
#           ]
#         },
#         {
#           "name": "matcha / hojicha americano",
#           "description": "(with water). matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Matcha/hojicha (green tea) and water are naturally gluten-free ingredients."
#             }
#           ]
#         },
#         {
#           "name": "lavender matcha / hojicha latte",
#           "description": "matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Matcha/hojicha, milk, and standard lavender syrup are generally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "lavender matcha / hojicha americano",
#           "description": "matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Matcha/hojicha, water, and standard lavender syrup are generally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "earth elixir",
#           "description": "blend of mushroom, maca root, & adaptogenic powders with a dose of caffeine or without; recommended with oat milk and a pump of maple syrup. matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Mushroom, maca root, adaptogenic powders, oat milk, and maple syrup are generally gluten-free ingredients."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "other",
#       "description": "",
#       "items": [
#         {
#           "name": "babyccino",
#           "description": "4 oz steamed milk.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Steamed milk is naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "hot chocolate",
#           "description": "",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Hot chocolate typically consists of milk and cocoa/chocolate, which are generally gluten-free. No thickeners are explicitly mentioned."
#             }
#           ]
#         },
#         {
#           "name": "homemade iced tea",
#           "description": "sweetened black tea.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Tea and sugar are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "london fog",
#           "description": "earl grey tea + steamed milk + vanilla & lavender syrup.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Earl Grey tea, milk, and standard vanilla and lavender syrups are generally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "hot teas",
#           "description": "herbal, breakfast blend, chamomile lemon, earl grey, green, jasmine.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Various types of tea are naturally gluten-free."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "croffles",
#       "description": "croffle (noun) - a hybrid mix of a croissant and waffle. contains gluten, wheat, milk, soy | may contain egg, tree nuts, sesame.",
#       "items": [
#         {
#           "name": "plain",
#           "description": "sugar glaze. croffle (noun) - a hybrid mix of a croissant and waffle. contains gluten, wheat, milk, soy | may contain egg, tree nuts, sesame.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The section description explicitly states that croffles 'contains gluten, wheat'."
#             }
#           ]
#         },
#         {
#           "name": "nutella",
#           "description": "topped with rice crispies. croffle (noun) - a hybrid mix of a croissant and waffle. contains gluten, wheat, milk, soy | may contain egg, tree nuts, sesame.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The section description explicitly states that croffles 'contains gluten, wheat'. Nutella is generally gluten-free, but the base item is not."
#             }
#           ]
#         },
#         {
#           "name": "seasonal croffle",
#           "description": "ask us about it! croffle (noun) - a hybrid mix of a croissant and waffle. contains gluten, wheat, milk, soy | may contain egg, tree nuts, sesame.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The section description explicitly states that croffles 'contains gluten, wheat'."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "grab-n-go",
#       "description": "",
#       "items": [
#         {
#           "name": "gochujang tamago sando",
#           "description": "eggs, red pepper paste, kewpie mayonnaise, sugar, pepper on milk toast.",
#           "symbols": [
#             "VG"
#           ],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The item description explicitly mentions 'milk toast,' which is a common source of wheat/gluten."
#             }
#           ]
#         },
#         {
#           "name": "forest overnight oats",
#           "description": "oat milk, oats, organic maple syrup, cinnamon.",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "Oats are naturally gluten-free but are often subject to cross-contamination if not certified gluten-free. 'Oats' alone are ambiguous."
#             }
#           ]
#         },
#         {
#           "name": "matcha chia seed pudding",
#           "description": "coconut milk, organic chia seeds, organic matcha, featuring seasonal jam.",
#           "symbols": [
#             "GF",
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The item is marked 'GF' and all listed ingredients (coconut milk, chia seeds, matcha, jam) are naturally gluten-free."
#             }
#           ]
#         },
#         {
#           "name": "protein power bites",
#           "description": "dates, cashews, dried cherries, coconut oil, cacao powder, pumpkin seeds, hemp seeds.",
#           "symbols": [
#             "GF",
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The item is marked 'GF' and all listed ingredients (dates, cashews, dried cherries, coconut oil, cacao powder, pumpkin seeds, hemp seeds) are naturally gluten-free."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "merch",
#       "description": "",
#       "items": [
#         {
#           "name": "forest cafe tote bag",
#           "description": "wash friendly, dry on low",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "gluten",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This is a non-food item and does not contain gluten."
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }
# START RESPONSE TEXT
# {
#   "sections": [
#     {
#       "section": "signature drink",
#       "description": "",
#       "items": [
#         {
#           "name": "FOREST LATTE",
#           "description": "espresso + organic maple syrup + cinnamon + milk. our signature flavor.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The ingredients listed (espresso, maple syrup, cinnamon, milk) are naturally shellfish-free, and there is no indication of shellfish-derived ingredients or cross-contamination risk in a coffee beverage."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "coffee & specialty drinks",
#       "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#       "items": [
#         {
#           "name": "brewed coffee",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Coffee is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish."
#             }
#           ]
#         },
#         {
#           "name": "cold brew",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Cold brew coffee is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish."
#             }
#           ]
#         },
#         {
#           "name": "espresso",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Espresso is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish."
#             }
#           ]
#         },
#         {
#           "name": "americano",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Americano (espresso and hot water) is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish."
#             }
#           ]
#         },
#         {
#           "name": "macchiato (traditional)",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Macchiato (espresso with a dash of milk) is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish."
#             }
#           ]
#         },
#         {
#           "name": "cortado",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Cortado (espresso with steamed milk) is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish."
#             }
#           ]
#         },
#         {
#           "name": "cappuccino",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Cappuccino (espresso with steamed milk foam) is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish."
#             }
#           ]
#         },
#         {
#           "name": "flat white",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Flat white (espresso with finely textured milk) is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish."
#             }
#           ]
#         },
#         {
#           "name": "latte",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Latte (espresso with steamed milk) is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish."
#             }
#           ]
#         },
#         {
#           "name": "mocha latte",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Mocha latte (espresso, chocolate, milk) is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish."
#             }
#           ]
#         },
#         {
#           "name": "salted caramel latte",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
# ...
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "The description for the coffee notes 'almond' as a flavor profile. While this may not indicate actual almond ingredients, it suggests almond is part of the coffee experience in this establishment, and cross-contamination with almond products (e.g., almond milk, pastries) is a risk in a coffee shop environment."
#             }
#           ]
#         },
#         {
#           "name": "vanilla latte",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "The description for the coffee notes 'almond' as a flavor profile. While this may not indicate actual almond ingredients, it suggests almond is part of the coffee experience in this establishment, and cross-contamination with almond products (e.g., almond milk, pastries) is a risk in a coffee shop environment."
#             }
#           ]
#         },
#         {
#           "name": "iced shakerato",
#           "description": "shaken espresso over milk. we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "The description for the coffee notes 'almond' as a flavor profile. While this may not indicate actual almond ingredients, it suggests almond is part of the coffee experience in this establishment, and cross-contamination with almond products (e.g., almond milk, pastries) is a risk in a coffee shop environment."
#             }
#           ]
#         },
#         {
#           "name": "ube latte (purple yam)",
#           "description": "we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "The description for the coffee notes 'almond' as a flavor profile. While this may not indicate actual almond ingredients, it suggests almond is part of the coffee experience in this establishment, and cross-contamination with almond products (e.g., almond milk, pastries) is a risk in a coffee shop environment."
#             }
#           ]
#         },
#         {
#           "name": "dirty ube latte",
#           "description": "(+ espresso). we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "The description for the coffee notes 'almond' as a flavor profile. While this may not indicate actual almond ingredients, it suggests almond is part of the coffee experience in this establishment, and cross-contamination with almond products (e.g., almond milk, pastries) is a risk in a coffee shop environment."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "matcha & hojicha",
#       "description": "matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#       "items": [
#         {
#           "name": "matcha / hojicha latte",
#           "description": "(with milk). matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "This is a coffee shop beverage, and almond milk is a common alternative, posing a risk of cross-contamination. The 'coffee & specialty drinks' section also mentions 'notes of almond' in their coffee description, indicating almond flavors are present in the establishment's profile."
#             }
#           ]
#         },
#         {
#           "name": "matcha / hojicha americano",
#           "description": "(with water). matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "This is a coffee shop beverage, and almond milk is a common alternative, posing a risk of cross-contamination. The 'coffee & specialty drinks' section also mentions 'notes of almond' in their coffee description, indicating almond flavors are present in the establishment's profile."
#             }
#           ]
#         },
#         {
#           "name": "lavender matcha / hojicha latte",
#           "description": "matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "This is a coffee shop beverage, and almond milk is a common alternative, posing a risk of cross-contamination. The 'coffee & specialty drinks' section also mentions 'notes of almond' in their coffee description, indicating almond flavors are present in the establishment's profile."
#             }
#           ]
#         },
#         {
#           "name": "lavender matcha / hojicha americano",
#           "description": "matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "This is a coffee shop beverage, and almond milk is a common alternative, posing a risk of cross-contamination. The 'coffee & specialty drinks' section also mentions 'notes of almond' in their coffee description, indicating almond flavors are present in the establishment's profile."
#             }
#           ]
#         },
#         {
#           "name": "earth elixir",
#           "description": "blend of mushroom, maca root, & adaptogenic powders with a dose of caffeine or without; recommended with oat milk and a pump of maple syrup. matcha - organic ceremonial grade ground green tea leaves; contains caffeine. hojicha - organic roasted green tea leaves; contains very little caffeine. pairs well with espresso, frothed, or both.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "This is a coffee shop beverage, and while oat milk is recommended, almond milk is a common alternative in such establishments, posing a risk of cross-contamination. The 'coffee & specialty drinks' section also mentions 'notes of almond' in their coffee description, indicating almond flavors are present in the establishment's profile."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "other",
#       "description": "",
#       "items": [
#         {
#           "name": "babyccino",
#           "description": "4 oz steamed milk.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "This item contains steamed milk. Given that a coffee shop typically offers almond milk as a dairy alternative, there is a risk of cross-contamination in preparation."
#             }
#           ]
#         },
#         {
#           "name": "hot chocolate",
#           "description": "",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "Hot chocolate can be made with various milks, including almond milk. Also, the establishment's overall context suggests the presence of tree nut products (e.g., 'notes of almond' in coffee, croffles section warning)."
#             }
#           ]
#         },
#         {
#           "name": "homemade iced tea",
#           "description": "sweetened black tea.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The item is a simple black tea with sugar, which does not naturally contain tree nuts. It has a low risk of direct contamination, although cross-contamination in the kitchen is always a possibility in a mixed-use environment."
#             }
#           ]
#         },
#         {
#           "name": "london fog",
#           "description": "earl grey tea + steamed milk + vanilla & lavender syrup.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "This item contains steamed milk. Given that a coffee shop typically offers almond milk as a dairy alternative, there is a risk of cross-contamination in preparation."
#             }
#           ]
#         },
#         {
#           "name": "hot teas",
#           "description": "herbal, breakfast blend, chamomile lemon, earl grey, green, jasmine.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The item is plain hot tea, which does not naturally contain tree nuts. It has a low risk of direct contamination, although cross-contamination in the kitchen is always a possibility in a mixed-use environment."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "croffles",
#       "description": "croffle (noun) - a hybrid mix of a croissant and waffle. contains gluten, wheat, milk, soy | may contain egg, tree nuts, sesame.",
#       "items": [
#         {
#           "name": "plain",
#           "description": "sugar glaze. croffle (noun) - a hybrid mix of a croissant and waffle. contains gluten, wheat, milk, soy | may contain egg, tree nuts, sesame.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "The section description explicitly states that croffles 'may contain tree nuts', indicating a risk of cross-contamination or shared ingredients in their preparation."
#             }
#           ]
#         },
#         {
#           "name": "nutella",
#           "description": "topped with rice crispies. croffle (noun) - a hybrid mix of a croissant and waffle. contains gluten, wheat, milk, soy | may contain egg, tree nuts, sesame.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_LIKELY",
#               "explanation": "Nutella is a hazelnut spread, making this dish explicitly contain tree nuts. The section description also warns that croffles 'may contain tree nuts'."
#             }
#           ]
#         },
#         {
#           "name": "seasonal croffle",
#           "description": "ask us about it! croffle (noun) - a hybrid mix of a croissant and waffle. contains gluten, wheat, milk, soy | may contain egg, tree nuts, sesame.",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "The section description explicitly states that croffles 'may contain tree nuts', indicating a risk of cross-contamination or shared ingredients in their preparation. A seasonal flavor could also potentially include tree nuts."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "grab-n-go",
#       "description": "",
#       "items": [
#         {
#           "name": "gochujang tamago sando",
#           "description": "eggs, red pepper paste, kewpie mayonnaise, sugar, pepper on milk toast.",
#           "symbols": [
#             "VG"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The ingredients listed do not contain tree nuts. While cross-contamination is always a minor risk in any establishment, this specific item does not present any high-risk factors."
#             }
#           ]
#         },
#         {
#           "name": "forest overnight oats",
#           "description": "oat milk, oats, organic maple syrup, cinnamon.",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "Overnight oats often feature nuts or nut-based granola. Although not listed, the general risk in a coffee shop setting (e.g., shared equipment, toppings from bins) makes cross-contamination plausible."
#             }
#           ]
#         },
#         {
#           "name": "matcha chia seed pudding",
#           "description": "coconut milk, organic chia seeds, organic matcha, featuring seasonal jam.",
#           "symbols": [
#             "GF",
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "This is a grab-and-go item from a facility that handles tree nuts (indicated by the croffles section and coffee notes). Such items can be subject to cross-contamination, especially if made in a shared kitchen or if nuts are used as garnishes for similar items."
#             }
#           ]
#         },
#         {
#           "name": "protein power bites",
#           "description": "dates, cashews, dried cherries, coconut oil, cacao powder, pumpkin seeds, hemp seeds.",
#           "symbols": [
#             "GF",
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The description explicitly lists 'cashews', which are a type of tree nut."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "merch",
#       "description": "",
#       "items": [
#         {
#           "name": "forest cafe tote bag",
#           "description": "wash friendly, dry on low",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This item is merchandise (a tote bag) and is not a food product; therefore, it contains no food allergens."
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }

# %%
import pickle

if False:
    with open("shellfish_dat.pkl", "wb") as file:
        pickle.dump(detection, file, protocol=pickle.HIGHEST_PROTOCOL)

if False:
    with open("glu_and_shel_dat.pkl", "wb") as file:
        pickle.dump(detection, file, protocol=pickle.HIGHEST_PROTOCOL)

if True:
    with open("nut_glu_and_shel_dat.pkl", "wb") as file:
        pickle.dump(detection, file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import pickle

with open("nut_glu_and_shel_dat.pkl", "rb") as file:
    loaded_data = pickle.load(file)

detection = loaded_data

# %%
detection
# Out:
# {<SupportedAllergen.GLUTEN: 'gluten'>: LabeledAllergenMenu(sections=[MenuSection(section='signature drink', description='', items=[MenuItem(name='FOREST LATTE', description='espresso + organic maple syrup + cinnamon + milk. our signature flavor.', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Standard coffee ingredients, maple syrup, cinnamon, and milk are naturally gluten-free.')])]), MenuSection(section='coffee & specialty drinks', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', items=[MenuItem(name='brewed coffee', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Coffee beans and water are naturally gluten-free.')]), MenuItem(name='cold brew', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Coffee beans and water are naturally gluten-free.')]), MenuItem(name='espresso', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Espresso (coffee) is naturally gluten-free.')]), MenuItem(name='americano', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Espresso and water are naturally gluten-free.')]), MenuItem(name='macchiato (traditional)', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Espresso and milk are naturally gluten-free.')]), MenuItem(name='cortado', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Espresso and milk are naturally gluten-free.')]), MenuItem(name='cappuccino', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Espresso and milk are naturally gluten-free.')]), MenuItem(name='flat white', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes  ...
#  <SupportedAllergen.SHELLFISH: 'shellfish'>: LabeledAllergenMenu(sections=[MenuSection(section='signature drink', description='', items=[MenuItem(name='FOREST LATTE', description='espresso + organic maple syrup + cinnamon + milk. our signature flavor.', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='The ingredients listed (espresso, maple syrup, cinnamon, milk) are naturally shellfish-free, and there is no indication of shellfish-derived ingredients or cross-contamination risk in a coffee beverage.')])]), MenuSection(section='coffee & specialty drinks', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', items=[MenuItem(name='brewed coffee', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='Coffee is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish.')]), MenuItem(name='cold brew', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='Cold brew coffee is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish.')]), MenuItem(name='espresso', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='Espresso is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish.')]), MenuItem(name='americano', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='Americano (espresso and hot water) is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish.')]), MenuItem(name='macchiato (traditional)', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='Macchiato (espresso with a dash of milk) is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish.')]), MenuItem(name='cortado', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='Cortado (espresso with steamed milk) is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish.')]), ...
#  <SupportedAllergen.TREE_NUTS: 'tree_nuts'>: LabeledAllergenMenu(sections=[MenuSection(section='signature drink', description='', items=[MenuItem(name='FOREST LATTE', description='espresso + organic maple syrup + cinnamon + milk. our signature flavor.', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='MAY_CONTAIN', explanation="While no explicit tree nuts are listed in the ingredients, this is a coffee shop beverage where almond milk is a common alternative, posing a risk of cross-contamination. The 'coffee & specialty drinks' section also mentions 'notes of almond' in their coffee description, indicating almond flavors are present in the establishment's profile.")])]), MenuSection(section='coffee & specialty drinks', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', items=[MenuItem(name='brewed coffee', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='MAY_CONTAIN', explanation="The description for the coffee notes 'almond' as a flavor profile. While this may not indicate actual almond ingredients, it suggests almond is part of the coffee experience in this establishment, and cross-contamination with almond products (e.g., almond milk, pastries) is a risk in a coffee shop environment.")]), MenuItem(name='cold brew', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='MAY_CONTAIN', explanation="The description for the coffee notes 'almond' as a flavor profile. While this may not indicate actual almond ingredients, it suggests almond is part of the coffee experience in this establishment, and cross-contamination with almond products (e.g., almond milk, pastries) is a risk in a coffee shop environment.")]), MenuItem(name='espresso', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='MAY_CONTAIN', explanation="The description for the coffee notes 'almond' as a flavor profile. While this may not indicate actual almond ingredients, it suggests almond is part of the coffee experience in this establishment, and cross-contamination with almond products (e.g., almond milk, pastries) is a risk in a coffee shop environment.")]), MenuItem(name='americano', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='MAY_CONTAIN', explanation="The description for the coffee notes 'almond' as a flavor profile. While this may not indicate actual almond ingredients, it suggests almond is part of the coffee experience in this establishment, and cross-contamination with almond products (e.g., almond milk, pastries) is a risk in a coffee shop environment.")]), MenuItem(name='macchiato (traditional)', description='we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown s ...

# %%
from allergy_detector import aggregate_allergies

agg = aggregate_allergies(detection)

# %%
print(agg.model_dump())
# Out:
# {'sections': [{'section': 'signature drink', 'description': '', 'items': [{'name': 'FOREST LATTE', 'description': 'espresso + organic maple syrup + cinnamon + milk. our signature flavor.', 'symbols': [], 'contains': [{'allergen': 'gluten', 'prediction': 'VERY_UNLIKELY', 'explanation': 'Standard coffee ingredients, maple syrup, cinnamon, and milk are naturally gluten-free.'}, {'allergen': 'shellfish', 'prediction': 'VERY_UNLIKELY', 'explanation': 'The ingredients listed (espresso, maple syrup, cinnamon, milk) are naturally shellfish-free, and there is no indication of shellfish-derived ingredients or cross-contamination risk in a coffee beverage.'}, {'allergen': 'tree_nuts', 'prediction': 'MAY_CONTAIN', 'explanation': "While no explicit tree nuts are listed in the ingredients, this is a coffee shop beverage where almond milk is a common alternative, posing a risk of cross-contamination. The 'coffee & specialty drinks' section also mentions 'notes of almond' in their coffee description, indicating almond flavors are present in the establishment's profile."}]}]}, {'section': 'coffee & specialty drinks', 'description': 'we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', 'items': [{'name': 'brewed coffee', 'description': 'we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', 'symbols': [], 'contains': [{'allergen': 'gluten', 'prediction': 'VERY_UNLIKELY', 'explanation': 'Coffee beans and water are naturally gluten-free.'}, {'allergen': 'shellfish', 'prediction': 'VERY_UNLIKELY', 'explanation': 'Coffee is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish.'}, {'allergen': 'tree_nuts', 'prediction': 'MAY_CONTAIN', 'explanation': "The description for the coffee notes 'almond' as a flavor profile. While this may not indicate actual almond ingredients, it suggests almond is part of the coffee experience in this establishment, and cross-contamination with almond products (e.g., almond milk, pastries) is a risk in a coffee shop environment."}]}, {'name': 'cold brew', 'description': 'we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', 'symbols': [], 'contains': [{'allergen': 'gluten', 'prediction': 'VERY_UNLIKELY', 'explanation': 'Coffee beans and water are naturally gluten-free.'}, {'allergen': 'shellfish', 'prediction': 'VERY_UNLIKELY', 'explanation': 'Cold brew coffee is naturally shellfish-free, and there are no ingredients or preparation methods that would introduce shellfish.'}, {'allergen': 'tree_nuts', 'prediction': 'MAY_CONTAIN', 'explanation': "The description for the coffee notes 'almond' as a flavor profile. While this may not indicate actual almond ingredients, it suggests almond is part of the coffee experience in this establishment, and cross-contamination with almond products (e.g., almond milk, pastries) is a risk in a coffee shop environment."}]}, {'name': 'espresso', 'description': 'we custom roast our own (arabica) beans. brewed coffee - medium roast; notes of chocolate, almond, cherry. cold brew - medium to dark roast; notes of cinnamon & brown sugar. decaf espresso - medium to dark roast; notes of caramel.', 'symbols': [], 'contains': [{'allergen': 'gluten', 'prediction': 'VERY_UNLIKELY', 'explanation': 'Espresso (coffee) is naturally gluten-free.'}, {'allergen': 'shellfish', 'prediction': 'VERY_UNLIKELY', 'explanation': 'Espresso is naturally shellfish-free, and there are no ingredients or preparation methods that would introduc ...

# %% [markdown]
# # Non-Example

# %%
# Non example
non_example = "https://businesssignsandmore.com/cdn/shop/files/salon-menu-board-price-list-341568.jpg?v=1742056416&width=1445"
bb, mime = fetch_image_as_base64(non_example)
non_example_img = ImageData(base64=bb, mime_type=mime)
non_example_img
# Out:
# ImageData(base64=b'\xff\xd8\xff\xe1\x00\xbcExif\x00\x00II*\x00\x08\x00\x00\x00\x06\x00\x12\x01\x03\x00\x01\x00\x00\x00\x01\x00\x00\x00\x1a\x01\x05\x00\x01\x00\x00\x00V\x00\x00\x00\x1b\x01\x05\x00\x01\x00\x00\x00^\x00\x00\x00(\x01\x03\x00\x01\x00\x00\x00\x02\x00\x00\x00\x13\x02\x03\x00\x01\x00\x00\x00\x01\x00\x00\x00i\x87\x04\x00\x01\x00\x00\x00f\x00\x00\x00\x00\x00\x00\x00H\x00\x00\x00\x01\x00\x00\x00H\x00\x00\x00\x01\x00\x00\x00\x06\x00\x00\x90\x07\x00\x04\x00\x00\x000210\x01\x91\x07\x00\x04\x00\x00\x00\x01\x02\x03\x00\x00\xa0\x07\x00\x04\x00\x00\x000100\x01\xa0\x03\x00\x01\x00\x00\x00\xff\xff\x00\x00\x02\xa0\x04\x00\x01\x00\x00\x00\xa5\x05\x00\x00\x03\xa0\x04\x00\x01\x00\x00\x00\xb4\x04\x00\x00\x00\x00\x00\x00\xff\xe2\x01\xb8ICC_PROFILE\x00\x01\x01\x00\x00\x01\xa8lcms\x02\x10\x00\x00mntrRGB XYZ \x07\xdc\x00\x01\x00\x19\x00\x03\x00)\x009acspAPPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-lcms\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\tdesc\x00\x00\x00\xf0\x00\x00\x00_cprt\x00\x00\x01L\x00\x00\x00\x0cwtpt\x00\x00\x01X\x00\x00\x00\x14rXYZ\x00\x00\x01l\x00\x00\x00\x14gXYZ\x00\x00\x01\x80\x00\x00\x00\x14bXYZ\x00\x00\x01\x94\x00\x00\x00\x14rTRC\x00\x00\x01\x0c\x00\x00\x00@gTRC\x00\x00\x01\x0c\x00\x00\x00@bTRC\x00\x00\x01\x0c\x00\x00\x00@desc\x00\x00\x00\x00\x00\x00\x00\x05c2ci\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00curv\x00\x00\x00\x00\x00\x00\x00\x1a\x00\x00\x00\xcb\x01\xc9\x03c\x05\x92\x08k\x0b\xf6\x10?\x15Q\x1b4!\xf1)\x902\x18;\x92F\x05Qw]\xedkpz\x05\x89\xb1\x9a|\xaci\xbf}\xd3\xc3\xe90\xff\xfftext\x00\x00\x00\x00CC0\x00XYZ \x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-XYZ \x00\x00\x00\x00\x00\x00o\xa2\x00\x008\xf5\x00\x00\x03\x90XYZ \x00\x00\x00\x00\x00\x00b\x99\x00\x00\xb7\x85\x00\x00\x18\xdaXYZ \x00\x00\x00\x00\x00\x00$\xa0\x00\x00\x0f\x84\x00\x00\xb6\xcf\xff\xdb\x00C\x00\x05\x05\x05\x05\x05\x05\x05\x06\x06\x05\x08\x08\x07\x08\x08\x0b\n\t\t\n\x0b\x11\x0c\r\x0c\r\x0c\x11\x1a\x10\x13\x10\x10\x13\x10\x1a\x17\x1b\x16\x15\x16\x1b\x17) \x1c\x1c )/\'%\'/9339GDG]]}\xff\xdb\x00C\x01\x05\x05\x05\x05\x05\x05\x05\x06\x06\x05\x08\x08\x07\x08\x08\x0b\n\t\t\n\x0b\x11\x0c\r\x0c\r\x0c\x11\x1a\x10\x13\x10\x10\x13\x10\x1a\x17\x1b\x16\x15\x16\x1b\x17) \x1c\x1c )/\'%\'/9339GDG]]}\xff\xc2\x00\x11\x08\x04\xb4\x05\xa5\x03\x01\x11\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x03\x00\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\xff\xc4\x00\x19\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\xff\xda\x00\x0c\x03\x01\x00\x02\x10\x03\x10\x00\x00\x00\xfcs\x900\x00\x00\x18\x80\x00\x00\x00B\x10\x00\x00\x80\x00\x06 \x18\x80\x06!\x80\x00\x00\x06\x80\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0c\x00`\x03\x00\x00\x00(\x06\x000\x01\x8e\x8a`\x03\x18\x0c\x00`1\x8e\x98\xc60\x01\x94f\\\x8b\x98\xcd\x19V\xc8Xf\t\xb2\t\x91\x121Di$\x90"D&R\x8a\x81\x12\x13H@H\x00\x00\x841\x00\x80@\x00\x01\x902J\x10\x00\x86\x00\x02\x18\x0c\x06kd\x86\x03\x00\x00\x00\x01\x88\x00`@\x86!\x00\x00\x00\x00\xa8\x86 \x18\x00\x86\x02\x18\x0cZ\x03\x00\x10\x00\xc0\x00@\x03\x10\xc0`\x00\x03\x00\x18\x00\xc41\x88`0\x18\x01B\xa7@\xc0`\x03\x02\x86!\x81Z\x10\x0c`1\x19L\x8b\x95rVH\xa8d\x11H\x11"\xa8\x89\x1c\x02\xa4H\x84H\x92R@\x05JU\x9a\x05\x02\x10\xc4 \x10\xc9\x10\xc0B(\x90\x1eJ\x1d!\x80\x00\x00\x08`\x03\x00\x11\x82\x1c\x001\x00\x0c@0\x10\x00\x08B\x01\x88\x00@\x00\x02\x18\x00\x00\x00\x00\x80`!\xe8\x00\x86\x00\x001\x00\x00\x0c\x00\x00\x06!\x80\xc0\x06\x001\x0cc\x01\x00\xc61\x85(t\x0e\x81\x80\xc0\xa0\x00\x19A@\xc0\x06#9FB\xd5\xab\xa0\x91@\x82\x00A"\xa7\x08\x04\x04\x88\x94\x90%\x00\xa9\x94\x94\x10\x00\x84\x00 \x10\x80b\x00\x00\x10@\x10\x0c\x00\x92\x841\x80\x86\x00\x04\x98\xf2C\x10\xc0@\x00\x03\x10\x00\x00\x08@!\x88\x00C\x00\x01\x00\x00\n\x9c\x02\x18\x86 \x1e\x8 ...

# %%
from menu_reader import read_menu

res = read_menu(non_example_img)
# Out:
# text_annotations {
#   locale: "en"
#   description: "Single Sessions\nMENU\nMonthly Unlimited\nBuy 5 Get 2 Free\nRegular Bed\n$7.70\nRegular Bed\n$44\nRegular Bed\n$38.50\nRegular Bed with Facial\n$8.80\nRegular Bed with Facials\n$49.50\nRegular Bed with Facial\n$44\nSolaris Level 2\n$12.10\nSolaris Level 2\n$66\nSolaris Level 2\n$60.50\nSolar Force Level 3\n$15.40\nSolar Force Level 3\nSolar Force Level 3\n$77\n$77\nSunScape Level 4\n$19.80\nSunscape Level 4\n$99\nSunscape Level 4\n$99\nRed Light Therapy\n$25.00\nRed Light Therapy\nMystic Spray Tan\n$178\n$99\nHaloSauna\n$25.00\n*2 months\n$150\nBuy Minutes Get Minutes\nMystic Spray Tan\n$35.60+\n*Add-On to any monthly pkg\n$20\nBuy 50 get 20 FREE\n$77\nHaloSauna\n$70\nBuy 75 get 30 FREE\n$115.50\nWeekly Sessions\n*Add-on HaloSauna to any Monthly\n$20\nBuy 100 get 40 FREE\n$154\nMystic Spray Tan (4 max)\n$99\nHaloSauna Unlimited\n$50\nBuy 150 get 70 FREE\n$231\nAll Access UV+RLT+Halo\n$170\nHybrid UV+RLT Unlimited\n$50\nBuy 200 get 100 FREE\n$308\n*2 months\n*All prices include 10% tan tax\n*Packages expire after one year"
#   bounding_poly {
#     vertices {
#       x: 121
#       y: 221
#     }
#     vertices {
#       x: 1371
#       y: 221
#     }
#     vertices {
#       x: 1371
#       y: 942
#     }
#     vertices {
#       x: 121
#       y: 942
#     }
#   }
# }
# text_annotations {
#   description: "Single"
#   bounding_poly {
#     vertices {
#       x: 225
#       y: 326
#     }
#     vertices {
#       x: 292
#       y: 325
#     }
#     vertices {
#       x: 292
#       y: 350
#     }
#     vertices {
#       x: 225
#       y: 351
#     }
#   }
# }
# text_annotations {
#   description: "Sessions"
#   bounding_poly {
#     vertices {
#       x: 296
#       y: 325
#     }
#     vertices {
#       x: 382
#       y: 324
#     }
#     vertices {
#       x: 382
#       y: 349
#     }
#     vertices {
#       x: 296
#       y: 350
#     }
#   }
# }
# text_annotations {
#   description: "MENU"
#   bounding_poly {
#     vertices {
#       x: 600
#       y: 221
#     }
#     vertices {
#       x: 871
#       y: 227
#     }
#     vertices {
#       x: 870
#       y: 292
#     }
#     vertices {
#       x: 599
#       y: 286
#     }
#   }
# }
# text_annotations {
#   description: "Monthly"
#   bounding_poly {
#     vertices {
#       x: 679
#       y: 338
#     }
#     vertices {
#       x: 765
#       y: 337
#     }
#     vertices {
#       x: 765
#       y: 364
#     }
#     vertices {
#       x: 679
#       y: 365
#     }
#   }
# }
# text_annotations {
#   description: "Unlimited"
#   bounding_poly {
#     vertices {
#       x: 768
#       y: 337
#     }
#     vertices {
#       x: 868
#       y: 335
#     }
#     vertices {
#       x: 868
#       y: 362
#     }
#     vertices {
#       x: 768
#       y: 364
#     }
#   }
# }
# text_annotations {
#   description: "Buy"
#   bounding_poly {
#     vertices {
#       x: 1106
#       y: 346
#     }
#     vertices {
#       x: 1144
#       y: 345
#     }
#     vertices {
#       x: 1144
#       y: 368
#     }
#     vertices {
#       x: 1106
#       y: 369
#     }
#   }
# }
# text_annotations {
#   description: "5"
#   bounding_poly {
#     vertices {
#       x: 1149
#       y: 346
#     }
#     vertices {
#       x: 1162
#       y: 346
#     }
#     vertices {
#       x: 1162
#       y: 368
#     }
#     vertices {
#       x: 1149
#       y: 368
#     }
#   }
# }
# text_annotations {
#   description: "Get"
#   bounding_poly {
#     vertices {
#       x: 1165
#       y: 345
#     }
#     vertices {
#       x: 1197
#       y: 345
#     }
#     vertices {
#       x: 1197
#       y: 368
#     }
#     vertices {
#       x: 1165
#       y: 368
#     }
#   }
# }
# text_annotations {
#   description: "2"
#   bounding_poly {
#     vertices {
#       x: 1201
#       y: 345
#     }
#     vertices {
#       x: 1212
#       y: 345
#     }
#     vertices {
#       x: 1212
#       y: 367
#     }
#     vertices {
#       x: 1201
#       y: 367
#     }
#   }
# }
# text_annotations {
#   description: "Free"
#   bounding_poly {
#     vertices {
#       x: 1217
#       y: 344
#     }
#     vertices {
#       x: 1260
#       y: 343
#     }
#     vertices {
#       x: 1260
#       y: 366
#     }
#     vertices {
#       x: 1217
#       y: 367
#     }
#   }
# }
# text_annotations {
#   description: "Regular"
#   bounding_poly {
#     vertices {
#       x: 121
#       y: 368
#     }
#     vertices {
#       x: 194
#       y: 367
#     }
#     vertices {
#       x: 194
#       y: 386
#     }
#     vertices {
#       x: 121
#       y: 387
#     }
#   }
# }
# text_annotations {
#   description: "Bed"
#   bounding_poly {
#     vertices {
#       x: 198
#       y: 367
#     }
#     vertices {
#       x: 233
#       y: 366
#     }
#     vertices {
#       x: 233
#       y: 384
#     }
#     vertices {
#       x: 198
#       y: 385
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 418
#       y: 373
#     }
#     vertices {
#       x: 428
#       y: 373
#     }
#     vertices {
#       x: 427
#       y: 390
#     }
#     vertices {
#       x: 417
#       y: 390
#     }
#   }
# }
# text_annotations {
#   description: "7.70"
#   bounding_poly {
#     vertices {
#       x: 430
#       y: 373
#     }
#     vertices {
#       x: 469
#       y: 375
#     }
#     vertices {
#       x: 468
#       y: 392
#     }
#     vertices {
#       x: 429
#       y: 390
#     }
#   }
# }
# text_annotations {
#   description: "Regular"
#   bounding_poly {
#     vertices {
#       x: 585
#       y: 379
#     }
#     vertices {
#       x: 654
#       y: 377
#     }
#     vertices {
#       x: 655
#       y: 397
#     }
#     vertices {
#       x: 586
#       y: 399
#     }
#   }
# }
# text_annotations {
#   description: "Bed"
#   bounding_poly {
#     vertices {
#       x: 657
#       y: 377
#     }
#     vertices {
#       x: 690
#       y: 376
#     }
#     vertices {
#       x: 691
#       y: 396
#     }
#     vertices {
#       x: 658
#       y: 397
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 850
#       y: 383
#     }
#     vertices {
#       x: 861
#       y: 383
#     }
#     vertices {
#       x: 861
#       y: 400
#     }
#     vertices {
#       x: 850
#       y: 400
#     }
#   }
# }
# text_annotations {
#   description: "44"
#   bounding_poly {
#     vertices {
#       x: 861
#       y: 383
#     }
#     vertices {
#       x: 884
#       y: 383
#     }
#     vertices {
#       x: 884
#       y: 400
#     }
#     vertices {
#       x: 861
#       y: 400
#     }
#   }
# }
# text_annotations {
#   description: "Regular"
#   bounding_poly {
#     vertices {
#       x: 1026
#       y: 386
#     }
#     vertices {
#       x: 1091
#       y: 384
#     }
#     vertices {
#       x: 1091
#       y: 403
#     }
#     vertices {
#       x: 1026
#       y: 405
#     }
#   }
# }
# text_annotations {
#   description: "Bed"
#   bounding_poly {
#     vertices {
#       x: 1096
#       y: 385
#     }
#     vertices {
#       x: 1128
#       y: 384
#     }
#     vertices {
#       x: 1128
#       y: 402
#     }
#     vertices {
#       x: 1096
#       y: 403
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 1296
#       y: 388
#     }
#     vertices {
#       x: 1305
#       y: 388
#     }
#     vertices {
#       x: 1305
#       y: 403
#     }
#     vertices {
#       x: 1296
#       y: 403
#     }
#   }
# }
# text_annotations {
#   description: "38.50"
#   bounding_poly {
#     vertices {
#       x: 1307
#       y: 387
#     }
#     vertices {
#       x: 1353
#       y: 388
#     }
#     vertices {
#       x: 1353
#       y: 404
#     }
#     vertices {
#       x: 1307
#       y: 403
#     }
#   }
# }
# text_annotations {
#   description: "Regular"
#   bounding_poly {
#     vertices {
#       x: 122
#       y: 410
#     }
#     vertices {
#       x: 194
#       y: 410
#     }
#     vertices {
#       x: 194
#       y: 429
#     }
#     vertices {
#       x: 122
#       y: 429
#     }
#   }
# }
# text_annotations {
#   description: "Bed"
#   bounding_poly {
#     vertices {
#       x: 199
#       y: 410
#     }
#     vertices {
#       x: 233
#       y: 410
#     }
#     vertices {
#       x: 233
#       y: 429
#     }
#     vertices {
#       x: 199
#       y: 429
#     }
#   }
# }
# text_annotations {
#   description: "with"
#   bounding_poly {
#     vertices {
#       x: 239
#       y: 410
#     }
#     vertices {
#       x: 278
#       y: 410
#     }
#     vertices {
#       x: 278
#       y: 429
#     }
#     vertices {
#       x: 239
#       y: 429
#     }
#   }
# }
# text_annotations {
#   description: "Facial"
#   bounding_poly {
#     vertices {
#       x: 285
#       y: 410
#     }
#     vertices {
#       x: 339
#       y: 410
#     }
#     vertices {
#       x: 339
#       y: 429
#     }
#     vertices {
#       x: 285
#       y: 429
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 418
#       y: 415
#     }
#     vertices {
#       x: 428
#       y: 415
#     }
#     vertices {
#       x: 428
#       y: 432
#     }
#     vertices {
#       x: 418
#       y: 432
#     }
#   }
# }
# text_annotations {
#   description: "8.80"
#   bounding_poly {
#     vertices {
#       x: 430
#       y: 415
#     }
#     vertices {
#       x: 469
#       y: 415
#     }
#     vertices {
#       x: 469
#       y: 432
#     }
#     vertices {
#       x: 430
#       y: 432
#     }
#   }
# }
# text_annotations {
#   description: "Regular"
#   bounding_poly {
#     vertices {
#       x: 586
#       y: 420
#     }
#     vertices {
#       x: 654
#       y: 420
#     }
#     vertices {
#       x: 654
#       y: 438
#     }
#     vertices {
#       x: 586
#       y: 438
#     }
#   }
# }
# text_annotations {
#   description: "Bed"
#   bounding_poly {
#     vertices {
#       x: 659
#       y: 420
#     }
#     vertices {
#       x: 692
#       y: 420
#     }
#     vertices {
#       x: 692
#       y: 438
#     }
#     vertices {
#       x: 659
#       y: 438
#     }
#   }
# }
# text_annotations {
#   description: "with"
#   bounding_poly {
#     vertices {
#       x: 697
#       y: 420
#     }
#     vertices {
#       x: 734
#       y: 420
#     }
#     vertices {
#       x: 734
#       y: 438
#     }
#     vertices {
#       x: 697
#       y: 438
#     }
#   }
# }
# text_annotations {
#   description: "Facials"
#   bounding_poly {
#     vertices {
#       x: 740
#       y: 420
#     }
#     vertices {
#       x: 800
#       y: 420
#     }
#     vertices {
#       x: 800
#       y: 438
#     }
#     vertices {
#       x: 740
#       y: 438
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 850
#       y: 424
#     }
#     vertices {
#       x: 861
#       y: 424
#     }
#     vertices {
#       x: 861
#       y: 440
#     }
#     vertices {
#       x: 850
#       y: 440
#     }
#   }
# }
# text_annotations {
#   description: "49.50"
#   bounding_poly {
#     vertices {
#       x: 861
#       y: 424
#     }
#     vertices {
#       x: 910
#       y: 424
#     }
#     vertices {
#       x: 910
#       y: 440
#     }
#     vertices {
#       x: 861
#       y: 440
#     }
#   }
# }
# text_annotations {
#   description: "Regular"
#   bounding_poly {
#     vertices {
#       x: 1027
#       y: 422
#     }
#     vertices {
#       x: 1090
#       y: 422
#     }
#     vertices {
#       x: 1090
#       y: 441
#     }
#     vertices {
#       x: 1027
#       y: 441
#     }
#   }
# }
# text_annotations {
#   description: "Bed"
#   bounding_poly {
#     vertices {
#       x: 1096
#       y: 422
#     }
#     vertices {
#       x: 1127
#       y: 422
#     }
#     vertices {
#       x: 1127
#       y: 440
#     }
#     vertices {
#       x: 1096
#       y: 440
#     }
#   }
# }
# text_annotations {
#   description: "with"
#   bounding_poly {
#     vertices {
#       x: 1132
#       y: 422
#     }
#     vertices {
#       x: 1167
#       y: 422
#     }
#     vertices {
#       x: 1167
#       y: 440
#     }
#     vertices {
#       x: 1132
#       y: 440
#     }
#   }
# }
# text_annotations {
#   description: "Facial"
#   bounding_poly {
#     vertices {
#       x: 1174
#       y: 421
#     }
#     vertices {
#       x: 1222
#       y: 421
#     }
#     vertices {
#       x: 1222
#       y: 440
#     }
#     vertices {
#       x: 1174
#       y: 440
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 1296
#       y: 425
#     }
#     vertices {
#       x: 1306
#       y: 425
#     }
#     vertices {
#       x: 1306
#       y: 441
#     }
#     vertices {
#       x: 1296
#       y: 441
#     }
#   }
# }
# text_annotations {
#   description: "44"
#   bounding_poly {
#     vertices {
#       x: 1306
#       y: 425
#     }
#     vertices {
#       x: 1328
#       y: 425
#     }
#     vertices {
#       x: 1328
#       y: 441
#     }
#     vertices {
#       x: 1306
#       y: 441
#     }
#   }
# }
# text_annotations {
#   description: "Solaris"
#   bounding_poly {
#     vertices {
#       x: 122
#       y: 449
#     }
#     vertices {
#       x: 185
#       y: 450
#     }
#     vertices {
#       x: 185
#       y: 468
#     }
#     vertices {
#       x: 122
#       y: 467
#     }
#   }
# }
# text_annotations {
#   description: "Level"
#   bounding_poly {
#     vertices {
#       x: 192
#       y: 450
#     }
#     vertices {
#       x: 240
#       y: 451
#     }
#     vertices {
#       x: 240
#       y: 469
#     }
#     vertices {
#       x: 192
#       y: 468
#     }
#   }
# }
# text_annotations {
#   description: "2"
#   bounding_poly {
#     vertices {
#       x: 244
#       y: 451
#     }
#     vertices {
#       x: 256
#       y: 451
#     }
#     vertices {
#       x: 256
#       y: 468
#     }
#     vertices {
#       x: 244
#       y: 468
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 419
#       y: 456
#     }
#     vertices {
#       x: 429
#       y: 456
#     }
#     vertices {
#       x: 429
#       y: 473
#     }
#     vertices {
#       x: 419
#       y: 473
#     }
#   }
# }
# text_annotations {
#   description: "12.10"
#   bounding_poly {
#     vertices {
#       x: 432
#       y: 456
#     }
#     vertices {
#       x: 481
#       y: 456
#     }
#     vertices {
#       x: 481
#       y: 473
#     }
#     vertices {
#       x: 432
#       y: 473
#     }
#   }
# }
# text_annotations {
#   description: "Solaris"
#   bounding_poly {
#     vertices {
#       x: 586
#       y: 459
#     }
#     vertices {
#       x: 645
#       y: 460
#     }
#     vertices {
#       x: 645
#       y: 477
#     }
#     vertices {
#       x: 586
#       y: 476
#     }
#   }
# }
# text_annotations {
#   description: "Level"
#   bounding_poly {
#     vertices {
#       x: 653
#       y: 460
#     }
#     vertices {
#       x: 696
#       y: 461
#     }
#     vertices {
#       x: 696
#       y: 478
#     }
#     vertices {
#       x: 653
#       y: 477
#     }
#   }
# }
# text_annotations {
#   description: "2"
#   bounding_poly {
#     vertices {
#       x: 701
#       y: 462
#     }
#     vertices {
#       x: 712
#       y: 462
#     }
#     vertices {
#       x: 712
#       y: 478
#     }
#     vertices {
#       x: 701
#       y: 478
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 851
#       y: 463
#     }
#     vertices {
#       x: 861
#       y: 463
#     }
#     vertices {
#       x: 860
#       y: 480
#     }
#     vertices {
#       x: 850
#       y: 480
#     }
#   }
# }
# text_annotations {
#   description: "66"
#   bounding_poly {
#     vertices {
#       x: 862
#       y: 463
#     }
#     vertices {
#       x: 884
#       y: 464
#     }
#     vertices {
#       x: 883
#       y: 481
#     }
#     vertices {
#       x: 861
#       y: 480
#     }
#   }
# }
# text_annotations {
#   description: "Solaris"
#   bounding_poly {
#     vertices {
#       x: 1026
#       y: 460
#     }
#     vertices {
#       x: 1083
#       y: 460
#     }
#     vertices {
#       x: 1083
#       y: 475
#     }
#     vertices {
#       x: 1026
#       y: 475
#     }
#   }
# }
# text_annotations {
#   description: "Level"
#   bounding_poly {
#     vertices {
#       x: 1090
#       y: 460
#     }
#     vertices {
#       x: 1133
#       y: 460
#     }
#     vertices {
#       x: 1133
#       y: 475
#     }
#     vertices {
#       x: 1090
#       y: 475
#     }
#   }
# }
# text_annotations {
#   description: "2"
#   bounding_poly {
#     vertices {
#       x: 1137
#       y: 460
#     }
#     vertices {
#       x: 1148
#       y: 460
#     }
#     vertices {
#       x: 1148
#       y: 475
#     }
#     vertices {
#       x: 1137
#       y: 475
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 1297
#       y: 461
#     }
#     vertices {
#       x: 1306
#       y: 461
#     }
#     vertices {
#       x: 1306
#       y: 477
#     }
#     vertices {
#       x: 1297
#       y: 477
#     }
#   }
# }
# text_annotations {
#   description: "60.50"
#   bounding_poly {
#     vertices {
#       x: 1308
#       y: 461
#     }
#     vertices {
#       x: 1354
#       y: 462
#     }
#     vertices {
#       x: 1354
#       y: 478
#     }
#     vertices {
#       x: 1308
#       y: 477
#     }
#   }
# }
# text_annotations {
#   description: "Solar"
#   bounding_poly {
#     vertices {
#       x: 122
#       y: 492
#     }
#     vertices {
#       x: 170
#       y: 493
#     }
#     vertices {
#       x: 170
#       y: 510
#     }
#     vertices {
#       x: 122
#       y: 509
#     }
#   }
# }
# text_annotations {
#   description: "Force"
#   bounding_poly {
#     vertices {
#       x: 177
#       y: 492
#     }
#     vertices {
#       x: 227
#       y: 493
#     }
#     vertices {
#       x: 227
#       y: 511
#     }
#     vertices {
#       x: 177
#       y: 510
#     }
#   }
# }
# text_annotations {
#   description: "Level"
#   bounding_poly {
#     vertices {
#       x: 235
#       y: 493
#     }
#     vertices {
#       x: 282
#       y: 494
#     }
#     vertices {
#       x: 282
#       y: 511
#     }
#     vertices {
#       x: 235
#       y: 510
#     }
#   }
# }
# text_annotations {
#   description: "3"
#   bounding_poly {
#     vertices {
#       x: 287
#       y: 493
#     }
#     vertices {
#       x: 299
#       y: 493
#     }
#     vertices {
#       x: 299
#       y: 510
#     }
#     vertices {
#       x: 287
#       y: 510
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 420
#       y: 497
#     }
#     vertices {
#       x: 430
#       y: 497
#     }
#     vertices {
#       x: 430
#       y: 514
#     }
#     vertices {
#       x: 420
#       y: 514
#     }
#   }
# }
# text_annotations {
#   description: "15.40"
#   bounding_poly {
#     vertices {
#       x: 433
#       y: 497
#     }
#     vertices {
#       x: 482
#       y: 498
#     }
#     vertices {
#       x: 482
#       y: 515
#     }
#     vertices {
#       x: 433
#       y: 514
#     }
#   }
# }
# text_annotations {
#   description: "Solar"
#   bounding_poly {
#     vertices {
#       x: 587
#       y: 500
#     }
#     vertices {
#       x: 632
#       y: 501
#     }
#     vertices {
#       x: 632
#       y: 519
#     }
#     vertices {
#       x: 587
#       y: 518
#     }
#   }
# }
# text_annotations {
#   description: "Force"
#   bounding_poly {
#     vertices {
#       x: 639
#       y: 501
#     }
#     vertices {
#       x: 685
#       y: 502
#     }
#     vertices {
#       x: 685
#       y: 520
#     }
#     vertices {
#       x: 639
#       y: 519
#     }
#   }
# }
# text_annotations {
#   description: "Level"
#   bounding_poly {
#     vertices {
#       x: 693
#       y: 502
#     }
#     vertices {
#       x: 736
#       y: 503
#     }
#     vertices {
#       x: 736
#       y: 520
#     }
#     vertices {
#       x: 693
#       y: 519
#     }
#   }
# }
# text_annotations {
#   description: "3"
#   bounding_poly {
#     vertices {
#       x: 741
#       y: 502
#     }
#     vertices {
#       x: 753
#       y: 502
#     }
#     vertices {
#       x: 753
#       y: 519
#     }
#     vertices {
#       x: 741
#       y: 519
#     }
#   }
# }
# text_annotations {
#   description: "Solar"
#   bounding_poly {
#     vertices {
#       x: 1026
#       y: 496
#     }
#     vertices {
#       x: 1070
#       y: 496
#     }
#     vertices {
#       x: 1070
#       y: 512
#     }
#     vertices {
#       x: 1026
#       y: 512
#     }
#   }
# }
# text_annotations {
#   description: "Force"
#   bounding_poly {
#     vertices {
#       x: 1076
#       y: 496
#     }
#     vertices {
#       x: 1122
#       y: 496
#     }
#     vertices {
#       x: 1122
#       y: 512
#     }
#     vertices {
#       x: 1076
#       y: 512
#     }
#   }
# }
# text_annotations {
#   description: "Level"
#   bounding_poly {
#     vertices {
#       x: 1128
#       y: 496
#     }
#     vertices {
#       x: 1171
#       y: 496
#     }
#     vertices {
#       x: 1171
#       y: 512
#     }
#     vertices {
#       x: 1128
#       y: 512
#     }
#   }
# }
# text_annotations {
#   description: "3"
#   bounding_poly {
#     vertices {
#       x: 1176
#       y: 496
#     }
#     vertices {
#       x: 1187
#       y: 496
#     }
#     vertices {
#       x: 1187
#       y: 512
#     }
#     vertices {
#       x: 1176
#       y: 512
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 850
#       y: 504
#     }
#     vertices {
#       x: 860
#       y: 504
#     }
#     vertices {
#       x: 860
#       y: 521
#     }
#     vertices {
#       x: 850
#       y: 521
#     }
#   }
# }
# text_annotations {
#   description: "77"
#   bounding_poly {
#     vertices {
#       x: 861
#       y: 504
#     }
#     vertices {
#       x: 883
#       y: 504
#     }
#     vertices {
#       x: 883
#       y: 521
#     }
#     vertices {
#       x: 861
#       y: 521
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 1297
#       y: 497
#     }
#     vertices {
#       x: 1306
#       y: 497
#     }
#     vertices {
#       x: 1306
#       y: 513
#     }
#     vertices {
#       x: 1297
#       y: 513
#     }
#   }
# }
# text_annotations {
#   description: "77"
#   bounding_poly {
#     vertices {
#       x: 1307
#       y: 497
#     }
#     vertices {
#       x: 1328
#       y: 497
#     }
#     vertices {
#       x: 1328
#       y: 513
#     }
#     vertices {
#       x: 1307
#       y: 513
#     }
#   }
# }
# text_annotations {
#   description: "SunScape"
#   bounding_poly {
#     vertices {
#       x: 122
#       y: 533
#     }
#     vertices {
#       x: 217
#       y: 533
#     }
#     vertices {
#       x: 217
#       y: 552
#     }
#     vertices {
#       x: 122
#       y: 552
#     }
#   }
# }
# text_annotations {
#   description: "Level"
#   bounding_poly {
#     vertices {
#       x: 223
#       y: 533
#     }
#     vertices {
#       x: 272
#       y: 533
#     }
#     vertices {
#       x: 272
#       y: 552
#     }
#     vertices {
#       x: 223
#       y: 552
#     }
#   }
# }
# text_annotations {
#   description: "4"
#   bounding_poly {
#     vertices {
#       x: 275
#       y: 533
#     }
#     vertices {
#       x: 289
#       y: 533
#     }
#     vertices {
#       x: 289
#       y: 552
#     }
#     vertices {
#       x: 275
#       y: 552
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 420
#       y: 537
#     }
#     vertices {
#       x: 430
#       y: 537
#     }
#     vertices {
#       x: 430
#       y: 554
#     }
#     vertices {
#       x: 420
#       y: 554
#     }
#   }
# }
# text_annotations {
#   description: "19.80"
#   bounding_poly {
#     vertices {
#       x: 433
#       y: 537
#     }
#     vertices {
#       x: 482
#       y: 537
#     }
#     vertices {
#       x: 482
#       y: 554
#     }
#     vertices {
#       x: 433
#       y: 554
#     }
#   }
# }
# text_annotations {
#   description: "Sunscape"
#   bounding_poly {
#     vertices {
#       x: 586
#       y: 542
#     }
#     vertices {
#       x: 673
#       y: 541
#     }
#     vertices {
#       x: 673
#       y: 561
#     }
#     vertices {
#       x: 586
#       y: 562
#     }
#   }
# }
# text_annotations {
#   description: "Level"
#   bounding_poly {
#     vertices {
#       x: 678
#       y: 541
#     }
#     vertices {
#       x: 724
#       y: 541
#     }
#     vertices {
#       x: 724
#       y: 561
#     }
#     vertices {
#       x: 678
#       y: 561
#     }
#   }
# }
# text_annotations {
#   description: "4"
#   bounding_poly {
#     vertices {
#       x: 727
#       y: 541
#     }
#     vertices {
#       x: 739
#       y: 541
#     }
#     vertices {
#       x: 739
#       y: 560
#     }
#     vertices {
#       x: 727
#       y: 560
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 850
#       y: 543
#     }
#     vertices {
#       x: 860
#       y: 543
#     }
#     vertices {
#       x: 860
#       y: 559
#     }
#     vertices {
#       x: 850
#       y: 559
#     }
#   }
# }
# text_annotations {
#   description: "99"
#   bounding_poly {
#     vertices {
#       x: 861
#       y: 543
#     }
#     vertices {
#       x: 882
#       y: 543
#     }
#     vertices {
#       x: 882
#       y: 559
#     }
#     vertices {
#       x: 861
#       y: 559
#     }
#   }
# }
# text_annotations {
#   description: "Sunscape"
#   bounding_poly {
#     vertices {
#       x: 1025
#       y: 532
#     }
#     vertices {
#       x: 1108
#       y: 531
#     }
#     vertices {
#       x: 1108
#       y: 551
#     }
#     vertices {
#       x: 1025
#       y: 552
#     }
#   }
# }
# text_annotations {
#   description: "Level"
#   bounding_poly {
#     vertices {
#       x: 1115
#       y: 531
#     }
#     vertices {
#       x: 1159
#       y: 530
#     }
#     vertices {
#       x: 1159
#       y: 549
#     }
#     vertices {
#       x: 1115
#       y: 550
#     }
#   }
# }
# text_annotations {
#   description: "4"
#   bounding_poly {
#     vertices {
#       x: 1162
#       y: 530
#     }
#     vertices {
#       x: 1174
#       y: 530
#     }
#     vertices {
#       x: 1174
#       y: 549
#     }
#     vertices {
#       x: 1162
#       y: 549
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 1297
#       y: 532
#     }
#     vertices {
#       x: 1307
#       y: 532
#     }
#     vertices {
#       x: 1307
#       y: 549
#     }
#     vertices {
#       x: 1297
#       y: 549
#     }
#   }
# }
# text_annotations {
#   description: "99"
#   bounding_poly {
#     vertices {
#       x: 1308
#       y: 532
#     }
#     vertices {
#       x: 1328
#       y: 532
#     }
#     vertices {
#       x: 1328
#       y: 549
#     }
#     vertices {
#       x: 1308
#       y: 549
#     }
#   }
# }
# text_annotations {
#   description: "Red"
#   bounding_poly {
#     vertices {
#       x: 124
#       y: 573
#     }
#     vertices {
#       x: 159
#       y: 574
#     }
#     vertices {
#       x: 158
#       y: 595
#     }
#     vertices {
#       x: 123
#       y: 594
#     }
#   }
# }
# text_annotations {
#   description: "Light"
#   bounding_poly {
#     vertices {
#       x: 165
#       y: 574
#     }
#     vertices {
#       x: 210
#       y: 575
#     }
#     vertices {
#       x: 209
#       y: 596
#     }
#     vertices {
#       x: 164
#       y: 595
#     }
#   }
# }
# text_annotations {
#   description: "Therapy"
#   bounding_poly {
#     vertices {
#       x: 216
#       y: 576
#     }
#     vertices {
#       x: 295
#       y: 578
#     }
#     vertices {
#       x: 294
#       y: 598
#     }
#     vertices {
#       x: 215
#       y: 596
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 422
#       y: 578
#     }
#     vertices {
#       x: 432
#       y: 578
#     }
#     vertices {
#       x: 431
#       y: 595
#     }
#     vertices {
#       x: 421
#       y: 595
#     }
#   }
# }
# text_annotations {
#   description: "25.00"
#   bounding_poly {
#     vertices {
#       x: 434
#       y: 578
#     }
#     vertices {
#       x: 483
#       y: 579
#     }
#     vertices {
#       x: 482
#       y: 596
#     }
#     vertices {
#       x: 433
#       y: 595
#     }
#   }
# }
# text_annotations {
#   description: "Red"
#   bounding_poly {
#     vertices {
#       x: 588
#       y: 581
#     }
#     vertices {
#       x: 623
#       y: 582
#     }
#     vertices {
#       x: 623
#       y: 601
#     }
#     vertices {
#       x: 588
#       y: 600
#     }
#   }
# }
# text_annotations {
#   description: "Light"
#   bounding_poly {
#     vertices {
#       x: 627
#       y: 581
#     }
#     vertices {
#       x: 672
#       y: 582
#     }
#     vertices {
#       x: 672
#       y: 602
#     }
#     vertices {
#       x: 627
#       y: 601
#     }
#   }
# }
# text_annotations {
#   description: "Therapy"
#   bounding_poly {
#     vertices {
#       x: 676
#       y: 582
#     }
#     vertices {
#       x: 748
#       y: 583
#     }
#     vertices {
#       x: 748
#       y: 603
#     }
#     vertices {
#       x: 676
#       y: 602
#     }
#   }
# }
# text_annotations {
#   description: "Mystic"
#   bounding_poly {
#     vertices {
#       x: 1025
#       y: 570
#     }
#     vertices {
#       x: 1082
#       y: 569
#     }
#     vertices {
#       x: 1082
#       y: 589
#     }
#     vertices {
#       x: 1025
#       y: 590
#     }
#   }
# }
# text_annotations {
#   description: "Spray"
#   bounding_poly {
#     vertices {
#       x: 1085
#       y: 569
#     }
#     vertices {
#       x: 1136
#       y: 568
#     }
#     vertices {
#       x: 1136
#       y: 588
#     }
#     vertices {
#       x: 1085
#       y: 589
#     }
#   }
# }
# text_annotations {
#   description: "Tan"
#   bounding_poly {
#     vertices {
#       x: 1140
#       y: 569
#     }
#     vertices {
#       x: 1172
#       y: 569
#     }
#     vertices {
#       x: 1172
#       y: 588
#     }
#     vertices {
#       x: 1140
#       y: 588
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 1297
#       y: 570
#     }
#     vertices {
#       x: 1307
#       y: 570
#     }
#     vertices {
#       x: 1307
#       y: 586
#     }
#     vertices {
#       x: 1297
#       y: 586
#     }
#   }
# }
# text_annotations {
#   description: "178"
#   bounding_poly {
#     vertices {
#       x: 1309
#       y: 570
#     }
#     vertices {
#       x: 1339
#       y: 570
#     }
#     vertices {
#       x: 1339
#       y: 586
#     }
#     vertices {
#       x: 1309
#       y: 586
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 851
#       y: 583
#     }
#     vertices {
#       x: 861
#       y: 583
#     }
#     vertices {
#       x: 861
#       y: 599
#     }
#     vertices {
#       x: 851
#       y: 599
#     }
#   }
# }
# text_annotations {
#   description: "99"
#   bounding_poly {
#     vertices {
#       x: 861
#       y: 583
#     }
#     vertices {
#       x: 882
#       y: 583
#     }
#     vertices {
#       x: 882
#       y: 599
#     }
#     vertices {
#       x: 861
#       y: 599
#     }
#   }
# }
# text_annotations {
#   description: "HaloSauna"
#   bounding_poly {
#     vertices {
#       x: 124
#       y: 617
#     }
#     vertices {
#       x: 226
#       y: 617
#     }
#     vertices {
#       x: 226
#       y: 632
#     }
#     vertices {
#       x: 124
#       y: 632
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 422
#       y: 619
#     }
#     vertices {
#       x: 432
#       y: 619
#     }
#     vertices {
#       x: 432
#       y: 635
#     }
#     vertices {
#       x: 422
#       y: 635
#     }
#   }
# }
# text_annotations {
#   description: "25.00"
#   bounding_poly {
#     vertices {
#       x: 434
#       y: 619
#     }
#     vertices {
#       x: 483
#       y: 620
#     }
#     vertices {
#       x: 483
#       y: 636
#     }
#     vertices {
#       x: 434
#       y: 635
#     }
#   }
# }
# text_annotations {
#   description: "*"
#   bounding_poly {
#     vertices {
#       x: 588
#       y: 627
#     }
#     vertices {
#       x: 594
#       y: 627
#     }
#     vertices {
#       x: 594
#       y: 637
#     }
#     vertices {
#       x: 588
#       y: 637
#     }
#   }
# }
# text_annotations {
#   description: "2"
#   bounding_poly {
#     vertices {
#       x: 592
#       y: 626
#     }
#     vertices {
#       x: 600
#       y: 626
#     }
#     vertices {
#       x: 600
#       y: 636
#     }
#     vertices {
#       x: 592
#       y: 636
#     }
#   }
# }
# text_annotations {
#   description: "months"
#   bounding_poly {
#     vertices {
#       x: 603
#       y: 626
#     }
#     vertices {
#       x: 647
#       y: 626
#     }
#     vertices {
#       x: 647
#       y: 636
#     }
#     vertices {
#       x: 603
#       y: 636
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 851
#       y: 622
#     }
#     vertices {
#       x: 860
#       y: 622
#     }
#     vertices {
#       x: 860
#       y: 638
#     }
#     vertices {
#       x: 851
#       y: 638
#     }
#   }
# }
# text_annotations {
#   description: "150"
#   bounding_poly {
#     vertices {
#       x: 863
#       y: 622
#     }
#     vertices {
#       x: 894
#       y: 622
#     }
#     vertices {
#       x: 894
#       y: 638
#     }
#     vertices {
#       x: 863
#       y: 638
#     }
#   }
# }
# text_annotations {
#   description: "Buy"
#   bounding_poly {
#     vertices {
#       x: 1107
#       y: 623
#     }
#     vertices {
#       x: 1146
#       y: 623
#     }
#     vertices {
#       x: 1146
#       y: 648
#     }
#     vertices {
#       x: 1107
#       y: 648
#     }
#   }
# }
# text_annotations {
#   description: "Minutes"
#   bounding_poly {
#     vertices {
#       x: 1148
#       y: 623
#     }
#     vertices {
#       x: 1226
#       y: 622
#     }
#     vertices {
#       x: 1226
#       y: 646
#     }
#     vertices {
#       x: 1148
#       y: 647
#     }
#   }
# }
# text_annotations {
#   description: "Get"
#   bounding_poly {
#     vertices {
#       x: 1231
#       y: 622
#     }
#     vertices {
#       x: 1264
#       y: 622
#     }
#     vertices {
#       x: 1264
#       y: 646
#     }
#     vertices {
#       x: 1231
#       y: 646
#     }
#   }
# }
# text_annotations {
#   description: "Minutes"
#   bounding_poly {
#     vertices {
#       x: 1267
#       y: 621
#     }
#     vertices {
#       x: 1345
#       y: 620
#     }
#     vertices {
#       x: 1345
#       y: 645
#     }
#     vertices {
#       x: 1267
#       y: 646
#     }
#   }
# }
# text_annotations {
#   description: "Mystic"
#   bounding_poly {
#     vertices {
#       x: 124
#       y: 657
#     }
#     vertices {
#       x: 186
#       y: 657
#     }
#     vertices {
#       x: 186
#       y: 677
#     }
#     vertices {
#       x: 124
#       y: 677
#     }
#   }
# }
# text_annotations {
#   description: "Spray"
#   bounding_poly {
#     vertices {
#       x: 191
#       y: 657
#     }
#     vertices {
#       x: 245
#       y: 657
#     }
#     vertices {
#       x: 245
#       y: 677
#     }
#     vertices {
#       x: 191
#       y: 677
#     }
#   }
# }
# text_annotations {
#   description: "Tan"
#   bounding_poly {
#     vertices {
#       x: 250
#       y: 657
#     }
#     vertices {
#       x: 287
#       y: 657
#     }
#     vertices {
#       x: 287
#       y: 677
#     }
#     vertices {
#       x: 250
#       y: 677
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 422
#       y: 660
#     }
#     vertices {
#       x: 433
#       y: 660
#     }
#     vertices {
#       x: 433
#       y: 677
#     }
#     vertices {
#       x: 422
#       y: 677
#     }
#   }
# }
# text_annotations {
#   description: "35.60"
#   bounding_poly {
#     vertices {
#       x: 434
#       y: 659
#     }
#     vertices {
#       x: 483
#       y: 659
#     }
#     vertices {
#       x: 483
#       y: 676
#     }
#     vertices {
#       x: 434
#       y: 676
#     }
#   }
# }
# text_annotations {
#   description: "+"
#   bounding_poly {
#     vertices {
#       x: 485
#       y: 659
#     }
#     vertices {
#       x: 495
#       y: 659
#     }
#     vertices {
#       x: 495
#       y: 676
#     }
#     vertices {
#       x: 485
#       y: 676
#     }
#   }
# }
# text_annotations {
#   description: "*"
#   bounding_poly {
#     vertices {
#       x: 589
#       y: 663
#     }
#     vertices {
#       x: 596
#       y: 663
#     }
#     vertices {
#       x: 596
#       y: 677
#     }
#     vertices {
#       x: 589
#       y: 677
#     }
#   }
# }
# text_annotations {
#   description: "Add"
#   bounding_poly {
#     vertices {
#       x: 593
#       y: 663
#     }
#     vertices {
#       x: 616
#       y: 663
#     }
#     vertices {
#       x: 616
#       y: 677
#     }
#     vertices {
#       x: 593
#       y: 677
#     }
#   }
# }
# text_annotations {
#   description: "-"
#   bounding_poly {
#     vertices {
#       x: 617
#       y: 663
#     }
#     vertices {
#       x: 622
#       y: 663
#     }
#     vertices {
#       x: 622
#       y: 677
#     }
#     vertices {
#       x: 617
#       y: 677
#     }
#   }
# }
# text_annotations {
#   description: "On"
#   bounding_poly {
#     vertices {
#       x: 622
#       y: 663
#     }
#     vertices {
#       x: 638
#       y: 663
#     }
#     vertices {
#       x: 638
#       y: 677
#     }
#     vertices {
#       x: 622
#       y: 677
#     }
#   }
# }
# text_annotations {
#   description: "to"
#   bounding_poly {
#     vertices {
#       x: 640
#       y: 663
#     }
#     vertices {
#       x: 653
#       y: 663
#     }
#     vertices {
#       x: 653
#       y: 678
#     }
#     vertices {
#       x: 640
#       y: 678
#     }
#   }
# }
# text_annotations {
#   description: "any"
#   bounding_poly {
#     vertices {
#       x: 656
#       y: 664
#     }
#     vertices {
#       x: 677
#       y: 664
#     }
#     vertices {
#       x: 677
#       y: 678
#     }
#     vertices {
#       x: 656
#       y: 678
#     }
#   }
# }
# text_annotations {
#   description: "monthly"
#   bounding_poly {
#     vertices {
#       x: 679
#       y: 664
#     }
#     vertices {
#       x: 726
#       y: 665
#     }
#     vertices {
#       x: 726
#       y: 680
#     }
#     vertices {
#       x: 679
#       y: 679
#     }
#   }
# }
# text_annotations {
#   description: "pkg"
#   bounding_poly {
#     vertices {
#       x: 728
#       y: 665
#     }
#     vertices {
#       x: 749
#       y: 665
#     }
#     vertices {
#       x: 749
#       y: 679
#     }
#     vertices {
#       x: 728
#       y: 679
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 851
#       y: 662
#     }
#     vertices {
#       x: 860
#       y: 662
#     }
#     vertices {
#       x: 860
#       y: 678
#     }
#     vertices {
#       x: 851
#       y: 678
#     }
#   }
# }
# text_annotations {
#   description: "20"
#   bounding_poly {
#     vertices {
#       x: 862
#       y: 662
#     }
#     vertices {
#       x: 883
#       y: 662
#     }
#     vertices {
#       x: 883
#       y: 678
#     }
#     vertices {
#       x: 862
#       y: 678
#     }
#   }
# }
# text_annotations {
#   description: "Buy"
#   bounding_poly {
#     vertices {
#       x: 1027
#       y: 679
#     }
#     vertices {
#       x: 1058
#       y: 678
#     }
#     vertices {
#       x: 1059
#       y: 699
#     }
#     vertices {
#       x: 1028
#       y: 700
#     }
#   }
# }
# text_annotations {
#   description: "50"
#   bounding_poly {
#     vertices {
#       x: 1062
#       y: 678
#     }
#     vertices {
#       x: 1084
#       y: 677
#     }
#     vertices {
#       x: 1085
#       y: 698
#     }
#     vertices {
#       x: 1063
#       y: 699
#     }
#   }
# }
# text_annotations {
#   description: "get"
#   bounding_poly {
#     vertices {
#       x: 1088
#       y: 678
#     }
#     vertices {
#       x: 1115
#       y: 677
#     }
#     vertices {
#       x: 1115
#       y: 697
#     }
#     vertices {
#       x: 1088
#       y: 698
#     }
#   }
# }
# text_annotations {
#   description: "20"
#   bounding_poly {
#     vertices {
#       x: 1120
#       y: 677
#     }
#     vertices {
#       x: 1141
#       y: 676
#     }
#     vertices {
#       x: 1141
#       y: 696
#     }
#     vertices {
#       x: 1120
#       y: 697
#     }
#   }
# }
# text_annotations {
#   description: "FREE"
#   bounding_poly {
#     vertices {
#       x: 1147
#       y: 676
#     }
#     vertices {
#       x: 1192
#       y: 675
#     }
#     vertices {
#       x: 1192
#       y: 696
#     }
#     vertices {
#       x: 1148
#       y: 697
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 1303
#       y: 678
#     }
#     vertices {
#       x: 1313
#       y: 678
#     }
#     vertices {
#       x: 1313
#       y: 694
#     }
#     vertices {
#       x: 1303
#       y: 694
#     }
#   }
# }
# text_annotations {
#   description: "77"
#   bounding_poly {
#     vertices {
#       x: 1313
#       y: 678
#     }
#     vertices {
#       x: 1335
#       y: 678
#     }
#     vertices {
#       x: 1335
#       y: 694
#     }
#     vertices {
#       x: 1313
#       y: 694
#     }
#   }
# }
# text_annotations {
#   description: "HaloSauna"
#   bounding_poly {
#     vertices {
#       x: 590
#       y: 701
#     }
#     vertices {
#       x: 683
#       y: 701
#     }
#     vertices {
#       x: 683
#       y: 715
#     }
#     vertices {
#       x: 590
#       y: 715
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 851
#       y: 701
#     }
#     vertices {
#       x: 861
#       y: 701
#     }
#     vertices {
#       x: 861
#       y: 717
#     }
#     vertices {
#       x: 851
#       y: 717
#     }
#   }
# }
# text_annotations {
#   description: "70"
#   bounding_poly {
#     vertices {
#       x: 862
#       y: 701
#     }
#     vertices {
#       x: 883
#       y: 701
#     }
#     vertices {
#       x: 883
#       y: 717
#     }
#     vertices {
#       x: 862
#       y: 717
#     }
#   }
# }
# text_annotations {
#   description: "Buy"
#   bounding_poly {
#     vertices {
#       x: 1027
#       y: 720
#     }
#     vertices {
#       x: 1058
#       y: 719
#     }
#     vertices {
#       x: 1058
#       y: 739
#     }
#     vertices {
#       x: 1027
#       y: 740
#     }
#   }
# }
# text_annotations {
#   description: "75"
#   bounding_poly {
#     vertices {
#       x: 1063
#       y: 720
#     }
#     vertices {
#       x: 1084
#       y: 720
#     }
#     vertices {
#       x: 1084
#       y: 739
#     }
#     vertices {
#       x: 1063
#       y: 739
#     }
#   }
# }
# text_annotations {
#   description: "get"
#   bounding_poly {
#     vertices {
#       x: 1088
#       y: 719
#     }
#     vertices {
#       x: 1115
#       y: 718
#     }
#     vertices {
#       x: 1115
#       y: 737
#     }
#     vertices {
#       x: 1088
#       y: 738
#     }
#   }
# }
# text_annotations {
#   description: "30"
#   bounding_poly {
#     vertices {
#       x: 1120
#       y: 718
#     }
#     vertices {
#       x: 1141
#       y: 718
#     }
#     vertices {
#       x: 1141
#       y: 738
#     }
#     vertices {
#       x: 1120
#       y: 738
#     }
#   }
# }
# text_annotations {
#   description: "FREE"
#   bounding_poly {
#     vertices {
#       x: 1148
#       y: 718
#     }
#     vertices {
#       x: 1192
#       y: 717
#     }
#     vertices {
#       x: 1192
#       y: 736
#     }
#     vertices {
#       x: 1148
#       y: 737
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 1303
#       y: 718
#     }
#     vertices {
#       x: 1313
#       y: 718
#     }
#     vertices {
#       x: 1313
#       y: 734
#     }
#     vertices {
#       x: 1303
#       y: 734
#     }
#   }
# }
# text_annotations {
#   description: "115.50"
#   bounding_poly {
#     vertices {
#       x: 1315
#       y: 718
#     }
#     vertices {
#       x: 1371
#       y: 718
#     }
#     vertices {
#       x: 1371
#       y: 734
#     }
#     vertices {
#       x: 1315
#       y: 734
#     }
#   }
# }
# text_annotations {
#   description: "Weekly"
#   bounding_poly {
#     vertices {
#       x: 232
#       y: 741
#     }
#     vertices {
#       x: 311
#       y: 740
#     }
#     vertices {
#       x: 311
#       y: 766
#     }
#     vertices {
#       x: 232
#       y: 767
#     }
#   }
# }
# text_annotations {
#   description: "Sessions"
#   bounding_poly {
#     vertices {
#       x: 314
#       y: 740
#     }
#     vertices {
#       x: 402
#       y: 738
#     }
#     vertices {
#       x: 402
#       y: 763
#     }
#     vertices {
#       x: 314
#       y: 765
#     }
#   }
# }
# text_annotations {
#   description: "*"
#   bounding_poly {
#     vertices {
#       x: 590
#       y: 742
#     }
#     vertices {
#       x: 596
#       y: 742
#     }
#     vertices {
#       x: 596
#       y: 756
#     }
#     vertices {
#       x: 590
#       y: 756
#     }
#   }
# }
# text_annotations {
#   description: "Add"
#   bounding_poly {
#     vertices {
#       x: 594
#       y: 742
#     }
#     vertices {
#       x: 617
#       y: 742
#     }
#     vertices {
#       x: 617
#       y: 756
#     }
#     vertices {
#       x: 594
#       y: 756
#     }
#   }
# }
# text_annotations {
#   description: "-"
#   bounding_poly {
#     vertices {
#       x: 618
#       y: 742
#     }
#     vertices {
#       x: 623
#       y: 742
#     }
#     vertices {
#       x: 623
#       y: 756
#     }
#     vertices {
#       x: 618
#       y: 756
#     }
#   }
# }
# text_annotations {
#   description: "on"
#   bounding_poly {
#     vertices {
#       x: 623
#       y: 742
#     }
#     vertices {
#       x: 637
#       y: 742
#     }
#     vertices {
#       x: 637
#       y: 756
#     }
#     vertices {
#       x: 623
#       y: 756
#     }
#   }
# }
# text_annotations {
#   description: "HaloSauna"
#   bounding_poly {
#     vertices {
#       x: 640
#       y: 742
#     }
#     vertices {
#       x: 702
#       y: 743
#     }
#     vertices {
#       x: 702
#       y: 758
#     }
#     vertices {
#       x: 640
#       y: 757
#     }
#   }
# }
# text_annotations {
#   description: "to"
#   bounding_poly {
#     vertices {
#       x: 704
#       y: 743
#     }
#     vertices {
#       x: 716
#       y: 743
#     }
#     vertices {
#       x: 716
#       y: 757
#     }
#     vertices {
#       x: 704
#       y: 757
#     }
#   }
# }
# text_annotations {
#   description: "any"
#   bounding_poly {
#     vertices {
#       x: 719
#       y: 743
#     }
#     vertices {
#       x: 740
#       y: 743
#     }
#     vertices {
#       x: 740
#       y: 757
#     }
#     vertices {
#       x: 719
#       y: 757
#     }
#   }
# }
# text_annotations {
#   description: "Monthly"
#   bounding_poly {
#     vertices {
#       x: 742
#       y: 743
#     }
#     vertices {
#       x: 788
#       y: 743
#     }
#     vertices {
#       x: 788
#       y: 757
#     }
#     vertices {
#       x: 742
#       y: 757
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 851
#       y: 740
#     }
#     vertices {
#       x: 860
#       y: 740
#     }
#     vertices {
#       x: 860
#       y: 757
#     }
#     vertices {
#       x: 851
#       y: 757
#     }
#   }
# }
# text_annotations {
#   description: "20"
#   bounding_poly {
#     vertices {
#       x: 862
#       y: 740
#     }
#     vertices {
#       x: 884
#       y: 740
#     }
#     vertices {
#       x: 884
#       y: 757
#     }
#     vertices {
#       x: 862
#       y: 757
#     }
#   }
# }
# text_annotations {
#   description: "Buy"
#   bounding_poly {
#     vertices {
#       x: 1027
#       y: 761
#     }
#     vertices {
#       x: 1058
#       y: 760
#     }
#     vertices {
#       x: 1058
#       y: 779
#     }
#     vertices {
#       x: 1027
#       y: 780
#     }
#   }
# }
# text_annotations {
#   description: "100"
#   bounding_poly {
#     vertices {
#       x: 1065
#       y: 760
#     }
#     vertices {
#       x: 1095
#       y: 759
#     }
#     vertices {
#       x: 1095
#       y: 778
#     }
#     vertices {
#       x: 1065
#       y: 779
#     }
#   }
# }
# text_annotations {
#   description: "get"
#   bounding_poly {
#     vertices {
#       x: 1099
#       y: 760
#     }
#     vertices {
#       x: 1127
#       y: 760
#     }
#     vertices {
#       x: 1127
#       y: 778
#     }
#     vertices {
#       x: 1099
#       y: 778
#     }
#   }
# }
# text_annotations {
#   description: "40"
#   bounding_poly {
#     vertices {
#       x: 1131
#       y: 759
#     }
#     vertices {
#       x: 1153
#       y: 759
#     }
#     vertices {
#       x: 1153
#       y: 778
#     }
#     vertices {
#       x: 1131
#       y: 778
#     }
#   }
# }
# text_annotations {
#   description: "FREE"
#   bounding_poly {
#     vertices {
#       x: 1158
#       y: 759
#     }
#     vertices {
#       x: 1203
#       y: 758
#     }
#     vertices {
#       x: 1203
#       y: 777
#     }
#     vertices {
#       x: 1158
#       y: 778
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 1304
#       y: 758
#     }
#     vertices {
#       x: 1314
#       y: 758
#     }
#     vertices {
#       x: 1314
#       y: 775
#     }
#     vertices {
#       x: 1304
#       y: 775
#     }
#   }
# }
# text_annotations {
#   description: "154"
#   bounding_poly {
#     vertices {
#       x: 1315
#       y: 758
#     }
#     vertices {
#       x: 1346
#       y: 759
#     }
#     vertices {
#       x: 1346
#       y: 776
#     }
#     vertices {
#       x: 1315
#       y: 775
#     }
#   }
# }
# text_annotations {
#   description: "Mystic"
#   bounding_poly {
#     vertices {
#       x: 590
#       y: 778
#     }
#     vertices {
#       x: 648
#       y: 778
#     }
#     vertices {
#       x: 648
#       y: 796
#     }
#     vertices {
#       x: 590
#       y: 796
#     }
#   }
# }
# text_annotations {
#   description: "Spray"
#   bounding_poly {
#     vertices {
#       x: 652
#       y: 778
#     }
#     vertices {
#       x: 703
#       y: 778
#     }
#     vertices {
#       x: 703
#       y: 796
#     }
#     vertices {
#       x: 652
#       y: 796
#     }
#   }
# }
# text_annotations {
#   description: "Tan"
#   bounding_poly {
#     vertices {
#       x: 707
#       y: 778
#     }
#     vertices {
#       x: 740
#       y: 778
#     }
#     vertices {
#       x: 740
#       y: 796
#     }
#     vertices {
#       x: 707
#       y: 796
#     }
#   }
# }
# text_annotations {
#   description: "("
#   bounding_poly {
#     vertices {
#       x: 744
#       y: 778
#     }
#     vertices {
#       x: 752
#       y: 778
#     }
#     vertices {
#       x: 752
#       y: 796
#     }
#     vertices {
#       x: 744
#       y: 796
#     }
#   }
# }
# text_annotations {
#   description: "4"
#   bounding_poly {
#     vertices {
#       x: 750
#       y: 778
#     }
#     vertices {
#       x: 761
#       y: 778
#     }
#     vertices {
#       x: 761
#       y: 796
#     }
#     vertices {
#       x: 750
#       y: 796
#     }
#   }
# }
# text_annotations {
#   description: "max"
#   bounding_poly {
#     vertices {
#       x: 766
#       y: 778
#     }
#     vertices {
#       x: 804
#       y: 778
#     }
#     vertices {
#       x: 804
#       y: 796
#     }
#     vertices {
#       x: 766
#       y: 796
#     }
#   }
# }
# text_annotations {
#   description: ")"
#   bounding_poly {
#     vertices {
#       x: 802
#       y: 778
#     }
#     vertices {
#       x: 810
#       y: 778
#     }
#     vertices {
#       x: 810
#       y: 796
#     }
#     vertices {
#       x: 802
#       y: 796
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 851
#       y: 779
#     }
#     vertices {
#       x: 860
#       y: 779
#     }
#     vertices {
#       x: 860
#       y: 795
#     }
#     vertices {
#       x: 851
#       y: 795
#     }
#   }
# }
# text_annotations {
#   description: "99"
#   bounding_poly {
#     vertices {
#       x: 862
#       y: 779
#     }
#     vertices {
#       x: 882
#       y: 779
#     }
#     vertices {
#       x: 882
#       y: 795
#     }
#     vertices {
#       x: 862
#       y: 795
#     }
#   }
# }
# text_annotations {
#   description: "HaloSauna"
#   bounding_poly {
#     vertices {
#       x: 126
#       y: 794
#     }
#     vertices {
#       x: 226
#       y: 793
#     }
#     vertices {
#       x: 226
#       y: 810
#     }
#     vertices {
#       x: 126
#       y: 811
#     }
#   }
# }
# text_annotations {
#   description: "Unlimited"
#   bounding_poly {
#     vertices {
#       x: 233
#       y: 793
#     }
#     vertices {
#       x: 320
#       y: 792
#     }
#     vertices {
#       x: 320
#       y: 809
#     }
#     vertices {
#       x: 233
#       y: 810
#     }
#   }
# }
# text_annotations {
#   description: "$"
#   bounding_poly {
#     vertices {
#       x: 424
#       y: 794
#     }
#     vertices {
#       x: 435
#       y: 794
#     }
#     vertices {
#       x: 435
#       y: 811
#     }
#     vertices {
#       x: 424
#       y: 811
#     }
#   }
# }
# text_annotations {
#   description: "50"
#   bounding_poly {
#     vertices {
#       x: 435
#       y: 793
#     }
#     vertices {
#       x: 458
#       y: 793
#     }
#     vertices {
#       x: 458
#       y: 810
#     }
#     vertices {
#       x: 435
#       y: 810
#     }
#   }
# }
# text_annotations {
#   description: "Buy"
#   bounding_poly {
#     vertices {
#       x: 1027
#       y: 801
#     }
#     vertices {
#       x: 1058
#       y: 800
#     }
#     vertices {
#       x: 1058
#       y: 820
#     }
#     vertices {
#       x: 1027
#       y: 821
#     }
#   }
# }
# text_annotations {
#   description: "150"
#   bounding_poly {
#     vertices {
#       x: 1065
#       y: 800
#     }
#     vertices {
#       x: 1096
#       y: 799
#     }
#     vertices {
#       x: 1096
#       y: 819
#     }
#     vertices {
#       x: 1065
#       y: 820
#     }
#   }
# }
# text_annotations {
#   description: "get"
#   bounding_poly {
#     vertices {
#       x: 1099
#       y: 800
#     }
#     vertices {
#       x: 1127
#       y: 799
#     }
#     vertices {
#       x: 1127
#       y: 818
#     }
#     vertices {
#       x: 1099
#       y: 819
#     }
#   }
# }
# text_annotations {
#   description: "70"
#   bounding_poly {
#     vertices {
#       x: 1132
#       y: 799
#     }
#     vertices {
#       x: 1153
#       y: 799
#     }
#     vertices {
#       x: 1153
#       y: 819
#     }
#     vertices {
# ...
#               }
#             }
#             text: "*"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 820
#               y: 918
#             }
#             vertices {
#               x: 897
#               y: 918
#             }
#             vertices {
#               x: 897
#               y: 936
#             }
#             vertices {
#               x: 820
#               y: 936
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 820
#                 y: 918
#               }
#               vertices {
#                 x: 832
#                 y: 918
#               }
#               vertices {
#                 x: 832
#                 y: 936
#               }
#               vertices {
#                 x: 820
#                 y: 936
#               }
#             }
#             text: "P"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 831
#                 y: 918
#               }
#               vertices {
#                 x: 841
#                 y: 918
#               }
#               vertices {
#                 x: 841
#                 y: 936
#               }
#               vertices {
#                 x: 831
#                 y: 936
#               }
#             }
#             text: "a"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 841
#                 y: 918
#               }
#               vertices {
#                 x: 850
#                 y: 918
#               }
#               vertices {
#                 x: 850
#                 y: 936
#               }
#               vertices {
#                 x: 841
#                 y: 936
#               }
#             }
#             text: "c"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 850
#                 y: 918
#               }
#               vertices {
#                 x: 861
#                 y: 918
#               }
#               vertices {
#                 x: 861
#                 y: 936
#               }
#               vertices {
#                 x: 850
#                 y: 936
#               }
#             }
#             text: "k"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 859
#                 y: 918
#               }
#               vertices {
#                 x: 868
#                 y: 918
#               }
#               vertices {
#                 x: 868
#                 y: 936
#               }
#               vertices {
#                 x: 859
#                 y: 936
#               }
#             }
#             text: "a"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 868
#                 y: 918
#               }
#               vertices {
#                 x: 879
#                 y: 918
#               }
#               vertices {
#                 x: 879
#                 y: 936
#               }
#               vertices {
#                 x: 868
#                 y: 936
#               }
#             }
#             text: "g"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 879
#                 y: 918
#               }
#               vertices {
#                 x: 888
#                 y: 918
#               }
#               vertices {
#                 x: 888
#                 y: 936
#               }
#               vertices {
#                 x: 879
#                 y: 936
#               }
#             }
#             text: "e"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 889
#                 y: 918
#               }
#               vertices {
#                 x: 897
#                 y: 918
#               }
#               vertices {
#                 x: 897
#                 y: 936
#               }
#               vertices {
#                 x: 889
#                 y: 936
#               }
#             }
#             text: "s"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 901
#               y: 918
#             }
#             vertices {
#               x: 951
#               y: 918
#             }
#             vertices {
#               x: 951
#               y: 936
#             }
#             vertices {
#               x: 901
#               y: 936
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 901
#                 y: 918
#               }
#               vertices {
#                 x: 911
#                 y: 918
#               }
#               vertices {
#                 x: 911
#                 y: 936
#               }
#               vertices {
#                 x: 901
#                 y: 936
#               }
#             }
#             text: "e"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 910
#                 y: 918
#               }
#               vertices {
#                 x: 920
#                 y: 918
#               }
#               vertices {
#                 x: 920
#                 y: 936
#               }
#               vertices {
#                 x: 910
#                 y: 936
#               }
#             }
#             text: "x"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 919
#                 y: 918
#               }
#               vertices {
#                 x: 930
#                 y: 918
#               }
#               vertices {
#                 x: 930
#                 y: 936
#               }
#               vertices {
#                 x: 919
#                 y: 936
#               }
#             }
#             text: "p"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 930
#                 y: 918
#               }
#               vertices {
#                 x: 934
#                 y: 918
#               }
#               vertices {
#                 x: 934
#                 y: 936
#               }
#               vertices {
#                 x: 930
#                 y: 936
#               }
#             }
#             text: "i"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 935
#                 y: 918
#               }
#               vertices {
#                 x: 942
#                 y: 918
#               }
#               vertices {
#                 x: 942
#                 y: 936
#               }
#               vertices {
#                 x: 935
#                 y: 936
#               }
#             }
#             text: "r"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 941
#                 y: 918
#               }
#               vertices {
#                 x: 951
#                 y: 918
#               }
#               vertices {
#                 x: 951
#                 y: 936
#               }
#               vertices {
#                 x: 941
#                 y: 936
#               }
#             }
#             text: "e"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 953
#               y: 918
#             }
#             vertices {
#               x: 993
#               y: 918
#             }
#             vertices {
#               x: 993
#               y: 936
#             }
#             vertices {
#               x: 953
#               y: 936
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 953
#                 y: 918
#               }
#               vertices {
#                 x: 963
#                 y: 918
#               }
#               vertices {
#                 x: 963
#                 y: 936
#               }
#               vertices {
#                 x: 953
#                 y: 936
#               }
#             }
#             text: "a"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 964
#                 y: 918
#               }
#               vertices {
#                 x: 973
#                 y: 918
#               }
#               vertices {
#                 x: 973
#                 y: 936
#               }
#               vertices {
#                 x: 964
#                 y: 936
#               }
#             }
#             text: "f"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 968
#                 y: 918
#               }
#               vertices {
#                 x: 977
#                 y: 918
#               }
#               vertices {
#                 x: 977
#                 y: 936
#               }
#               vertices {
#                 x: 968
#                 y: 936
#               }
#             }
#             text: "t"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 975
#                 y: 918
#               }
#               vertices {
#                 x: 986
#                 y: 918
#               }
#               vertices {
#                 x: 986
#                 y: 936
#               }
#               vertices {
#                 x: 975
#                 y: 936
#               }
#             }
#             text: "e"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 985
#                 y: 918
#               }
#               vertices {
#                 x: 993
#                 y: 918
#               }
#               vertices {
#                 x: 993
#                 y: 936
#               }
#               vertices {
#                 x: 985
#                 y: 936
#               }
#             }
#             text: "r"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 996
#               y: 918
#             }
#             vertices {
#               x: 1026
#               y: 918
#             }
#             vertices {
#               x: 1026
#               y: 936
#             }
#             vertices {
#               x: 996
#               y: 936
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 996
#                 y: 918
#               }
#               vertices {
#                 x: 1007
#                 y: 918
#               }
#               vertices {
#                 x: 1007
#                 y: 936
#               }
#               vertices {
#                 x: 996
#                 y: 936
#               }
#             }
#             text: "o"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 1005
#                 y: 918
#               }
#               vertices {
#                 x: 1015
#                 y: 918
#               }
#               vertices {
#                 x: 1015
#                 y: 936
#               }
#               vertices {
#                 x: 1005
#                 y: 936
#               }
#             }
#             text: "n"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1015
#                 y: 918
#               }
#               vertices {
#                 x: 1026
#                 y: 918
#               }
#               vertices {
#                 x: 1026
#                 y: 936
#               }
#               vertices {
#                 x: 1015
#                 y: 936
#               }
#             }
#             text: "e"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#               confidence: 1
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1028
#               y: 918
#             }
#             vertices {
#               x: 1065
#               y: 918
#             }
#             vertices {
#               x: 1065
#               y: 936
#             }
#             vertices {
#               x: 1028
#               y: 936
#             }
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 1028
#                 y: 918
#               }
#               vertices {
#                 x: 1040
#                 y: 918
#               }
#               vertices {
#                 x: 1040
#                 y: 936
#               }
#               vertices {
#                 x: 1028
#                 y: 936
#               }
#             }
#             text: "y"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 1038
#                 y: 918
#               }
#               vertices {
#                 x: 1049
#                 y: 918
#               }
#               vertices {
#                 x: 1049
#                 y: 936
#               }
#               vertices {
#                 x: 1038
#                 y: 936
#               }
#             }
#             text: "e"
#           }
#           symbols {
#             bounding_box {
#               vertices {
#                 x: 1046
#                 y: 918
#               }
#               vertices {
#                 x: 1057
#                 y: 918
#               }
#               vertices {
#                 x: 1057
#                 y: 936
#               }
#               vertices {
#                 x: 1046
#                 y: 936
#               }
#             }
#             text: "a"
#           }
#           symbols {
#             property {
#               detected_break {
#                 type_: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1056
#                 y: 918
#               }
#               vertices {
#                 x: 1065
#                 y: 918
#               }
#               vertices {
#                 x: 1065
#                 y: 936
#               }
#               vertices {
#                 x: 1056
#                 y: 936
#               }
#             }
#             text: "r"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#   }
#   text: "Single Sessions\nMENU\nMonthly Unlimited\nBuy 5 Get 2 Free\nRegular Bed\n$7.70\nRegular Bed\n$44\nRegular Bed\n$38.50\nRegular Bed with Facial\n$8.80\nRegular Bed with Facials\n$49.50\nRegular Bed with Facial\n$44\nSolaris Level 2\n$12.10\nSolaris Level 2\n$66\nSolaris Level 2\n$60.50\nSolar Force Level 3\n$15.40\nSolar Force Level 3\nSolar Force Level 3\n$77\n$77\nSunScape Level 4\n$19.80\nSunscape Level 4\n$99\nSunscape Level 4\n$99\nRed Light Therapy\n$25.00\nRed Light Therapy\nMystic Spray Tan\n$178\n$99\nHaloSauna\n$25.00\n*2 months\n$150\nBuy Minutes Get Minutes\nMystic Spray Tan\n$35.60+\n*Add-On to any monthly pkg\n$20\nBuy 50 get 20 FREE\n$77\nHaloSauna\n$70\nBuy 75 get 30 FREE\n$115.50\nWeekly Sessions\n*Add-on HaloSauna to any Monthly\n$20\nBuy 100 get 40 FREE\n$154\nMystic Spray Tan (4 max)\n$99\nHaloSauna Unlimited\n$50\nBuy 150 get 70 FREE\n$231\nAll Access UV+RLT+Halo\n$170\nHybrid UV+RLT Unlimited\n$50\nBuy 200 get 100 FREE\n$308\n*2 months\n*All prices include 10% tan tax\n*Packages expire after one year"
# }
# Failed to structure menu with reason: NOT_RESTAURANT_MENU
# {
#     "error": "NOT_RESTAURANT_MENU"
# }

# %%
res
# Out:
# MenuData(sections=[MenuSection(section='INVALID_MENU', description='NOT_RESTAURANT_MENU', items=[])])
