# %%
from menu_reader import read_menu
from allergy_detector import detect_allergens
from common.custom_types import SupportedAllergen, LabeledAllergenMenu
from test import fetch_image_from_url, save_obj, load_obj
from typing import Dict

async def run_detection(img_url:str, save_menu_filename:str, use_data_file:str | None) -> Dict[SupportedAllergen, LabeledAllergenMenu]:
    if not use_data_file:
        img = fetch_image_from_url(img_url)
        menu_data = await read_menu(img)
        save_obj(menu_data, save_menu_filename)
    else:
        menu_data = load_obj(use_data_file)
        
    detection = await detect_allergens(menu_data, [SupportedAllergen.GLUTEN, SupportedAllergen.SHELLFISH, SupportedAllergen.TREE_NUTS])
    return detection

# %%
from test import load_test_data
import os

resource_loc = os.path.join(".", "test", "resources")
resource_name = os.path.join(resource_loc, "test_data.csv")
test_data = load_test_data(resource_name)
display(test_data)

set_url = list(test_data.keys())[2]
display(set_url)
expected = test_data[set_url]
# Out:
# {'https://lh3.googleusercontent.com/gps-cs-s/AC9h4no-ksE_LnvrRx9Q7TB_9Uh0ykwM3bodo-zQZi_fwWj48MmEKsxIy3ypZF6wQoFII3KICMuPJdI7i-j_UkHtDz3uhH6DPmBgVfm_jjB6hUhtQYEoUILvv_pBbUfORB-ZJR7TALuGZA=s1024-v1': {'tuna crudo': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'crispy tofu bites': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'crispy szechuan pepper shrimp': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'spring rolls': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'grilled lemongrass wings': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'octopus': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'tiger fries': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'chinese broccoli': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'spicy eggplant': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'market salad': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': 'VERY_LIKELY'},
#   'spicy chili garlic ho fun noodles': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'braised malaysian style chicken': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_LIKELY'},
#   'crispy & spicy vegetable rice': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': 'VERY_LIKELY'},
#   'peanut street noodles': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': 'VERY_LIKELY'},
#   'market fish': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_LIKELY'}},
#  'https://lh3.googleusercontent.com/gps-cs-s/AC9h4nodlRBcbH_gpRDvRIbQ1B_BpM3r2YCoJL4iknEverAlutAVquhzAH5Krkry8hpBQfXvbM78TAhmiyQoOSJtLeZMxnX-n-T7p45mwBp7Cd5O5tp2hXYmtrbF87efeuU8gykzdoN8iw=s3072-v1': {'sushi lunch': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'sushi special': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'sushi and sashimi combo': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'salmon platter': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'veggie roll combo': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'maki combo': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'sashimi lunch': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'kaisen don': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'momoya box': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'chirashi': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'mini chirashi & cold udon w/ tempura': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'shokadou bento box': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'sukiyaki gozen': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'miso black cod': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'tempura entrée': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'momoya gozen': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'una- ju': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'cold kamo soba & salmon oyako': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'matcha molten french toast': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'soba souffle pancakes': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'pistachio cherry galette': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan}},
#  'https://lh3.googleusercontent.com/gps-cs-s/AC9h4notMFpdMNb3ppVKRschEtjnq6fh-PP6MinEV9kES2RzYyoSXD9sZJUKalO0hVfpAGlAJZNQN8Wc9uixCm8W33-w2U61MwVj4T407t9ufKs0BiLrqnZLKSwvpW6WwE0zJu6-KRcgQg=s1024-v1': {'piatto del salumiere': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'prosciutto di parma': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'carpaccio di bresaola': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'polipo octopus': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'fritto misto calamari': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'carciofini': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'insalata di cesare': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'insalata di rucola': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'gnocchi': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'bucatini arrabbiata': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'black linguine': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'calamarata': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'spinach fettuccine': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'garganelli': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'spaghetti carbonara smoked pancetta': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'fusilli avellinesi': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'lasagna': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   "rigatoni all' amatriciana guanciale": {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'parmigiana di melanzane': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'brodetto di pesce': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'pesce del di* mp': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'pollo alla milanese': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'scaloppine di pollo': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'tagliata': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'grilled seasonal vegetable plate': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'sauteed spinach': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'roasted brussels sprouts': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'herbed sautéed potatoes': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'sautéed string beans': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan}}}
# 'https://lh3.googleusercontent.com/gps-cs-s/AC9h4notMFpdMNb3ppVKRschEtjnq6fh-PP6MinEV9kES2RzYyoSXD9sZJUKalO0hVfpAGlAJZNQN8Wc9uixCm8W33-w2U61MwVj4T407t9ufKs0BiLrqnZLKSwvpW6WwE0zJu6-KRcgQg=s1024-v1'

# %%
from test import load_obj

if False:
    output = await run_detection(
        set_url, save_menu_filename="italian_menu.pkl", use_data_file=None
    )
    save_obj(output, filename="italian_detection.pkl")

output = load_obj("italian_detection.pkl")
display(output)
display(expected)
# Out:
# {<SupportedAllergen.GLUTEN: 'gluten'>: LabeledAllergenMenu(sections=[MenuSection(section='ANTIPASTI', description='', items=[MenuItem(name='PIATTO DEL SALUMIERE', description='ASSORTED CURED MEATS & CHEESES FOR 2 / FOR 4', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='This dish consists of naturally gluten-free cured meats and cheeses.')]), MenuItem(name='PROSCIUTTO DI PARMA', description='SEASONAL FRUIT', symbols=['GF'], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Prosciutto and seasonal fruit are naturally gluten-free, and the item is marked GF.')]), MenuItem(name='CARPACCIO DI BRESAOLA', description='DRIED CURED BEEF, MUSHROOM CONFIT, ARUGULA, SHAVED PARMIGIANO', symbols=['GF'], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Dried cured beef, mushrooms, arugula, and cheese are naturally gluten-free, and the item is marked GF.')]), MenuItem(name='POLIPO', description='OCTOPUS, POTATOES, OLIVE TAPENADE, CAPERS', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Octopus, potatoes, olive tapenade, and capers are naturally gluten-free ingredients.')]), MenuItem(name='FRITTO MISTO', description='CALAMARI, SHRIMP, PESCE, VEGETABLES, SPICY AIOLI', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_LIKELY', explanation="The term 'Fritto Misto' implies fried, and calamari, shrimp, and fish are commonly breaded or battered with wheat flour before frying.")]), MenuItem(name='CARCIOFINI', description='FRIED BABY ARTICHOKE HEARTS, SPICED BREAD CRUMBS', symbols=['V'], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_LIKELY', explanation="The dish explicitly contains 'BREAD CRUMBS', which are a common source of gluten.")]), MenuItem(name='INSALATA DI CESARE', description='ROMAINE, CAESAR DRESSING. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP', symbols=['V'], contains=[AllergenPrediction(allergen='gluten', prediction='MAY_CONTAIN', explanation='Caesar dressing often contains Worcestershire sauce or other ingredients with hidden gluten, and croutons are a common component of a Caesar salad, though not explicitly mentioned here.')]), MenuItem(name='INSALATA DI RUCOLA', description='ARUGULA, CHERRY TOMATO, PARMIGIANO, LEMON. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP', symbols=['V', 'GF'], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Arugula, cherry tomato, parmigiano, and lemon are naturally gluten-free, and the item is marked GF.')])]), MenuSection(section='PRIMI', description='GLUTEN FREE OR WHOLE WHEAT PASTA AVAILABLE ($2 SUPPLEMENT, EXCLUDING LASAGNA & GNOCCHI).', items=[MenuItem(name='GNOCCHI', description='RICOTTA & POTATO GNOCCHI, PESTO, STRING BEANS, PINE NUTS', symbols=['V'], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_LIKELY', explanation='Gnocchi is a type of pasta often made with wheat flour, and the section description explicitly excludes gnocchi from gluten-free pasta options.')]), MenuItem(name='BUCATINI ARRABBIATA', description='SPICY TOMATO SAUCE', symbols=['V'], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_LIKELY', explanation='Bucatini is a type of pasta, which is explicitly a common source of gluten. While GF options are available for the section, the default is gluten-containing.')]), MenuItem(name='BLACK LINGUINE', description='SQUID INK PASTA, HEAD-ON PRAWNS, SPICY TOMATO SAUCE', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_LIKELY', explanation='Linguine is a type of pasta, which is explicitly a common source of gluten. While GF options are available for the section, the default is gluten-containing.')]), MenuItem(name='CALAMARATA', description='SEAFOOD MEDLEY, LOBSTER SAUCE', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_LIKELY', explanation='Calama ...
#  <SupportedAllergen.SHELLFISH: 'shellfish'>: LabeledAllergenMenu(sections=[MenuSection(section='ANTIPASTI', description='', items=[MenuItem(name='PIATTO DEL SALUMIERE', description='ASSORTED CURED MEATS & CHEESES FOR 2 / FOR 4', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='This dish consists of cured meats and cheeses, which do not contain shellfish and are not typically associated with hidden shellfish ingredients.')]), MenuItem(name='PROSCIUTTO DI PARMA', description='SEASONAL FRUIT', symbols=['GF'], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='This dish consists of cured ham and fruit, which do not contain shellfish and are not typically associated with hidden shellfish ingredients.')]), MenuItem(name='CARPACCIO DI BRESAOLA', description='DRIED CURED BEEF, MUSHROOM CONFIT, ARUGULA, SHAVED PARMIGIANO', symbols=['GF'], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='This dish consists of beef, mushrooms, arugula, and cheese, which do not contain shellfish and are not typically associated with hidden shellfish ingredients.')]), MenuItem(name='POLIPO', description='OCTOPUS, POTATOES, OLIVE TAPENADE, CAPERS', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_LIKELY', explanation="The dish explicitly lists 'OCTOPUS', which is a type of shellfish (mollusk).")]), MenuItem(name='FRITTO MISTO', description='CALAMARI, SHRIMP, PESCE, VEGETABLES, SPICY AIOLI', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_LIKELY', explanation="The dish explicitly lists 'CALAMARI' (squid) and 'SHRIMP', both of which are shellfish.")]), MenuItem(name='CARCIOFINI', description='FRIED BABY ARTICHOKE HEARTS, SPICED BREAD CRUMBS', symbols=['V'], contains=[AllergenPrediction(allergen='shellfish', prediction='MAY_CONTAIN', explanation="This dish is fried, and the menu includes other fried items like 'Fritto Misto' (calamari, shrimp), which suggests a high risk of cross-contamination in shared fryers.")]), MenuItem(name='INSALATA DI CESARE', description='ROMAINE, CAESAR DRESSING. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP', symbols=['V'], contains=[AllergenPrediction(allergen='shellfish', prediction='MAY_CONTAIN', explanation="Caesar dressing can sometimes contain hidden shellfish ingredients (e.g., shrimp paste). Additionally, the option to add 'GRILLED SHRIMP' suggests potential cross-contamination on shared cooking surfaces.")]), MenuItem(name='INSALATA DI RUCOLA', description='ARUGULA, CHERRY TOMATO, PARMIGIANO, LEMON. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP', symbols=['V', 'GF'], contains=[AllergenPrediction(allergen='shellfish', prediction='MAY_CONTAIN', explanation="The option to add 'GRILLED SHRIMP' suggests potential cross-contamination if grilled on shared surfaces with other ingredients.")])]), MenuSection(section='PRIMI', description='GLUTEN FREE OR WHOLE WHEAT PASTA AVAILABLE ($2 SUPPLEMENT, EXCLUDING LASAGNA & GNOCCHI).', items=[MenuItem(name='GNOCCHI', description='RICOTTA & POTATO GNOCCHI, PESTO, STRING BEANS, PINE NUTS', symbols=['V'], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='The ingredients listed are naturally shellfish-free and there are no common hidden shellfish sources in this dish or cuisine type.')]), MenuItem(name='BUCATINI ARRABBIATA', description='SPICY TOMATO SAUCE', symbols=['V'], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='The ingredients listed are naturally shellfish-free and there are no common hidden shellfish sources in this dish or cuisine type.')]), MenuItem(name='BLACK LINGUINE', description='SQUID INK PASTA, HEAD-ON PRAWNS, SPICY TOMATO SAUCE', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_LIKELY', explanation="The dish explicitly lists 'SQUID INK PASTA' and 'PRAWNS', both of which a ...
#  <SupportedAllergen.TREE_NUTS: 'tree_nuts'>: LabeledAllergenMenu(sections=[MenuSection(section='ANTIPASTI', description='', items=[MenuItem(name='PIATTO DEL SALUMIERE', description='ASSORTED CURED MEATS & CHEESES FOR 2 / FOR 4', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of cured meats and cheeses, which are naturally nut-free, with no indications of tree nut ingredients.')]), MenuItem(name='PROSCIUTTO DI PARMA', description='SEASONAL FRUIT', symbols=['GF'], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of prosciutto and seasonal fruit, which are naturally nut-free, with no indications of tree nut ingredients.')]), MenuItem(name='CARPACCIO DI BRESAOLA', description='DRIED CURED BEEF, MUSHROOM CONFIT, ARUGULA, SHAVED PARMIGIANO', symbols=['GF'], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The ingredients listed do not suggest the presence of tree nuts.')]), MenuItem(name='POLIPO', description='OCTOPUS, POTATOES, OLIVE TAPENADE, CAPERS', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The ingredients listed, including olive tapenade, do not typically contain tree nuts.')]), MenuItem(name='FRITTO MISTO', description='CALAMARI, SHRIMP, PESCE, VEGETABLES, SPICY AIOLI', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of fried seafood and vegetables with aioli, none of which commonly contain tree nuts.')]), MenuItem(name='CARCIOFINI', description='FRIED BABY ARTICHOKE HEARTS, SPICED BREAD CRUMBS', symbols=['V'], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='Fried artichoke hearts and spiced bread crumbs do not explicitly or implicitly suggest the presence of tree nuts.')]), MenuItem(name='INSALATA DI CESARE', description='ROMAINE, CAESAR DRESSING. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP', symbols=['V'], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='Traditional Caesar salad ingredients do not contain tree nuts.')]), MenuItem(name='INSALATA DI RUCOLA', description='ARUGULA, CHERRY TOMATO, PARMIGIANO, LEMON. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP', symbols=['V', 'GF'], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='This simple salad consists of ingredients that are naturally nut-free.')])]), MenuSection(section='PRIMI', description='GLUTEN FREE OR WHOLE WHEAT PASTA AVAILABLE ($2 SUPPLEMENT, EXCLUDING LASAGNA & GNOCCHI).', items=[MenuItem(name='GNOCCHI', description='RICOTTA & POTATO GNOCCHI, PESTO, STRING BEANS, PINE NUTS', symbols=['V'], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_LIKELY', explanation="The description explicitly states 'PINE NUTS', which are a type of tree nut, and also mentions pesto, which is traditionally made with pine nuts.")]), MenuItem(name='BUCATINI ARRABBIATA', description='SPICY TOMATO SAUCE', symbols=['V'], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of pasta with a spicy tomato sauce, which does not typically contain tree nuts.')]), MenuItem(name='BLACK LINGUINE', description='SQUID INK PASTA, HEAD-ON PRAWNS, SPICY TOMATO SAUCE', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The ingredients listed do not suggest the presence of tree nuts.')]), MenuItem(name='CALAMARATA', description='SEAFOOD MEDLEY, LOBSTER SAUCE', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The ingredients listed do not suggest the presence of tree nuts.')]), MenuItem(name='SPINACH FETTUCCINE', description='ITALIAN SWEET SAUSAGE, SHISHITO PEPPERS, BRANDY SAUCE', symbols=[], contains= ...
# {'piatto del salumiere': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'prosciutto di parma': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'carpaccio di bresaola': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'polipo octopus': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_LIKELY',
#   'contains_peanuts': nan},
#  'fritto misto calamari': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_LIKELY',
#   'contains_peanuts': nan},
#  'carciofini': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'insalata di cesare': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'insalata di rucola': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'gnocchi': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'bucatini arrabbiata': {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'black linguine': {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_LIKELY',
#   'contains_peanuts': nan},
#  'calamarata': {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_LIKELY',
#   'contains_peanuts': nan},
#  'spinach fettuccine': {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'garganelli': {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'spaghetti carbonara smoked pancetta': {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'fusilli avellinesi': {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'lasagna': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  "rigatoni all' amatriciana guanciale": {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'parmigiana di melanzane': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'brodetto di pesce': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_LIKELY',
#   'contains_peanuts': nan},
#  'pesce del di* mp': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'MAY_CONTAIN',
#   'contains_peanuts': nan},
#  'pollo alla milanese': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'scaloppine di pollo': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'tagliata': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'grilled seasonal vegetable plate': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'sauteed spinach': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'roasted brussels sprouts': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'herbed sautéed potatoes': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'sautéed string beans': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan}}

# %%
from test import pair_expected_and_produced_items


df=pair_expected_and_produced_items(expected=expected, produced=output['gluten'])
display(df)
# Out:
#                            Item Name  ...       Expected
# 0               piatto del salumiere  ...    VERY_LIKELY
# 1                prosciutto di parma  ...  VERY_UNLIKELY
# 2              carpaccio di bresaola  ...  VERY_UNLIKELY
# 3                         carciofini  ...    VERY_LIKELY
# 4                 insalata di cesare  ...    VERY_LIKELY
# 5                 insalata di rucola  ...  VERY_UNLIKELY
# 6                            gnocchi  ...    VERY_LIKELY
# 7                bucatini arrabbiata  ...    MAY_CONTAIN
# 8                     black linguine  ...    MAY_CONTAIN
# 9                         calamarata  ...    MAY_CONTAIN
# 10                spinach fettuccine  ...    MAY_CONTAIN
# 11                        garganelli  ...    MAY_CONTAIN
# 12                fusilli avellinesi  ...    MAY_CONTAIN
# 13                           lasagna  ...    VERY_LIKELY
# 14           parmigiana di melanzane  ...  VERY_UNLIKELY
# 15                 brodetto di pesce  ...  VERY_UNLIKELY
# 16               pollo alla milanese  ...    VERY_LIKELY
# 17               scaloppine di pollo  ...    VERY_LIKELY
# 18                          tagliata  ...  VERY_UNLIKELY
# 19  grilled seasonal vegetable plate  ...  VERY_UNLIKELY
# 20           herbed sautéed potatoes  ...  VERY_UNLIKELY
# 21              sautéed string beans  ...  VERY_UNLIKELY
#
# [22 rows x 5 columns]

# %%
(df['Expected'] == df['Prediction'] ).value_counts()
# Out:
# True     13
# False     9
# Name: count, dtype: int64
