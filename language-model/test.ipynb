# %%
from menu_reader import read_menu
from allergy_detector import detect_allergens
from common.custom_types import SupportedAllergen, LabeledAllergenMenu
from test import fetch_image_from_url, save_obj, load_obj
from typing import Dict

async def run_detection(img_url:str, save_menu_filename:str, use_menu_data:str | None) -> Dict[SupportedAllergen, LabeledAllergenMenu]:
    if not use_menu_data:
        img = fetch_image_from_url(img_url)
        menu_data = await read_menu(img)
        save_obj(menu_data, save_menu_filename)
    else:
        menu_data = load_obj(use_menu_data)
        
    detection = await detect_allergens(menu_data, [SupportedAllergen.GLUTEN, SupportedAllergen.SHELLFISH, SupportedAllergen.TREE_NUTS])
    return detection

# %%
from test import load_test_data
import os

resource_loc = os.path.join(".", "test", "resources")
resource_name = os.path.join(resource_loc, "test_data.csv")
test_data = load_test_data(resource_name)
display(test_data)

set_url = list(test_data.keys())[0]
display(set_url)
expected = test_data[set_url]
# Out:
# {'https://lh3.googleusercontent.com/gps-cs-s/AC9h4notMFpdMNb3ppVKRschEtjnq6fh-PP6MinEV9kES2RzYyoSXD9sZJUKalO0hVfpAGlAJZNQN8Wc9uixCm8W33-w2U61MwVj4T407t9ufKs0BiLrqnZLKSwvpW6WwE0zJu6-KRcgQg=s1024-v1': {'piatto del salumiere': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'prosciutto di parma': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'carpaccio di bresaola': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'polipo octopus': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'fritto misto calamari': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'carciofini': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'insalata di cesare': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'insalata di rucola': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'gnocchi': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'bucatini arrabbiata': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'black linguine': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'calamarata': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'spinach fettuccine': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'garganelli': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'spaghetti carbonara smoked pancetta': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'fusilli avellinesi': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'lasagna': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   "rigatoni all' amatriciana guanciale": {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'parmigiana di melanzane': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'brodetto di pesce': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'pesce del di* mp': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'pollo alla milanese': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'scaloppine di pollo': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'tagliata': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'grilled seasonal vegetable plate': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'sauteed spinach': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'roasted brussels sprouts': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'herbed sautéed potatoes': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'sautéed string beans': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan}},
#  'https://lh3.googleusercontent.com/gps-cs-s/AC9h4nodlRBcbH_gpRDvRIbQ1B_BpM3r2YCoJL4iknEverAlutAVquhzAH5Krkry8hpBQfXvbM78TAhmiyQoOSJtLeZMxnX-n-T7p45mwBp7Cd5O5tp2hXYmtrbF87efeuU8gykzdoN8iw=s3072-v1': {'sushi lunch': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'sushi special': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'sushi and sashimi combo': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'salmon platter': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'veggie roll combo': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'maki combo': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'sashimi lunch': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'kaisen don': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'momoya box': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'chirashi': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'mini chirashi & cold udon w/ tempura': {'contains_gluten': 'MAY_CONTAIN',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'shokadou bento box': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'sukiyaki gozen': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': nan},
#   'miso black cod': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'tempura entrée': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'momoya gozen': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': nan},
#   'una- ju': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'cold kamo soba & salmon oyako': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'matcha molten french toast': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'soba souffle pancakes': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan},
#   'pistachio cherry galette': {'contains_gluten': 'VERY_LIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': nan}},
#  'https://lh3.googleusercontent.com/gps-cs-s/AC9h4no-ksE_LnvrRx9Q7TB_9Uh0ykwM3bodo-zQZi_fwWj48MmEKsxIy3ypZF6wQoFII3KICMuPJdI7i-j_UkHtDz3uhH6DPmBgVfm_jjB6hUhtQYEoUILvv_pBbUfORB-ZJR7TALuGZA=s1024-v1': {'tuna crudo': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'crispy tofu bites': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'crispy szechuan pepper shrimp': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'spring rolls': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'grilled lemongrass wings': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'octopus': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_LIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'tiger fries': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'chinese broccoli': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'spicy eggplant': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'market salad': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': 'VERY_LIKELY'},
#   'spicy chili garlic ho fun noodles': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_UNLIKELY'},
#   'braised malaysian style chicken': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_LIKELY'},
#   'crispy & spicy vegetable rice': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': 'VERY_LIKELY'},
#   'peanut street noodles': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'MAY_CONTAIN',
#    'contains_peanuts': 'VERY_LIKELY'},
#   'market fish': {'contains_gluten': 'VERY_UNLIKELY',
#    'contains_shellfish': 'VERY_UNLIKELY',
#    'contains_peanuts': 'VERY_LIKELY'}}}
# 'https://lh3.googleusercontent.com/gps-cs-s/AC9h4notMFpdMNb3ppVKRschEtjnq6fh-PP6MinEV9kES2RzYyoSXD9sZJUKalO0hVfpAGlAJZNQN8Wc9uixCm8W33-w2U61MwVj4T407t9ufKs0BiLrqnZLKSwvpW6WwE0zJu6-KRcgQg=s1024-v1'

# %%
from test import load_obj

if True:
    output = await run_detection(
        set_url, save_menu_filename="italian_menu.pkl", use_menu_data="italian_menu.pkl"
    )
    save_obj(output, filename="italian_detection.pkl")

output = load_obj("italian_detection.pkl")
display(output)
display(expected)
# Out:
# START RESPONSE TEXT
# {
#   "sections": [
#     {
#       "section": "ANTIPASTI",
#       "description": "",
#       "items": [
#         {
#           "name": "PIATTO DEL SALUMIERE",
#           "description": "ASSORTED CURED MEATS & CHEESES FOR 2 / FOR 4",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of simple cured meats and cheeses, which do not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "PROSCIUTTO DI PARMA",
#           "description": "SEASONAL FRUIT",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of simple prosciutto and fruit, which do not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "CARPACCIO DI BRESAOLA",
#           "description": "DRIED CURED BEEF, MUSHROOM CONFIT, ARUGULA, SHAVED PARMIGIANO",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of simple ingredients that do not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "POLIPO",
#           "description": "OCTOPUS, POTATOES, OLIVE TAPENADE, CAPERS",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of simple ingredients that do not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "FRITTO MISTO",
#           "description": "CALAMARI, SHRIMP, PESCE, VEGETABLES, SPICY AIOLI",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of fried seafood and vegetables, with no explicit tree nut ingredients."
#             }
#           ]
#         },
#         {
#           "name": "CARCIOFINI",
#           "description": "FRIED BABY ARTICHOKE HEARTS, SPICED BREAD CRUMBS",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of fried artichokes with bread crumbs, which do not typically contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "INSALATA DI CESARE",
#           "description": "ROMAINE, CAESAR DRESSING. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of a Caesar salad, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "INSALATA DI RUCOLA",
#           "description": "ARUGULA, CHERRY TOMATO, PARMIGIANO, LEMON. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP",
#           "symbols": [
#             "V",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of a simple arugula salad with no explicit tree nut ingredients."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "PRIMI",
#       "description": "GLUTEN FREE OR WHOLE WHEAT PASTA AVAILABLE ($2 SUPPLEMENT, EXCLUDING LASAGNA & GNOCCHI).",
#       "items": [
#         {
#           "name": "GNOCCHI",
#           "description": "RICOTTA & POTATO GNOCCHI, PESTO, STRING BEANS, PINE NUTS",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The description explicitly lists 'PINE NUTS', which are a type of tree nut."
#             }
#           ]
#         },
#         {
#           "name": "BUCATINI ARRABBIATA",
#           "description": "SPICY TOMATO SAUCE",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta with spicy tomato sauce, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "BLACK LINGUINE",
#           "description": "SQUID INK PASTA, HEAD-ON PRAWNS, SPICY TOMATO SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta with seafood and tomato sauce, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "CALAMARATA",
#           "description": "SEAFOOD MEDLEY, LOBSTER SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta with seafood and lobster sauce, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "SPINACH FETTUCCINE",
#           "description": "ITALIAN SWEET SAUSAGE, SHISHITO PEPPERS, BRANDY SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta with sausage and peppers, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "GARGANELLI",
#           "description": "WAGYU BOLOGNESE, PARMIGIANO",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta with Bolognese sauce, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "SPAGHETTI CARBONARA",
#           "description": "SMOKED PANCETTA (PORK), PECORINO, BLACK PEPPER",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta Carbonara, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "FUSILLI AVELLINESI",
#           "description": "LAMB RAGU, SAFFRON CREAM, MICRO GREENS",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta with lamb ragu, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "LASAGNA",
#           "description": "WAGYU BOLOGNESE, TOMATO & BÉCHAMEL SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of lasagna with Bolognese and béchamel sauces, which do not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "RIGATONI ALL' AMATRICIANA",
#           "description": "GUANCIALE (PORK CHEEK), TOMATO, PECORINO, RED CHILI FLAKE, RED ONION",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta Amatriciana, which does not naturally contain tree nuts."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "SECONDI",
#       "description": "",
#       "items": [
#         {
#           "name": "PARMIGIANA DI MELANZANE",
#           "description": "EGGPLANT, MOZZARELLA, TOMATO",
#           "symbols": [
#             "V",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of eggplant parmigiana, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "BRODETTO DI PESCE",
#           "description": "LOBSTER TOMATO BROTH, CLAMS, MUSSELS, SHRIMP, CALAMARI",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of a seafood broth, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "PESCE DEL DI*",
#           "description": "",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "A simple fish dish does not typically contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "POLLO ALLA MILANESE",
#           "description": "ARUGULA & CHERRY TOMATO SALAD",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Chicken Milanese is a breaded cutlet, which typically does not contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "SCALOPPINE DI POLLO",
#           "description": "GRILLED VEGETABLES, WHITE WINE, LEMON, CAPERS",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of chicken scaloppine with vegetables, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "TAGLIATA*",
#           "description": "SLICED BLACK ANGUS NY STRIP STEAK, HERBED SAUTÉED POTATOES, BRANDY PEPPERCORN SAUCE",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of steak with potatoes and sauce, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "GRILLED SEASONAL VEGETABLE PLATE",
#           "description": "",
#           "symbols": [
#             "V",
#             "VG",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of grilled vegetables, which do not naturally contain tree nuts."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "CONTORNI",
#       "description": "",
#       "items": [
#         {
#           "name": "SAUTÉED SPINACH",
#           "description": "",
#           "symbols": [
#             "V",
#             "VG",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of sautéed spinach, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "ROASTED BRUSSELS SPROUTS, PANCETTA (PORK)",
#           "description": "",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of roasted Brussels sprouts with pancetta, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "HERBED SAUTÉED POTATOES",
#           "description": "",
#           "symbols": [
#             "V",
#             "VG",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of sautéed potatoes, which do not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "SAUTÉED STRING BEANS",
#           "description": "",
#           "symbols": [
#             "V",
#             "VG",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of sautéed string beans, which do not naturally contain tree nuts."
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }
# END RESPONSE TEXT
# {
#   "sections": [
#     {
#       "section": "ANTIPASTI",
#       "description": "",
#       "items": [
#         {
#           "name": "PIATTO DEL SALUMIERE",
#           "description": "ASSORTED CURED MEATS & CHEESES FOR 2 / FOR 4",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of simple cured meats and cheeses, which do not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "PROSCIUTTO DI PARMA",
#           "description": "SEASONAL FRUIT",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of simple prosciutto and fruit, which do not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "CARPACCIO DI BRESAOLA",
#           "description": "DRIED CURED BEEF, MUSHROOM CONFIT, ARUGULA, SHAVED PARMIGIANO",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of simple ingredients that do not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "POLIPO",
#           "description": "OCTOPUS, POTATOES, OLIVE TAPENADE, CAPERS",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of simple ingredients that do not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "FRITTO MISTO",
#           "description": "CALAMARI, SHRIMP, PESCE, VEGETABLES, SPICY AIOLI",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of fried seafood and vegetables, with no explicit tree nut ingredients."
#             }
#           ]
#         },
#         {
#           "name": "CARCIOFINI",
#           "description": "FRIED BABY ARTICHOKE HEARTS, SPICED BREAD CRUMBS",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of fried artichokes with bread crumbs, which do not typically contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "INSALATA DI CESARE",
#           "description": "ROMAINE, CAESAR DRESSING. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of a Caesar salad, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "INSALATA DI RUCOLA",
#           "description": "ARUGULA, CHERRY TOMATO, PARMIGIANO, LEMON. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP",
#           "symbols": [
#             "V",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of a simple arugula salad with no explicit tree nut ingredients."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "PRIMI",
#       "description": "GLUTEN FREE OR WHOLE WHEAT PASTA AVAILABLE ($2 SUPPLEMENT, EXCLUDING LASAGNA & GNOCCHI).",
#       "items": [
#         {
#           "name": "GNOCCHI",
#           "description": "RICOTTA & POTATO GNOCCHI, PESTO, STRING BEANS, PINE NUTS",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The description explicitly lists 'PINE NUTS', which are a type of tree nut."
#             }
#           ]
#         },
#         {
#           "name": "BUCATINI ARRABBIATA",
#           "description": "SPICY TOMATO SAUCE",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta with spicy tomato sauce, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "BLACK LINGUINE",
#           "description": "SQUID INK PASTA, HEAD-ON PRAWNS, SPICY TOMATO SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta with seafood and tomato sauce, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "CALAMARATA",
#           "description": "SEAFOOD MEDLEY, LOBSTER SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta with seafood and lobster sauce, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "SPINACH FETTUCCINE",
#           "description": "ITALIAN SWEET SAUSAGE, SHISHITO PEPPERS, BRANDY SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta with sausage and peppers, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "GARGANELLI",
#           "description": "WAGYU BOLOGNESE, PARMIGIANO",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta with Bolognese sauce, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "SPAGHETTI CARBONARA",
#           "description": "SMOKED PANCETTA (PORK), PECORINO, BLACK PEPPER",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta Carbonara, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "FUSILLI AVELLINESI",
#           "description": "LAMB RAGU, SAFFRON CREAM, MICRO GREENS",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta with lamb ragu, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "LASAGNA",
#           "description": "WAGYU BOLOGNESE, TOMATO & BÉCHAMEL SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of lasagna with Bolognese and béchamel sauces, which do not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "RIGATONI ALL' AMATRICIANA",
#           "description": "GUANCIALE (PORK CHEEK), TOMATO, PECORINO, RED CHILI FLAKE, RED ONION",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of pasta Amatriciana, which does not naturally contain tree nuts."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "SECONDI",
#       "description": "",
#       "items": [
#         {
#           "name": "PARMIGIANA DI MELANZANE",
#           "description": "EGGPLANT, MOZZARELLA, TOMATO",
#           "symbols": [
#             "V",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of eggplant parmigiana, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "BRODETTO DI PESCE",
#           "description": "LOBSTER TOMATO BROTH, CLAMS, MUSSELS, SHRIMP, CALAMARI",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of a seafood broth, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "PESCE DEL DI*",
#           "description": "",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "A simple fish dish does not typically contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "POLLO ALLA MILANESE",
#           "description": "ARUGULA & CHERRY TOMATO SALAD",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Chicken Milanese is a breaded cutlet, which typically does not contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "SCALOPPINE DI POLLO",
#           "description": "GRILLED VEGETABLES, WHITE WINE, LEMON, CAPERS",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of chicken scaloppine with vegetables, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "TAGLIATA*",
#           "description": "SLICED BLACK ANGUS NY STRIP STEAK, HERBED SAUTÉED POTATOES, BRANDY PEPPERCORN SAUCE",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of steak with potatoes and sauce, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "GRILLED SEASONAL VEGETABLE PLATE",
#           "description": "",
#           "symbols": [
#             "V",
#             "VG",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of grilled vegetables, which do not naturally contain tree nuts."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "CONTORNI",
#       "description": "",
#       "items": [
#         {
#           "name": "SAUTÉED SPINACH",
#           "description": "",
#           "symbols": [
#             "V",
#             "VG",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of sautéed spinach, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "ROASTED BRUSSELS SPROUTS, PANCETTA (PORK)",
#           "description": "",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of roasted Brussels sprouts with pancetta, which does not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "HERBED SAUTÉED POTATOES",
#           "description": "",
#           "symbols": [
#             "V",
#             "VG",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of sautéed potatoes, which do not naturally contain tree nuts."
#             }
#           ]
#         },
#         {
#           "name": "SAUTÉED STRING BEANS",
#           "description": "",
#           "symbols": [
#             "V",
#             "VG",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "tree_nuts",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of sautéed string beans, which do not naturally contain tree nuts."
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }
# START RESPONSE TEXT
# {
#   "sections": [
#     {
#       "section": "ANTIPASTI",
#       "description": "",
#       "items": [
#         {
#           "name": "PIATTO DEL SALUMIERE",
#           "description": "ASSORTED CURED MEATS & CHEESES FOR 2 / FOR 4",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of cured meats and cheeses, which do not typically contain shellfish."
#             }
#           ]
#         },
#         {
#           "name": "PROSCIUTTO DI PARMA",
#           "description": "SEASONAL FRUIT",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This dish explicitly lists prosciutto and fruit, which are naturally shellfish-free."
#             }
#           ]
#         },
#         {
#           "name": "CARPACCIO DI BRESAOLA",
#           "description": "DRIED CURED BEEF, MUSHROOM CONFIT, ARUGULA, SHAVED PARMIGIANO",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The ingredients listed (dried cured beef, mushrooms, arugula, cheese) are naturally shellfish-free."
#             }
#           ]
#         },
#         {
#           "name": "POLIPO",
#           "description": "OCTOPUS, POTATOES, OLIVE TAPENADE, CAPERS",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The dish explicitly lists 'Octopus', which is a mollusk and thus a shellfish."
#             }
#           ]
#         },
#         {
#           "name": "FRITTO MISTO",
#           "description": "CALAMARI, SHRIMP, PESCE, VEGETABLES, SPICY AIOLI",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The dish explicitly lists 'Calamari' (squid) and 'Shrimp', both of which are common shellfish."
#             }
#           ]
#         },
#         {
#           "name": "CARCIOFINI",
#           "description": "FRIED BABY ARTICHOKE HEARTS, SPICED BREAD CRUMBS",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This is a vegetarian dish of fried artichoke hearts, and no shellfish ingredients or hidden sources are indicated."
#             }
#           ]
#         },
#         {
#           "name": "INSALATA DI CESARE",
#           "description": "ROMAINE, CAESAR DRESSING. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "While Caesar dressing traditionally contains anchovies (fish), some recipes or commercial versions may include shrimp paste, making it a potential hidden source. The option to add grilled shrimp also increases the risk of cross-contamination."
#             }
#           ]
#         },
#         {
#           "name": "INSALATA DI RUCOLA",
#           "description": "ARUGULA, CHERRY TOMATO, PARMIGIANO, LEMON. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP",
#           "symbols": [
#             "V",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "The option to add grilled shrimp introduces a risk of cross-contamination with shellfish during preparation."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "PRIMI",
#       "description": "GLUTEN FREE OR WHOLE WHEAT PASTA AVAILABLE ($2 SUPPLEMENT, EXCLUDING LASAGNA & GNOCCHI).",
#       "items": [
#         {
#           "name": "GNOCCHI",
#           "description": "RICOTTA & POTATO GNOCCHI, PESTO, STRING BEANS, PINE NUTS",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The ingredients listed are naturally shellfish-free, and no hidden sources are expected in traditional pesto or gnocchi."
#             }
#           ]
#         },
#         {
#           "name": "BUCATINI ARRABBIATA",
#           "description": "SPICY TOMATO SAUCE",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This is a vegetarian pasta dish with a spicy tomato sauce, containing no explicit or hidden shellfish ingredients."
#             }
#           ]
#         },
#         {
#           "name": "BLACK LINGUINE",
#           "description": "SQUID INK PASTA, HEAD-ON PRAWNS, SPICY TOMATO SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The dish explicitly contains 'Prawns' and 'Squid Ink Pasta', with squid ink derived from a mollusk (squid), making it a very likely source of shellfish."
#             }
#           ]
#         },
#         {
#           "name": "CALAMARATA",
#           "description": "SEAFOOD MEDLEY, LOBSTER SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The dish explicitly mentions 'Seafood Medley' and 'Lobster Sauce', indicating the definite presence of shellfish."
#             }
#           ]
#         },
#         {
#           "name": "SPINACH FETTUCCINE",
#           "description": "ITALIAN SWEET SAUSAGE, SHISHITO PEPPERS, BRANDY SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The ingredients listed (sausage, peppers, brandy sauce) are not typically associated with shellfish and no hidden sources are expected."
#             }
#           ]
#         },
#         {
#           "name": "GARGANELLI",
#           "description": "WAGYU BOLOGNESE, PARMIGIANO",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This dish features beef bolognese and cheese, neither of which contains shellfish or its derivatives."
#             }
#           ]
#         },
#         {
#           "name": "SPAGHETTI CARBONARA",
#           "description": "SMOKED PANCETTA (PORK), PECORINO, BLACK PEPPER",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The ingredients listed (pancetta, cheese, pepper) are naturally shellfish-free."
#             }
#           ]
#         },
#         {
#           "name": "FUSILLI AVELLINESI",
#           "description": "LAMB RAGU, SAFFRON CREAM, MICRO GREENS",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The ingredients listed (lamb ragu, saffron cream) are naturally shellfish-free."
#             }
#           ]
#         },
#         {
#           "name": "LASAGNA",
#           "description": "WAGYU BOLOGNESE, TOMATO & BÉCHAMEL SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This dish features beef bolognese and béchamel sauce, neither of which contains shellfish or its derivatives."
#             }
#           ]
#         },
#         {
#           "name": "RIGATONI ALL' AMATRICIANA",
#           "description": "GUANCIALE (PORK CHEEK), TOMATO, PECORINO, RED CHILI FLAKE, RED ONION",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The ingredients listed (pork cheek, tomato, cheese) are naturally shellfish-free."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "SECONDI",
#       "description": "",
#       "items": [
#         {
#           "name": "PARMIGIANA DI MELANZANE",
#           "description": "EGGPLANT, MOZZARELLA, TOMATO",
#           "symbols": [
#             "V",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This is a vegetarian dish consisting of eggplant, mozzarella, and tomato, with no shellfish ingredients."
#             }
#           ]
#         },
#         {
#           "name": "BRODETTO DI PESCE",
#           "description": "LOBSTER TOMATO BROTH, CLAMS, MUSSELS, SHRIMP, CALAMARI",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The dish explicitly lists 'Lobster', 'Clams', 'Mussels', 'Shrimp', and 'Calamari', all of which are common shellfish."
#             }
#           ]
#         },
#         {
#           "name": "PESCE DEL DI*",
#           "description": "",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "The name 'Pesce del Di' means 'Fish of the Day', but without further description, it's possible it could be served with a shellfish-based sauce or prepared on shared equipment, increasing the risk for shellfish."
#             }
#           ]
#         },
#         {
#           "name": "POLLO ALLA MILANESE",
#           "description": "ARUGULA & CHERRY TOMATO SALAD",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This chicken dish with salad contains no explicit shellfish ingredients or known hidden sources."
#             }
#           ]
#         },
#         {
#           "name": "SCALOPPINE DI POLLO",
#           "description": "GRILLED VEGETABLES, WHITE WINE, LEMON, CAPERS",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This chicken dish with grilled vegetables and a white wine sauce contains no explicit shellfish ingredients or known hidden sources."
#             }
#           ]
#         },
#         {
#           "name": "TAGLIATA*",
#           "description": "SLICED BLACK ANGUS NY STRIP STEAK, HERBED SAUTÉED POTATOES, BRANDY PEPPERCORN SAUCE",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The ingredients listed (steak, potatoes, peppercorn sauce) are naturally shellfish-free."
#             }
#           ]
#         },
#         {
#           "name": "GRILLED SEASONAL VEGETABLE PLATE",
#           "description": "",
#           "symbols": [
#             "V",
#             "VG",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This is a vegetarian and vegan dish of grilled vegetables, with no explicit or hidden shellfish ingredients."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "CONTORNI",
#       "description": "",
#       "items": [
#         {
#           "name": "SAUTÉED SPINACH",
#           "description": "",
#           "symbols": [
#             "V",
#             "VG",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This is a simple side dish of sautéed spinach, which is naturally shellfish-free."
#             }
#           ]
#         },
#         {
#           "name": "ROASTED BRUSSELS SPROUTS, PANCETTA (PORK)",
#           "description": "",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish contains Brussels sprouts and pancetta (pork), neither of which are sources of shellfish."
#             }
#           ]
#         },
#         {
#           "name": "HERBED SAUTÉED POTATOES",
#           "description": "",
#           "symbols": [
#             "V",
#             "VG",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This is a simple side dish of herbed sautéed potatoes, which are naturally shellfish-free."
#             }
#           ]
#         },
#         {
#           "name": "SAUTÉED STRING BEANS",
#           "description": "",
#           "symbols": [
#             "V",
#             "VG",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This is a simple side dish of sautéed string beans, which are naturally shellfish-free."
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }
# END RESPONSE TEXT
# {
#   "sections": [
#     {
#       "section": "ANTIPASTI",
#       "description": "",
#       "items": [
#         {
#           "name": "PIATTO DEL SALUMIERE",
#           "description": "ASSORTED CURED MEATS & CHEESES FOR 2 / FOR 4",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The dish consists of cured meats and cheeses, which do not typically contain shellfish."
#             }
#           ]
#         },
#         {
#           "name": "PROSCIUTTO DI PARMA",
#           "description": "SEASONAL FRUIT",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This dish explicitly lists prosciutto and fruit, which are naturally shellfish-free."
#             }
#           ]
#         },
#         {
#           "name": "CARPACCIO DI BRESAOLA",
#           "description": "DRIED CURED BEEF, MUSHROOM CONFIT, ARUGULA, SHAVED PARMIGIANO",
#           "symbols": [
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The ingredients listed (dried cured beef, mushrooms, arugula, cheese) are naturally shellfish-free."
#             }
#           ]
#         },
#         {
#           "name": "POLIPO",
#           "description": "OCTOPUS, POTATOES, OLIVE TAPENADE, CAPERS",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The dish explicitly lists 'Octopus', which is a mollusk and thus a shellfish."
#             }
#           ]
#         },
#         {
#           "name": "FRITTO MISTO",
#           "description": "CALAMARI, SHRIMP, PESCE, VEGETABLES, SPICY AIOLI",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The dish explicitly lists 'Calamari' (squid) and 'Shrimp', both of which are common shellfish."
#             }
#           ]
#         },
#         {
#           "name": "CARCIOFINI",
#           "description": "FRIED BABY ARTICHOKE HEARTS, SPICED BREAD CRUMBS",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This is a vegetarian dish of fried artichoke hearts, and no shellfish ingredients or hidden sources are indicated."
#             }
#           ]
#         },
#         {
#           "name": "INSALATA DI CESARE",
#           "description": "ROMAINE, CAESAR DRESSING. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "While Caesar dressing traditionally contains anchovies (fish), some recipes or commercial versions may include shrimp paste, making it a potential hidden source. The option to add grilled shrimp also increases the risk of cross-contamination."
#             }
#           ]
#         },
#         {
#           "name": "INSALATA DI RUCOLA",
#           "description": "ARUGULA, CHERRY TOMATO, PARMIGIANO, LEMON. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP",
#           "symbols": [
#             "V",
#             "GF"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "MAY_CONTAIN",
#               "explanation": "The option to add grilled shrimp introduces a risk of cross-contamination with shellfish during preparation."
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "section": "PRIMI",
#       "description": "GLUTEN FREE OR WHOLE WHEAT PASTA AVAILABLE ($2 SUPPLEMENT, EXCLUDING LASAGNA & GNOCCHI).",
#       "items": [
#         {
#           "name": "GNOCCHI",
#           "description": "RICOTTA & POTATO GNOCCHI, PESTO, STRING BEANS, PINE NUTS",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The ingredients listed are naturally shellfish-free, and no hidden sources are expected in traditional pesto or gnocchi."
#             }
#           ]
#         },
#         {
#           "name": "BUCATINI ARRABBIATA",
#           "description": "SPICY TOMATO SAUCE",
#           "symbols": [
#             "V"
#           ],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This is a vegetarian pasta dish with a spicy tomato sauce, containing no explicit or hidden shellfish ingredients."
#             }
#           ]
#         },
#         {
#           "name": "BLACK LINGUINE",
#           "description": "SQUID INK PASTA, HEAD-ON PRAWNS, SPICY TOMATO SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The dish explicitly contains 'Prawns' and 'Squid Ink Pasta', with squid ink derived from a mollusk (squid), making it a very likely source of shellfish."
#             }
#           ]
#         },
#         {
#           "name": "CALAMARATA",
#           "description": "SEAFOOD MEDLEY, LOBSTER SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_LIKELY",
#               "explanation": "The dish explicitly mentions 'Seafood Medley' and 'Lobster Sauce', indicating the definite presence of shellfish."
#             }
#           ]
#         },
#         {
#           "name": "SPINACH FETTUCCINE",
#           "description": "ITALIAN SWEET SAUSAGE, SHISHITO PEPPERS, BRANDY SAUCE",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The ingredients listed (sausage, peppers, brandy sauce) are not typically associated with shellfish and no hidden sources are expected."
#             }
#           ]
#         },
#         {
#           "name": "GARGANELLI",
#           "description": "WAGYU BOLOGNESE, PARMIGIANO",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "This dish features beef bolognese and cheese, neither of which contains shellfish or its derivatives."
#             }
#           ]
#         },
#         {
#           "name": "SPAGHETTI CARBONARA",
#           "description": "SMOKED PANCETTA (PORK), PECORINO, BLACK PEPPER",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The ingredients listed (pancetta, cheese, pepper) are naturally shellfish-free."
#             }
#           ]
#         },
#         {
#           "name": "FUSILLI AVELLINESI",
#           "description": "LAMB RAGU, SAFFRON CREAM, MICRO GREENS",
#           "symbols": [],
#           "contains": [
#             {
#               "allergen": "shellfish",
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "The ingredients listed (lamb ragu, saffron cream) are naturally shellfish-free."
#             }
#           ]
#         },
# ...
#               "prediction": "VERY_UNLIKELY",
#               "explanation": "Tagged as GF and consists of naturally gluten-free sautéed string beans with no indication of gluten-containing ingredients or cross-contamination."
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }
# {<SupportedAllergen.GLUTEN: 'gluten'>: LabeledAllergenMenu(sections=[MenuSection(section='ANTIPASTI', description='', items=[MenuItem(name='PIATTO DEL SALUMIERE', description='ASSORTED CURED MEATS & CHEESES FOR 2 / FOR 4', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Contains naturally gluten-free ingredients, and no gluten-containing sauces or preparations are mentioned.')]), MenuItem(name='PROSCIUTTO DI PARMA', description='SEASONAL FRUIT', symbols=['GF'], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Tagged as GF and consists of naturally gluten-free ingredients with no indications of cross-contamination.')]), MenuItem(name='CARPACCIO DI BRESAOLA', description='DRIED CURED BEEF, MUSHROOM CONFIT, ARUGULA, SHAVED PARMIGIANO', symbols=['GF'], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Tagged as GF and consists of naturally gluten-free ingredients with no indications of cross-contamination.')]), MenuItem(name='POLIPO', description='OCTOPUS, POTATOES, OLIVE TAPENADE, CAPERS', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Contains naturally gluten-free ingredients, and no gluten-containing sauces or preparations are mentioned.')]), MenuItem(name='FRITTO MISTO', description='CALAMARI, SHRIMP, PESCE, VEGETABLES, SPICY AIOLI', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_LIKELY', explanation='Fritto Misto typically implies a battered and fried preparation, which almost always contains wheat flour.')]), MenuItem(name='CARCIOFINI', description='FRIED BABY ARTICHOKE HEARTS, SPICED BREAD CRUMBS', symbols=['V'], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_LIKELY', explanation="The description explicitly mentions 'bread crumbs,' which are a common source of gluten.")]), MenuItem(name='INSALATA DI CESARE', description='ROMAINE, CAESAR DRESSING. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP', symbols=['V'], contains=[AllergenPrediction(allergen='gluten', prediction='MAY_CONTAIN', explanation='Caesar salads often contain croutons, and the dressing may contain hidden gluten ingredients or be made with thickeners.')]), MenuItem(name='INSALATA DI RUCOLA', description='ARUGULA, CHERRY TOMATO, PARMIGIANO, LEMON. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP', symbols=['V', 'GF'], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_UNLIKELY', explanation='Tagged as GF and consists of naturally gluten-free ingredients with no indications of cross-contamination.')])]), MenuSection(section='PRIMI', description='GLUTEN FREE OR WHOLE WHEAT PASTA AVAILABLE ($2 SUPPLEMENT, EXCLUDING LASAGNA & GNOCCHI).', items=[MenuItem(name='GNOCCHI', description='RICOTTA & POTATO GNOCCHI, PESTO, STRING BEANS, PINE NUTS', symbols=['V'], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_LIKELY', explanation='Gnocchi is explicitly excluded from gluten-free substitutions and is typically made with wheat flour, a common source of gluten.')]), MenuItem(name='BUCATINI ARRABBIATA', description='SPICY TOMATO SAUCE', symbols=['V'], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_LIKELY', explanation='Bucatini is a type of pasta, which is explicitly stated in the section description to be gluten-containing by default. Wheat is a common source of gluten.')]), MenuItem(name='BLACK LINGUINE', description='SQUID INK PASTA, HEAD-ON PRAWNS, SPICY TOMATO SAUCE', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_LIKELY', explanation='Linguine is a type of pasta, which is explicitly stated in the section description to be gluten-containing by default. Wheat is a common source of gluten.')]), MenuItem(name='CALAMARATA', description='SEAFOOD MEDLEY, LOBSTER SAUCE', symbols=[], contains=[AllergenPrediction(allergen='gluten', prediction='VERY_LIKELY', explanation='Calamarata is a typ ...
#  <SupportedAllergen.SHELLFISH: 'shellfish'>: LabeledAllergenMenu(sections=[MenuSection(section='ANTIPASTI', description='', items=[MenuItem(name='PIATTO DEL SALUMIERE', description='ASSORTED CURED MEATS & CHEESES FOR 2 / FOR 4', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='The dish consists of cured meats and cheeses, which do not typically contain shellfish.')]), MenuItem(name='PROSCIUTTO DI PARMA', description='SEASONAL FRUIT', symbols=['GF'], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='This dish explicitly lists prosciutto and fruit, which are naturally shellfish-free.')]), MenuItem(name='CARPACCIO DI BRESAOLA', description='DRIED CURED BEEF, MUSHROOM CONFIT, ARUGULA, SHAVED PARMIGIANO', symbols=['GF'], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='The ingredients listed (dried cured beef, mushrooms, arugula, cheese) are naturally shellfish-free.')]), MenuItem(name='POLIPO', description='OCTOPUS, POTATOES, OLIVE TAPENADE, CAPERS', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_LIKELY', explanation="The dish explicitly lists 'Octopus', which is a mollusk and thus a shellfish.")]), MenuItem(name='FRITTO MISTO', description='CALAMARI, SHRIMP, PESCE, VEGETABLES, SPICY AIOLI', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_LIKELY', explanation="The dish explicitly lists 'Calamari' (squid) and 'Shrimp', both of which are common shellfish.")]), MenuItem(name='CARCIOFINI', description='FRIED BABY ARTICHOKE HEARTS, SPICED BREAD CRUMBS', symbols=['V'], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='This is a vegetarian dish of fried artichoke hearts, and no shellfish ingredients or hidden sources are indicated.')]), MenuItem(name='INSALATA DI CESARE', description='ROMAINE, CAESAR DRESSING. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP', symbols=['V'], contains=[AllergenPrediction(allergen='shellfish', prediction='MAY_CONTAIN', explanation='While Caesar dressing traditionally contains anchovies (fish), some recipes or commercial versions may include shrimp paste, making it a potential hidden source. The option to add grilled shrimp also increases the risk of cross-contamination.')]), MenuItem(name='INSALATA DI RUCOLA', description='ARUGULA, CHERRY TOMATO, PARMIGIANO, LEMON. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP', symbols=['V', 'GF'], contains=[AllergenPrediction(allergen='shellfish', prediction='MAY_CONTAIN', explanation='The option to add grilled shrimp introduces a risk of cross-contamination with shellfish during preparation.')])]), MenuSection(section='PRIMI', description='GLUTEN FREE OR WHOLE WHEAT PASTA AVAILABLE ($2 SUPPLEMENT, EXCLUDING LASAGNA & GNOCCHI).', items=[MenuItem(name='GNOCCHI', description='RICOTTA & POTATO GNOCCHI, PESTO, STRING BEANS, PINE NUTS', symbols=['V'], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='The ingredients listed are naturally shellfish-free, and no hidden sources are expected in traditional pesto or gnocchi.')]), MenuItem(name='BUCATINI ARRABBIATA', description='SPICY TOMATO SAUCE', symbols=['V'], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_UNLIKELY', explanation='This is a vegetarian pasta dish with a spicy tomato sauce, containing no explicit or hidden shellfish ingredients.')]), MenuItem(name='BLACK LINGUINE', description='SQUID INK PASTA, HEAD-ON PRAWNS, SPICY TOMATO SAUCE', symbols=[], contains=[AllergenPrediction(allergen='shellfish', prediction='VERY_LIKELY', explanation="The dish explicitly contains 'Prawns' and 'Squid Ink Pasta', with squid ink derived from a mollusk (squid), making it a very likely source of shellfish.")]), MenuItem(name='CALAMARATA', description='SEAFOOD MEDLEY, LOBSTER SAUCE', symbols=[], contains=[AllergenPrediction(allergen='shellfish', pre ...
#  <SupportedAllergen.TREE_NUTS: 'tree_nuts'>: LabeledAllergenMenu(sections=[MenuSection(section='ANTIPASTI', description='', items=[MenuItem(name='PIATTO DEL SALUMIERE', description='ASSORTED CURED MEATS & CHEESES FOR 2 / FOR 4', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of simple cured meats and cheeses, which do not naturally contain tree nuts.')]), MenuItem(name='PROSCIUTTO DI PARMA', description='SEASONAL FRUIT', symbols=['GF'], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of simple prosciutto and fruit, which do not naturally contain tree nuts.')]), MenuItem(name='CARPACCIO DI BRESAOLA', description='DRIED CURED BEEF, MUSHROOM CONFIT, ARUGULA, SHAVED PARMIGIANO', symbols=['GF'], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of simple ingredients that do not naturally contain tree nuts.')]), MenuItem(name='POLIPO', description='OCTOPUS, POTATOES, OLIVE TAPENADE, CAPERS', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of simple ingredients that do not naturally contain tree nuts.')]), MenuItem(name='FRITTO MISTO', description='CALAMARI, SHRIMP, PESCE, VEGETABLES, SPICY AIOLI', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of fried seafood and vegetables, with no explicit tree nut ingredients.')]), MenuItem(name='CARCIOFINI', description='FRIED BABY ARTICHOKE HEARTS, SPICED BREAD CRUMBS', symbols=['V'], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of fried artichokes with bread crumbs, which do not typically contain tree nuts.')]), MenuItem(name='INSALATA DI CESARE', description='ROMAINE, CAESAR DRESSING. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP', symbols=['V'], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of a Caesar salad, which does not naturally contain tree nuts.')]), MenuItem(name='INSALATA DI RUCOLA', description='ARUGULA, CHERRY TOMATO, PARMIGIANO, LEMON. ADD GRILLED CHICKEN / ADD GRILLED SHRIMP', symbols=['V', 'GF'], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of a simple arugula salad with no explicit tree nut ingredients.')])]), MenuSection(section='PRIMI', description='GLUTEN FREE OR WHOLE WHEAT PASTA AVAILABLE ($2 SUPPLEMENT, EXCLUDING LASAGNA & GNOCCHI).', items=[MenuItem(name='GNOCCHI', description='RICOTTA & POTATO GNOCCHI, PESTO, STRING BEANS, PINE NUTS', symbols=['V'], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_LIKELY', explanation="The description explicitly lists 'PINE NUTS', which are a type of tree nut.")]), MenuItem(name='BUCATINI ARRABBIATA', description='SPICY TOMATO SAUCE', symbols=['V'], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of pasta with spicy tomato sauce, which does not naturally contain tree nuts.')]), MenuItem(name='BLACK LINGUINE', description='SQUID INK PASTA, HEAD-ON PRAWNS, SPICY TOMATO SAUCE', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of pasta with seafood and tomato sauce, which does not naturally contain tree nuts.')]), MenuItem(name='CALAMARATA', description='SEAFOOD MEDLEY, LOBSTER SAUCE', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', prediction='VERY_UNLIKELY', explanation='The dish consists of pasta with seafood and lobster sauce, which does not naturally contain tree nuts.')]), MenuItem(name='SPINACH FETTUCCINE', description='ITALIAN SWEET SAUSAGE, SHISHITO PEPPERS, BRANDY SAUCE', symbols=[], contains=[AllergenPrediction(allergen='tree_nuts', pred ...
# {'piatto del salumiere': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'prosciutto di parma': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'carpaccio di bresaola': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'polipo octopus': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_LIKELY',
#   'contains_peanuts': nan},
#  'fritto misto calamari': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_LIKELY',
#   'contains_peanuts': nan},
#  'carciofini': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'insalata di cesare': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'insalata di rucola': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'gnocchi': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'bucatini arrabbiata': {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'black linguine': {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_LIKELY',
#   'contains_peanuts': nan},
#  'calamarata': {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_LIKELY',
#   'contains_peanuts': nan},
#  'spinach fettuccine': {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'garganelli': {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'spaghetti carbonara smoked pancetta': {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'fusilli avellinesi': {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'lasagna': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  "rigatoni all' amatriciana guanciale": {'contains_gluten': 'MAY_CONTAIN',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'parmigiana di melanzane': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'brodetto di pesce': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_LIKELY',
#   'contains_peanuts': nan},
#  'pesce del di* mp': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'MAY_CONTAIN',
#   'contains_peanuts': nan},
#  'pollo alla milanese': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'scaloppine di pollo': {'contains_gluten': 'VERY_LIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'tagliata': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'grilled seasonal vegetable plate': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'sauteed spinach': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'roasted brussels sprouts': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'herbed sautéed potatoes': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan},
#  'sautéed string beans': {'contains_gluten': 'VERY_UNLIKELY',
#   'contains_shellfish': 'VERY_UNLIKELY',
#   'contains_peanuts': nan}}

# %%
from test import pair_expected_and_produced_items


df=pair_expected_and_produced_items(expected=expected, produced=output['gluten'])
display(df)
# Out:
#                            Item Name Allergen Name     Prediction  \
# 0               piatto del salumiere        gluten  VERY_UNLIKELY
# 1                prosciutto di parma        gluten  VERY_UNLIKELY
# 2              carpaccio di bresaola        gluten  VERY_UNLIKELY
# 3                         carciofini        gluten    VERY_LIKELY
# 4                 insalata di cesare        gluten    MAY_CONTAIN
# 5                 insalata di rucola        gluten  VERY_UNLIKELY
# 6                            gnocchi        gluten    VERY_LIKELY
# 7                bucatini arrabbiata        gluten    VERY_LIKELY
# 8                     black linguine        gluten    VERY_LIKELY
# 9                         calamarata        gluten    VERY_LIKELY
# 10                spinach fettuccine        gluten    VERY_LIKELY
# 11                        garganelli        gluten    VERY_LIKELY
# 12                fusilli avellinesi        gluten    VERY_LIKELY
# 13                           lasagna        gluten    VERY_LIKELY
# 14           parmigiana di melanzane        gluten  VERY_UNLIKELY
# 15                 brodetto di pesce        gluten  VERY_UNLIKELY
# 16               pollo alla milanese        gluten    VERY_LIKELY
# 17               scaloppine di pollo        gluten  VERY_UNLIKELY
# 18  grilled seasonal vegetable plate        gluten  VERY_UNLIKELY
# 19           herbed sautéed potatoes        gluten  VERY_UNLIKELY
# 20              sautéed string beans        gluten  VERY_UNLIKELY
#
#                                           Explanation       Expected
# 0   Contains naturally gluten-free ingredients, an...    VERY_LIKELY
# 1   Tagged as GF and consists of naturally gluten-...  VERY_UNLIKELY
# 2   Tagged as GF and consists of naturally gluten-...  VERY_UNLIKELY
# 3   The description explicitly mentions 'bread cru...    VERY_LIKELY
# 4   Caesar salads often contain croutons, and the ...    VERY_LIKELY
# 5   Tagged as GF and consists of naturally gluten-...  VERY_UNLIKELY
# 6   Gnocchi is explicitly excluded from gluten-fre...    VERY_LIKELY
# 7   Bucatini is a type of pasta, which is explicit...    MAY_CONTAIN
# 8   Linguine is a type of pasta, which is explicit...    MAY_CONTAIN
# 9   Calamarata is a type of pasta, which is explic...    MAY_CONTAIN
# 10  Fettuccine is a type of pasta, which is explic...    MAY_CONTAIN
# 11  Garganelli is a type of pasta, which is explic...    MAY_CONTAIN
# 12  Fusilli is a type of pasta, which is explicitl...    MAY_CONTAIN
# 13  Lasagna is explicitly excluded from gluten-fre...    VERY_LIKELY
# 14  Tagged as GF and typically made with naturally...  VERY_UNLIKELY
# 15  Tagged as GF and consists of naturally gluten-...  VERY_UNLIKELY
# 16  Alla Milanese implies a breaded and fried prep...    VERY_LIKELY
# 17  Consists of naturally gluten-free ingredients....    VERY_LIKELY
# 18  Tagged as GF and consists of naturally gluten-...  VERY_UNLIKELY
# 19  Tagged as GF and consists of naturally gluten-...  VERY_UNLIKELY
# 20  Tagged as GF and consists of naturally gluten-...  VERY_UNLIKELY

# %%
(df['Expected'] == df['Prediction'] ).value_counts()
# Out:
# True     12
# False     9
# Name: count, dtype: int64
